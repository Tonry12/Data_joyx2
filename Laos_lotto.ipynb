# %% [markdown]
# <a href="https://colab.research.google.com/github/Tonry12/Data_joyx2/blob/main/Laos_lotto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
lotto = pd.read_csv('/content/drive/MyDrive/SPN/Laos_Lotto.csv')

# %%
lotto_ai = pd.read_csv('/content/drive/MyDrive/SPN/Laos_Lotto_pre.csv')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy
import os
import pickle
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
lotto
# Out:
#           date  เลข 4 ตัว  เลข 3 ตัว  เลข 2 ตัว  weekday_dum    weekday
# 0     5/3/2024       7999        999         99            6     Friday
# 1    4/29/2024       4351        351         51            2     Monday
# 2    4/26/2024       8721        721         21            6     Friday
# 3    4/24/2024       2552        552         52            4  Wednesday
# 4    4/22/2024       9490        490         90            2     Monday
# ..         ...        ...        ...        ...          ...        ...
# 144  5/19/2023       8573        573         73            6     Friday
# 145  5/17/2023       9846        846         46            4  Wednesday
# 146  5/15/2023       8649        649         49            2     Monday
# 147  5/12/2023       4077         77         77            6     Friday
# 148  5/10/2023       8521        521         21            4  Wednesday
#
# [149 rows x 6 columns]

# %%
lotto.isnull().any()
# Out:
# date           False
# เลข 4 ตัว      False
# เลข 3 ตัว      False
# เลข 2 ตัว      False
# weekday_dum    False
# weekday        False
# dtype: bool

# %%
lotto.rename(columns={'เลข 4 ตัว': 'top4','เลข 3 ตัว':'top3','เลข 2 ตัว':'top2'},inplace=True)

# %%
lt = lotto.drop(columns=['weekday_dum'])

# %%
lt['date'] = pd.to_datetime(lt['date'])

# %%
lt.dtypes
# Out:
# date       datetime64[ns]
# top4                int64
# top3                int64
# top2                int64
# weekday            object
# dtype: object

# %%
lt['top4'] = lt['top4'].apply(lambda x: '{:04}'.format(x))

# %%
lt
# Out:
#           date  top4  top3  top2    weekday
# 0   2024-05-03  7999   999    99     Friday
# 1   2024-04-29  4351   351    51     Monday
# 2   2024-04-26  8721   721    21     Friday
# 3   2024-04-24  2552   552    52  Wednesday
# 4   2024-04-22  9490   490    90     Monday
# ..         ...   ...   ...   ...        ...
# 144 2023-05-19  8573   573    73     Friday
# 145 2023-05-17  9846   846    46  Wednesday
# 146 2023-05-15  8649   649    49     Monday
# 147 2023-05-12  4077    77    77     Friday
# 148 2023-05-10  8521   521    21  Wednesday
#
# [149 rows x 5 columns]

# %%
lt_1 = lt

# %%
lt_1['top4'] = lt_1['top4'].astype(str)

# Split each value in the 'digi' column into its individual digits
lt_1['r1'] = lt_1['top4'].apply(lambda x: int(x[0]))
lt_1['r2'] = lt_1['top4'].apply(lambda x: int(x[1]))
lt_1['r3'] = lt_1['top4'].apply(lambda x: int(x[2]))
lt_1['r4'] = lt_1['top4'].apply(lambda x: int(x[3]))

# %%
lt_1= lt_1.drop(columns=['top3','top2'])

# %%
lt_1
# Out:
#           date  top4    weekday  r1  r2  r3  r4
# 0   2024-05-03  7999     Friday   7   9   9   9
# 1   2024-04-29  4351     Monday   4   3   5   1
# 2   2024-04-26  8721     Friday   8   7   2   1
# 3   2024-04-24  2552  Wednesday   2   5   5   2
# 4   2024-04-22  9490     Monday   9   4   9   0
# ..         ...   ...        ...  ..  ..  ..  ..
# 144 2023-05-19  8573     Friday   8   5   7   3
# 145 2023-05-17  9846  Wednesday   9   8   4   6
# 146 2023-05-15  8649     Monday   8   6   4   9
# 147 2023-05-12  4077     Friday   4   0   7   7
# 148 2023-05-10  8521  Wednesday   8   5   2   1
#
# [149 rows x 7 columns]

# %% [markdown]
# # วันจันทร์

# %% [markdown]
# ## เลขท้าย 4 ตัว

# %%
monday = lt_1[lt_1['weekday'] == "Monday"]

# %%
monday.head()
# Out:
#          date  top4 weekday  r1  r2  r3  r4
# 1  2024-04-29  4351  Monday   4   3   5   1
# 4  2024-04-22  9490  Monday   9   4   9   0
# 8  2024-04-08  9545  Monday   9   5   4   5
# 11 2024-04-01  1596  Monday   1   5   9   6
# 16 2024-03-18  8302  Monday   8   3   0   2

# %%
# เลขท้ายสี่ตัวหลักที่ 1 ที่ออกบ่อยสุด
grouped_counts = monday.groupby('r1').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#    r1  Count
# 9   9     10

# %%
# เลขท้ายสี่ตัวหลักที่ 2 ที่ออกบ่อยสุด
grouped_counts = monday.groupby('r2').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#    r2  Count
# 8   8      9

# %%
# เลขท้ายสี่ตัวหลักที่ 3 ที่ออกบ่อยสุด
grouped_counts = monday.groupby('r3').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#    r3  Count
# 2   2      8
# 9   9      8

# %%
# เลขท้ายสี่ตัวหลักที่ 4 ที่ออกบ่อยสุด
grouped_counts = monday.groupby('r4').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#    r4  Count
# 5   5      8

# %% [markdown]
# ### สรุป เลขท้าย 4 ตัวที่ออกบ่อยที่สุดคือ 9825 หรือ 9895

# %% [markdown]
# # งวดวันพุธ

# %%
wed = lt_1[lt_1['weekday'] == "Wednesday"]

# %%
wed
# Out:
#           date  top4    weekday  r1  r2  r3  r4
# 3   2024-04-24  2552  Wednesday   2   5   5   2
# 7   2024-04-10  4389  Wednesday   4   3   8   9
# 10  2024-04-03  1959  Wednesday   1   9   5   9
# 13  2024-03-27  0911  Wednesday   0   9   1   1
# 15  2024-03-20  7706  Wednesday   7   7   0   6
# 18  2024-03-13  1857  Wednesday   1   8   5   7
# 20  2024-03-06  6478  Wednesday   6   4   7   8
# 23  2024-02-28  6118  Wednesday   6   1   1   8
# 26  2024-02-21  3890  Wednesday   3   8   9   0
# 29  2024-02-14  7243  Wednesday   7   2   4   3
# 32  2024-02-07  8368  Wednesday   8   3   6   8
# 35  2024-01-31  8932  Wednesday   8   9   3   2
# 38  2024-01-24  7380  Wednesday   7   3   8   0
# 41  2024-01-17  1226  Wednesday   1   2   2   6
# 44  2024-01-10  8391  Wednesday   8   3   9   1
# 47  2024-01-03  3873  Wednesday   3   8   7   3
# 49  2023-12-27  8785  Wednesday   8   7   8   5
# 52  2023-12-20  9922  Wednesday   9   9   2   2
# 55  2023-12-13  2232  Wednesday   2   2   3   2
# 58  2023-12-06  4186  Wednesday   4   1   8   6
# 61  2023-11-29  5288  Wednesday   5   2   8   8
# 64  2023-11-22  4264  Wednesday   4   2   6   4
# 67  2023-11-15  5514  Wednesday   5   5   1   4
# 70  2023-11-08  7939  Wednesday   7   9   3   9
# 73  2023-11-01  5402  Wednesday   5   4   0   2
# 76  2023-10-25  0480  Wednesday   0   4   8   0
# 79  2023-10-18  6273  Wednesday   6   2   7   3
# 82  2023-10-11  9264  Wednesday   9   2   6   4
# 85  2023-10-04  9629  Wednesday   9   6   2   9
# 88  2023-09-27  0210  Wednesday   0   2   1   0
# 91  2023-09-20  7372  Wednesday   7   3   7   2
# 94  2023-09-13  8831  Wednesday   8   8   3   1
# 97  2023-09-06  1717  Wednesday   1   7   1   7
# 100 2023-08-30  2529  Wednesday   2   5   2   9
# 103 2023-08-23  3061  Wednesday   3   0   6   1
# 106 2023-08-16  1697  Wednesday   1   6   9   7
# 109 2023-08-09  3116  Wednesday   3   1   1   6
# 112 2023-08-02  7809  Wednesday   7   8   0   9
# 115 2023-07-26  1350  Wednesday   1   3   5   0
# 118 2023-07-19  5878  Wednesday   5   8   7   8
# 121 2023-07-12  1034  Wednesday   1   0   3   4
# 124 2023-07-05  0908  Wednesday   0   9   0   8
# 127 2023-06-28  2229  Wednesday   2   2   2   9
# 130 2023-06-21  7341  Wednesday   7   3   4   1
# 133 2023-06-14  2952  Wednesday   2   9   5   2
# 136 2023-06-07  0318  Wednesday   0   3   1   8
# 139 2023-05-31  7922  Wednesday   7   9   2   2
# 142 2023-05-24  2572  Wednesday   2   5   7   2
# 145 2023-05-17  9846  Wednesday   9   8   4   6
# 148 2023-05-10  8521  Wednesday   8   5   2   1

# %%
# เลขท้ายสี่ตัวหลักที่ 1 ที่ออกบ่อยสุด
grouped_counts = wed.groupby('r1').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#    r1  Count
# 7   7      8

# %%
# เลขท้ายสี่ตัวหลักที่ 2 ที่ออกบ่อยสุด
grouped_counts = wed.groupby('r2').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#    r2  Count
# 2   2      9

# %%
# เลขท้ายสี่ตัวหลักที่ 3 ที่ออกบ่อยสุด
grouped_counts = wed.groupby('r3').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#    r3  Count
# 1   1      7
# 2   2      7

# %%
# เลขท้ายสี่ตัวหลักที่ 4 ที่ออกบ่อยสุด
grouped_counts = wed.groupby('r4').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#    r4  Count
# 2   2      9

# %% [markdown]
# ### สรุป เลขท้าย 4 ตัวที่ออกบ่อยที่สุดคือ 7212 หรือ 7222

# %%
wed_1 = lt[lt['weekday'] == "Wednesday"]

# %%
wed_1
# Out:
#           date  top4  top3  top2    weekday  r1  r2  r3  r4
# 3   2024-04-24  2552   552    52  Wednesday   2   5   5   2
# 7   2024-04-10  4389   389    89  Wednesday   4   3   8   9
# 10  2024-04-03  1959   959    59  Wednesday   1   9   5   9
# 13  2024-03-27  0911   911    11  Wednesday   0   9   1   1
# 15  2024-03-20  7706   706     6  Wednesday   7   7   0   6
# 18  2024-03-13  1857   857    57  Wednesday   1   8   5   7
# 20  2024-03-06  6478   478    78  Wednesday   6   4   7   8
# 23  2024-02-28  6118   118    18  Wednesday   6   1   1   8
# 26  2024-02-21  3890   890    90  Wednesday   3   8   9   0
# 29  2024-02-14  7243   243    43  Wednesday   7   2   4   3
# 32  2024-02-07  8368   368    68  Wednesday   8   3   6   8
# 35  2024-01-31  8932   932    32  Wednesday   8   9   3   2
# 38  2024-01-24  7380   380    80  Wednesday   7   3   8   0
# 41  2024-01-17  1226   226    26  Wednesday   1   2   2   6
# 44  2024-01-10  8391   391    91  Wednesday   8   3   9   1
# 47  2024-01-03  3873   873    73  Wednesday   3   8   7   3
# 49  2023-12-27  8785   785    85  Wednesday   8   7   8   5
# 52  2023-12-20  9922   922    22  Wednesday   9   9   2   2
# 55  2023-12-13  2232   232    32  Wednesday   2   2   3   2
# 58  2023-12-06  4186   186    86  Wednesday   4   1   8   6
# 61  2023-11-29  5288   288    88  Wednesday   5   2   8   8
# 64  2023-11-22  4264   264    64  Wednesday   4   2   6   4
# 67  2023-11-15  5514   514    14  Wednesday   5   5   1   4
# 70  2023-11-08  7939   939    39  Wednesday   7   9   3   9
# 73  2023-11-01  5402   402     2  Wednesday   5   4   0   2
# 76  2023-10-25  0480   480    80  Wednesday   0   4   8   0
# 79  2023-10-18  6273   273    73  Wednesday   6   2   7   3
# 82  2023-10-11  9264   264    64  Wednesday   9   2   6   4
# 85  2023-10-04  9629   629    29  Wednesday   9   6   2   9
# 88  2023-09-27  0210   210    10  Wednesday   0   2   1   0
# 91  2023-09-20  7372   372    72  Wednesday   7   3   7   2
# 94  2023-09-13  8831   831    31  Wednesday   8   8   3   1
# 97  2023-09-06  1717   717    17  Wednesday   1   7   1   7
# 100 2023-08-30  2529   529    29  Wednesday   2   5   2   9
# 103 2023-08-23  3061    61    61  Wednesday   3   0   6   1
# 106 2023-08-16  1697   697    97  Wednesday   1   6   9   7
# 109 2023-08-09  3116   116    16  Wednesday   3   1   1   6
# 112 2023-08-02  7809   809     9  Wednesday   7   8   0   9
# 115 2023-07-26  1350   350    50  Wednesday   1   3   5   0
# 118 2023-07-19  5878   878    78  Wednesday   5   8   7   8
# 121 2023-07-12  1034    34    34  Wednesday   1   0   3   4
# 124 2023-07-05  0908   908     8  Wednesday   0   9   0   8
# 127 2023-06-28  2229   229    29  Wednesday   2   2   2   9
# 130 2023-06-21  7341   341    41  Wednesday   7   3   4   1
# 133 2023-06-14  2952   952    52  Wednesday   2   9   5   2
# 136 2023-06-07  0318   318    18  Wednesday   0   3   1   8
# 139 2023-05-31  7922   922    22  Wednesday   7   9   2   2
# 142 2023-05-24  2572   572    72  Wednesday   2   5   7   2
# 145 2023-05-17  9846   846    46  Wednesday   9   8   4   6
# 148 2023-05-10  8521   521    21  Wednesday   8   5   2   1

# %%
grouped_counts
# Out:
#    r4  Count
# 0   0      5
# 1   1      6
# 2   2      9
# 3   3      3
# 4   4      4
# 5   5      1
# 6   6      5
# 7   7      3
# 8   8      7
# 9   9      7

# %%
# เลขท้าย2ตัวที่ออกบ่อยสุด
grouped_counts = wed_1.groupby('top2').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#     top2  Count
# 13    29      3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy
import os
import pickle

# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
lotto_ai
# Out:
#           date  เลข 4 ตัว  เลข 3 ตัว  เลข 2 ตัว  เลขล่าง  เลขบน  weekday_dum  \
# 0    5/29/2024       5419        419         19       54     19          NaN
# 1    5/27/2024       9853        853         53       98     53          NaN
# 2    5/24/2024       9057         57         57       90     57          NaN
# 3    5/22/2024       3710        710         10       37     10          NaN
# 4    5/20/2024        147        147         47        1     47          NaN
# ..         ...        ...        ...        ...      ...    ...          ...
# 155  5/19/2023       8573        573         73       85     73          6.0
# 156  5/17/2023       9846        846         46       98     46          4.0
# 157  5/15/2023       8649        649         49       86     49          2.0
# 158  5/12/2023       4077         77         77       40     77          6.0
# 159  5/10/2023       8521        521         21       85     21          4.0
#
#        weekday
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 155     Friday
# 156  Wednesday
# 157     Monday
# 158     Friday
# 159  Wednesday
#
# [160 rows x 8 columns]

# %%
lotto_ai['date'] = pd.to_datetime(lotto_ai['date'])

# %%
lotto_ai
# Out:
#           date  เลข 4 ตัว  เลข 3 ตัว  เลข 2 ตัว  เลขล่าง  เลขบน  weekday_dum  \
# 0   2024-05-29       5419        419         19       54     19          NaN
# 1   2024-05-27       9853        853         53       98     53          NaN
# 2   2024-05-24       9057         57         57       90     57          NaN
# 3   2024-05-22       3710        710         10       37     10          NaN
# 4   2024-05-20        147        147         47        1     47          NaN
# ..         ...        ...        ...        ...      ...    ...          ...
# 155 2023-05-19       8573        573         73       85     73          6.0
# 156 2023-05-17       9846        846         46       98     46          4.0
# 157 2023-05-15       8649        649         49       86     49          2.0
# 158 2023-05-12       4077         77         77       40     77          6.0
# 159 2023-05-10       8521        521         21       85     21          4.0
#
#        weekday
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 155     Friday
# 156  Wednesday
# 157     Monday
# 158     Friday
# 159  Wednesday
#
# [160 rows x 8 columns]

# %%
lt_2 = lotto_ai.copy()

# %%
lt_2
# Out:
#           date  เลข 4 ตัว  เลข 3 ตัว  เลข 2 ตัว  เลขล่าง  เลขบน  weekday_dum  \
# 0   2024-05-29       5419        419         19       54     19          NaN
# 1   2024-05-27       9853        853         53       98     53          NaN
# 2   2024-05-24       9057         57         57       90     57          NaN
# 3   2024-05-22       3710        710         10       37     10          NaN
# 4   2024-05-20        147        147         47        1     47          NaN
# ..         ...        ...        ...        ...      ...    ...          ...
# 155 2023-05-19       8573        573         73       85     73          6.0
# 156 2023-05-17       9846        846         46       98     46          4.0
# 157 2023-05-15       8649        649         49       86     49          2.0
# 158 2023-05-12       4077         77         77       40     77          6.0
# 159 2023-05-10       8521        521         21       85     21          4.0
#
#        weekday
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 155     Friday
# 156  Wednesday
# 157     Monday
# 158     Friday
# 159  Wednesday
#
# [160 rows x 8 columns]

# %%
sh = lt_2.shape

# %%
z = 1

# %%
lt_3 = lt_2.iloc[z:sh[0], 0:sh[1]]

# %%
lt_3
# Out:
#           date  เลข 4 ตัว  เลข 3 ตัว  เลข 2 ตัว  เลขล่าง  เลขบน  weekday_dum  \
# 1   2024-05-27       9853        853         53       98     53          NaN
# 2   2024-05-24       9057         57         57       90     57          NaN
# 3   2024-05-22       3710        710         10       37     10          NaN
# 4   2024-05-20        147        147         47        1     47          NaN
# 5   2024-05-17       8717        717         17       87     17          NaN
# ..         ...        ...        ...        ...      ...    ...          ...
# 155 2023-05-19       8573        573         73       85     73          6.0
# 156 2023-05-17       9846        846         46       98     46          4.0
# 157 2023-05-15       8649        649         49       86     49          2.0
# 158 2023-05-12       4077         77         77       40     77          6.0
# 159 2023-05-10       8521        521         21       85     21          4.0
#
#        weekday
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# ..         ...
# 155     Friday
# 156  Wednesday
# 157     Monday
# 158     Friday
# 159  Wednesday
#
# [159 rows x 8 columns]

# %% [markdown]
# # LSTM

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
dfp = lt_3.copy()

# %%
df = dfp.reset_index()

# %%
df
# Out:
#      index       date  เลข 4 ตัว  เลข 3 ตัว  เลข 2 ตัว  เลขล่าง  เลขบน  \
# 0        1 2024-05-27       9853        853         53       98     53
# 1        2 2024-05-24       9057         57         57       90     57
# 2        3 2024-05-22       3710        710         10       37     10
# 3        4 2024-05-20        147        147         47        1     47
# 4        5 2024-05-17       8717        717         17       87     17
# ..     ...        ...        ...        ...        ...      ...    ...
# 154    155 2023-05-19       8573        573         73       85     73
# 155    156 2023-05-17       9846        846         46       98     46
# 156    157 2023-05-15       8649        649         49       86     49
# 157    158 2023-05-12       4077         77         77       40     77
# 158    159 2023-05-10       8521        521         21       85     21
#
#      weekday_dum    weekday
# 0            NaN        NaN
# 1            NaN        NaN
# 2            NaN        NaN
# 3            NaN        NaN
# 4            NaN        NaN
# ..           ...        ...
# 154          6.0     Friday
# 155          4.0  Wednesday
# 156          2.0     Monday
# 157          6.0     Friday
# 158          4.0  Wednesday
#
# [159 rows x 9 columns]

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
df2 = df.copy()

# %%
df1 = df.copy()
df.drop(['index','date','เลข 4 ตัว','เลข 3 ตัว','เลข 2 ตัว','weekday_dum','weekday'], axis=1, inplace=True)

number_of_features = df.shape[1]

# %%
df
# Out:
#      เลขล่าง  เลขบน
# 0         98     53
# 1         90     57
# 2         37     10
# 3          1     47
# 4         87     17
# ..       ...    ...
# 154       85     73
# 155       98     46
# 156       86     49
# 157       40     77
# 158       85     21
#
# [159 rows x 2 columns]

# %%
df1.drop(['index','เลข 4 ตัว','เลข 3 ตัว','เลข 2 ตัว','weekday_dum','weekday'], axis=1, inplace=True)

# %%
df1
# Out:
#           date  เลขล่าง  เลขบน
# 0   2024-05-27       98     53
# 1   2024-05-24       90     57
# 2   2024-05-22       37     10
# 3   2024-05-20        1     47
# 4   2024-05-17       87     17
# ..         ...      ...    ...
# 154 2023-05-19       85     73
# 155 2023-05-17       98     46
# 156 2023-05-15       86     49
# 157 2023-05-12       40     77
# 158 2023-05-10       85     21
#
# [159 rows x 3 columns]

# %%
window_length = 7
window_length
# Out:
# 7

# %%
train = df.copy()
train.head((window_length+1))
# Out:
#    เลขล่าง  เลขบน
# 0       98     53
# 1       90     57
# 2       37     10
# 3        1     47
# 4       87     17
# 5       99      2
# 6       35     98
# 7       11     55

# %%
train_rows = train.values.shape[0]
train_samples = np.empty([ train_rows - window_length, window_length, number_of_features], dtype=float)
train_labels = np.empty([ train_rows - window_length, number_of_features], dtype=float)
for i in range(0, train_rows-window_length):
    train_samples[i] = train.iloc[i : i+window_length, 0 : number_of_features]
    train_labels[i] = train.iloc[i+window_length : i+window_length+1, 0 : number_of_features]

# %%
train.values.shape[0]
# Out:
# 159

# %%
train_samples[0]
# Out:
# array([[98., 53.],
#        [90., 57.],
#        [37., 10.],
#        [ 1., 47.],
#        [87., 17.],
#        [99.,  2.],
#        [35., 98.]])

# %%
train_labels[0]
# Out:
# array([11., 55.])

# %%
scaler = StandardScaler()
transformed_dataset = scaler.fit_transform(train.values)
scaled_train_samples = pd.DataFrame(data=transformed_dataset, index=train.index)

# %%
scaled_train_samples.head(window_length+1)
# Out:
#           0         1
# 0  1.495009  0.169932
# 1  1.224696  0.304023
# 2 -0.566127 -1.271542
# 3 -1.782536 -0.031203
# 4  1.123329 -1.036883
# 5  1.528798 -1.539723
# 6 -0.633705  1.678452
# 7 -1.444644  0.236978

# %%
x_train = np.empty([ train_rows - window_length, window_length, number_of_features], dtype=float)
y_train = np.empty([ train_rows - window_length, number_of_features], dtype=float)

for i in range(0, train_rows-window_length):
    x_train[i] = scaled_train_samples.iloc[i : i+window_length, 0 : number_of_features]
    y_train[i] = scaled_train_samples.iloc[i+window_length : i+window_length+1, 0 : number_of_features]

# %%
y_train
# Out:
# array([[-1.4446443 ,  0.23697775],
#        [ 0.41375735, -0.96983778],
#        [-1.41085518,  0.70629491],
#        [ 0.85301592,  1.71197452],
#        [-0.36339243,  0.10288714],
#        [ 1.12332889, -0.90279247],
#        [-0.97159661,  0.13640979],
#        [ 1.35985274,  1.41027064],
#        [-0.39718155,  0.77334021],
#        [ 1.35985274, -0.53404328],
#        [-0.36339243,  1.37674798],
#        [ 1.39364186, -0.09824878],
#        [ 0.48133559, -1.47267759],
#        [-1.17433134,  0.37106837],
#        [-1.30948782,  1.61140656],
#        [-1.00538573, -0.93631513],
#        [-1.51222255, -1.23801901],
#        [-0.87022925,  0.33754571],
#        [ 0.78543768, -1.40563228],
#        [ 0.98817241, -1.5397229 ],
#        [ 0.0082879 ,  1.34322533],
#        [-1.20812046,  0.30402306],
#        [-0.19444683,  0.27050041],
#        [ 0.34617911,  1.00799879],
#        [ 0.1772335 , -1.1039284 ],
#        [ 0.44754647, -0.70165655],
#        [ 0.24481174, -1.00336044],
#        [ 1.05575065,  1.61140656],
#        [-0.56612716,  0.80686287],
#        [-0.53233804,  1.41027064],
#        [ 1.52879834, -0.33290736],
#        [ 1.32606362,  1.41027064],
#        [ 0.61649208, -0.16529409],
#        [ 0.61649208, -1.1039284 ],
#        [ 0.95438328,  0.10288714],
#        [ 0.98817241,  0.67277225],
#        [-1.07296397,  0.50515898],
#        [-0.32960331, -1.1709737 ],
#        [ 1.19090713, -0.53404328],
#        [ 1.02196153,  1.71197452],
#        [-1.2756987 , -0.86926982],
#        [ 0.6502812 ,  1.0750441 ],
#        [-0.80265101,  1.71197452],
#        [ 1.39364186, -0.6681339 ],
#        [-1.41085518, -0.73517921],
#        [-1.24190958, -0.80222451],
#        [-1.24190958, -0.80222451],
#        [ 0.98817241,  1.44379329],
#        [-0.32960331,  0.90743083],
#        [-0.59991628,  0.90743083],
#        [-0.53233804,  0.84038552],
#        [ 0.54891383,  1.5778839 ],
#        [ 1.12332889,  1.24265737],
#        [ 0.10965526,  0.6392496 ],
#        [-0.36339243,  0.2034551 ],
#        [ 1.52879834, -0.86926982],
#        [ 1.22469625, -0.80222451],
#        [ 0.92059416,  1.27618002],
#        [-1.07296397, -0.53404328],
#        [ 0.24481174,  1.37674798],
#        [ 0.0082879 ,  0.67277225],
#        [-0.43097068,  1.27618002],
#        [ 0.95438328, -0.06472613],
#        [-1.00538573,  1.71197452],
#        [-0.05929034,  1.34322533],
#        [ 0.04207702, -1.33858697],
#        [-0.49854892, -1.27154167],
#        [-0.39718155,  0.53868164],
#        [ 0.04207702,  0.10288714],
#        [ 0.0082879 ,  0.84038552],
#        [ 0.04207702, -1.13745105],
#        [ 0.27860087,  0.2034551 ],
#        [-1.54601167,  1.04152144],
#        [ 0.85301592, -0.29938471],
#        [-1.20812046, -0.6681339 ],
#        [-1.07296397, -0.80222451],
#        [ 0.0082879 , -1.5397229 ],
#        [-1.51222255, -0.80222451],
#        [-1.41085518, -0.86926982],
#        [-1.68116815,  1.0750441 ],
#        [ 1.02196153,  1.30970267],
#        [-1.14054222, -1.37210963],
#        [ 0.27860087,  0.84038552],
#        [ 1.29227449,  0.00231918],
#        [ 0.21102262, -0.73517921],
#        [ 1.29227449,  0.53868164],
#        [ 0.14344438, -1.6067682 ],
#        [-1.17433134,  0.94095348],
#        [ 1.42743098, -0.63461124],
#        [ 1.49500922,  0.47163633],
#        [-0.4647598 , -1.27154167],
#        [-1.74874639, -1.27154167],
#        [-0.19444683, -0.73517921],
#        [-0.22823595, -1.40563228],
#        [ 0.6502812 ,  0.80686287],
#        [-0.22823595, -1.6067682 ],
#        [-0.39718155,  1.71197452],
#        [ 1.15711801, -0.56756594],
#        [ 1.25848537, -0.33290736],
#        [-1.14054222, -0.46699798],
#        [-1.24190958, -1.03688309],
#        [ 1.49500922,  1.71197452],
#        [ 0.95438328, -0.50052063],
#        [-0.97159661, -0.63461124],
#        [ 0.34617911,  1.0750441 ],
#        [ 0.14344438, -1.50620024],
#        [-0.80265101,  0.43811368],
#        [ 1.22469625, -1.50620024],
#        [ 1.32606362, -0.13177144],
#        [-1.2756987 ,  1.64492921],
#        [ 0.68407032, -0.50052063],
#        [ 1.12332889, -1.1039284 ],
#        [-0.76886188, -1.07040574],
#        [ 0.58270295, -0.43347532],
#        [-1.64737903, -0.39995267],
#        [ 0.8192268 , -1.30506432],
#        [-0.26202507, -1.43915493],
#        [ 0.54891383, -1.57324555],
#        [-1.37706606,  0.06936448],
#        [-1.71495727,  1.41027064],
#        [ 1.19090713, -0.53404328],
#        [ 0.14344438,  1.00799879],
#        [ 0.10965526, -0.93631513],
#        [-0.97159661,  1.34322533],
#        [-1.47843343, -0.46699798],
#        [ 1.49500922, -0.80222451],
#        [ 1.32606362, -0.29938471],
#        [-1.51222255, -1.33858697],
#        [ 0.41375735,  0.77334021],
#        [-1.20812046, -0.43347532],
#        [-1.07296397, -0.63461124],
#        [ 0.88680504,  0.60572695],
#        [-0.19444683,  0.73981756],
#        [ 0.6502812 , -0.2323394 ],
#        [-1.51222255,  1.14208941],
#        [-1.64737903, -1.07040574],
#        [-0.83644013,  0.13640979],
#        [ 1.12332889, -0.83574717],
#        [ 0.37996823,  0.70629491],
#        [-1.71495727, -1.00336044],
#        [ 0.48133559,  1.5778839 ],
#        [-1.30948782,  0.27050041],
#        [ 0.85301592, -0.86926982],
#        [ 0.48133559, -0.43347532],
#        [-0.26202507,  0.6392496 ],
#        [-0.97159661,  0.80686287],
#        [ 0.0082879 ,  1.30970267],
#        [ 1.05575065,  0.84038552],
#        [ 1.49500922, -0.06472613],
#        [ 1.08953977,  0.03584183],
#        [-0.4647598 ,  0.97447614],
#        [ 1.05575065, -0.90279247]])

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Bidirectional, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import mse

# %%
# Initialising the RNN
model = Sequential()
# Adding the input layer and the LSTM layer
model.add(Bidirectional(LSTM(240,
                        input_shape = (window_length, number_of_features),
                        return_sequences = True)))
# Adding a first Dropout layer
model.add(Dropout(0.2))
# Adding a second LSTM layer
model.add(Bidirectional(LSTM(240,
                        input_shape = (window_length, number_of_features),
                        return_sequences = True)))
# Adding a second Dropout layer
model.add(Dropout(0.2))
# Adding a third LSTM layer
model.add(Bidirectional(LSTM(240,
                        input_shape = (window_length, number_of_features),
                        return_sequences = True)))
# Adding a fourth LSTM layer
model.add(Bidirectional(LSTM(240,
                        input_shape = (window_length, number_of_features),
                        return_sequences = False)))
# Adding a third Dropout layer
model.add(Dropout(0.2))
# Adding the first output layer
model.add(Dense(70))
# Adding the last output layer
model.add(Dense(number_of_features))

# %%
model.compile(optimizer=Adam(learning_rate=0.005), loss ='mse', metrics=['accuracy'])

# %%
model.fit(x=x_train, y=y_train, batch_size=128, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 2/2 - 19s - loss: 1.0005 - accuracy: 0.5395 - 19s/epoch - 9s/step
# Epoch 2/100
# 2/2 - 1s - loss: 6.0361 - accuracy: 0.4934 - 851ms/epoch - 425ms/step
# Epoch 3/100
# 2/2 - 1s - loss: 0.9793 - accuracy: 0.4408 - 926ms/epoch - 463ms/step
# Epoch 4/100
# 2/2 - 1s - loss: 0.9913 - accuracy: 0.5592 - 1s/epoch - 692ms/step
# Epoch 5/100
# 2/2 - 1s - loss: 0.9885 - accuracy: 0.5724 - 1s/epoch - 704ms/step
# Epoch 6/100
# 2/2 - 1s - loss: 0.9709 - accuracy: 0.5395 - 1s/epoch - 693ms/step
# Epoch 7/100
# 2/2 - 1s - loss: 0.9613 - accuracy: 0.5855 - 1s/epoch - 695ms/step
# Epoch 8/100
# 2/2 - 1s - loss: 0.9586 - accuracy: 0.5789 - 835ms/epoch - 418ms/step
# Epoch 9/100
# 2/2 - 1s - loss: 0.9444 - accuracy: 0.5789 - 819ms/epoch - 410ms/step
# Epoch 10/100
# 2/2 - 1s - loss: 0.9360 - accuracy: 0.5395 - 820ms/epoch - 410ms/step
# Epoch 11/100
# 2/2 - 1s - loss: 0.9801 - accuracy: 0.5461 - 842ms/epoch - 421ms/step
# Epoch 12/100
# 2/2 - 1s - loss: 0.9735 - accuracy: 0.4934 - 840ms/epoch - 420ms/step
# Epoch 13/100
# 2/2 - 1s - loss: 0.9339 - accuracy: 0.5329 - 837ms/epoch - 419ms/step
# Epoch 14/100
# 2/2 - 1s - loss: 0.9237 - accuracy: 0.5395 - 817ms/epoch - 409ms/step
# Epoch 15/100
# 2/2 - 1s - loss: 0.9168 - accuracy: 0.5789 - 806ms/epoch - 403ms/step
# Epoch 16/100
# 2/2 - 1s - loss: 0.9164 - accuracy: 0.6053 - 820ms/epoch - 410ms/step
# Epoch 17/100
# 2/2 - 1s - loss: 0.8938 - accuracy: 0.6382 - 807ms/epoch - 403ms/step
# Epoch 18/100
# 2/2 - 1s - loss: 0.9109 - accuracy: 0.6184 - 829ms/epoch - 414ms/step
# Epoch 19/100
# 2/2 - 1s - loss: 0.8753 - accuracy: 0.6118 - 827ms/epoch - 413ms/step
# Epoch 20/100
# 2/2 - 1s - loss: 0.8627 - accuracy: 0.6184 - 1s/epoch - 703ms/step
# Epoch 21/100
# 2/2 - 1s - loss: 0.8774 - accuracy: 0.6250 - 1s/epoch - 704ms/step
# Epoch 22/100
# 2/2 - 1s - loss: 0.8115 - accuracy: 0.6053 - 1s/epoch - 653ms/step
# Epoch 23/100
# 2/2 - 1s - loss: 0.8685 - accuracy: 0.6447 - 1s/epoch - 745ms/step
# Epoch 24/100
# 2/2 - 1s - loss: 0.8038 - accuracy: 0.6842 - 852ms/epoch - 426ms/step
# Epoch 25/100
# 2/2 - 1s - loss: 0.8150 - accuracy: 0.6184 - 817ms/epoch - 408ms/step
# Epoch 26/100
# 2/2 - 1s - loss: 0.8241 - accuracy: 0.6053 - 830ms/epoch - 415ms/step
# Epoch 27/100
# 2/2 - 1s - loss: 0.7768 - accuracy: 0.6447 - 823ms/epoch - 412ms/step
# Epoch 28/100
# 2/2 - 1s - loss: 0.7577 - accuracy: 0.6842 - 862ms/epoch - 431ms/step
# Epoch 29/100
# 2/2 - 1s - loss: 0.7568 - accuracy: 0.6974 - 825ms/epoch - 413ms/step
# Epoch 30/100
# 2/2 - 1s - loss: 0.7562 - accuracy: 0.6447 - 813ms/epoch - 406ms/step
# Epoch 31/100
# 2/2 - 1s - loss: 0.7667 - accuracy: 0.6382 - 831ms/epoch - 416ms/step
# Epoch 32/100
# 2/2 - 1s - loss: 0.7509 - accuracy: 0.6316 - 829ms/epoch - 415ms/step
# Epoch 33/100
# 2/2 - 1s - loss: 0.7296 - accuracy: 0.6579 - 816ms/epoch - 408ms/step
# Epoch 34/100
# 2/2 - 1s - loss: 0.6836 - accuracy: 0.7039 - 823ms/epoch - 411ms/step
# Epoch 35/100
# 2/2 - 1s - loss: 0.6858 - accuracy: 0.6842 - 815ms/epoch - 407ms/step
# Epoch 36/100
# 2/2 - 1s - loss: 0.6099 - accuracy: 0.7434 - 1s/epoch - 627ms/step
# Epoch 37/100
# 2/2 - 1s - loss: 0.6039 - accuracy: 0.7368 - 1s/epoch - 695ms/step
# Epoch 38/100
# 2/2 - 1s - loss: 0.6770 - accuracy: 0.6579 - 1s/epoch - 680ms/step
# Epoch 39/100
# 2/2 - 1s - loss: 0.5510 - accuracy: 0.6974 - 1s/epoch - 727ms/step
# Epoch 40/100
# 2/2 - 1s - loss: 0.6360 - accuracy: 0.7500 - 937ms/epoch - 469ms/step
# Epoch 41/100
# 2/2 - 1s - loss: 0.5424 - accuracy: 0.7763 - 819ms/epoch - 410ms/step
# Epoch 42/100
# 2/2 - 1s - loss: 0.5204 - accuracy: 0.7368 - 823ms/epoch - 411ms/step
# Epoch 43/100
# 2/2 - 1s - loss: 0.5201 - accuracy: 0.7368 - 817ms/epoch - 408ms/step
# Epoch 44/100
# 2/2 - 1s - loss: 0.4799 - accuracy: 0.7829 - 799ms/epoch - 399ms/step
# Epoch 45/100
# 2/2 - 1s - loss: 0.4857 - accuracy: 0.7829 - 825ms/epoch - 412ms/step
# Epoch 46/100
# 2/2 - 1s - loss: 0.4794 - accuracy: 0.7895 - 827ms/epoch - 413ms/step
# Epoch 47/100
# 2/2 - 1s - loss: 0.4317 - accuracy: 0.8026 - 827ms/epoch - 414ms/step
# Epoch 48/100
# 2/2 - 1s - loss: 0.4593 - accuracy: 0.7632 - 814ms/epoch - 407ms/step
# Epoch 49/100
# 2/2 - 1s - loss: 0.3861 - accuracy: 0.7829 - 821ms/epoch - 410ms/step
# Epoch 50/100
# 2/2 - 1s - loss: 0.4411 - accuracy: 0.7763 - 820ms/epoch - 410ms/step
# Epoch 51/100
# 2/2 - 1s - loss: 0.3790 - accuracy: 0.8224 - 828ms/epoch - 414ms/step
# Epoch 52/100
# 2/2 - 1s - loss: 0.3571 - accuracy: 0.8158 - 1s/epoch - 548ms/step
# Epoch 53/100
# 2/2 - 1s - loss: 0.3489 - accuracy: 0.8421 - 1s/epoch - 703ms/step
# Epoch 54/100
# 2/2 - 1s - loss: 0.3399 - accuracy: 0.8553 - 1s/epoch - 687ms/step
# Epoch 55/100
# 2/2 - 1s - loss: 0.2822 - accuracy: 0.8026 - 1s/epoch - 698ms/step
# Epoch 56/100
# 2/2 - 1s - loss: 0.3067 - accuracy: 0.8158 - 1s/epoch - 550ms/step
# Epoch 57/100
# 2/2 - 1s - loss: 0.3026 - accuracy: 0.8750 - 820ms/epoch - 410ms/step
# Epoch 58/100
# 2/2 - 1s - loss: 0.2708 - accuracy: 0.8618 - 810ms/epoch - 405ms/step
# Epoch 59/100
# 2/2 - 1s - loss: 0.2471 - accuracy: 0.8487 - 861ms/epoch - 431ms/step
# Epoch 60/100
# 2/2 - 1s - loss: 0.2631 - accuracy: 0.8618 - 807ms/epoch - 404ms/step
# Epoch 61/100
# 2/2 - 1s - loss: 0.2609 - accuracy: 0.8618 - 1s/epoch - 587ms/step
# Epoch 62/100
# 2/2 - 1s - loss: 0.2468 - accuracy: 0.8947 - 833ms/epoch - 417ms/step
# Epoch 63/100
# 2/2 - 1s - loss: 0.2588 - accuracy: 0.8947 - 839ms/epoch - 419ms/step
# Epoch 64/100
# 2/2 - 1s - loss: 0.2184 - accuracy: 0.8750 - 838ms/epoch - 419ms/step
# Epoch 65/100
# 2/2 - 1s - loss: 0.2049 - accuracy: 0.9145 - 827ms/epoch - 413ms/step
# Epoch 66/100
# 2/2 - 1s - loss: 0.1610 - accuracy: 0.9474 - 832ms/epoch - 416ms/step
# Epoch 67/100
# 2/2 - 1s - loss: 0.1619 - accuracy: 0.9079 - 849ms/epoch - 425ms/step
# Epoch 68/100
# 2/2 - 1s - loss: 0.1513 - accuracy: 0.9079 - 1s/epoch - 678ms/step
# Epoch 69/100
# 2/2 - 2s - loss: 0.1608 - accuracy: 0.9079 - 2s/epoch - 843ms/step
# Epoch 70/100
# 2/2 - 1s - loss: 0.1445 - accuracy: 0.9145 - 1s/epoch - 670ms/step
# Epoch 71/100
# 2/2 - 1s - loss: 0.1339 - accuracy: 0.9013 - 1s/epoch - 734ms/step
# Epoch 72/100
# 2/2 - 1s - loss: 0.1105 - accuracy: 0.9013 - 833ms/epoch - 416ms/step
# Epoch 73/100
# 2/2 - 1s - loss: 0.1396 - accuracy: 0.8947 - 816ms/epoch - 408ms/step
# Epoch 74/100
# 2/2 - 1s - loss: 0.1218 - accuracy: 0.9079 - 835ms/epoch - 417ms/step
# Epoch 75/100
# 2/2 - 1s - loss: 0.0863 - accuracy: 0.9276 - 821ms/epoch - 411ms/step
# Epoch 76/100
# 2/2 - 1s - loss: 0.1273 - accuracy: 0.9342 - 823ms/epoch - 411ms/step
# Epoch 77/100
# 2/2 - 1s - loss: 0.1037 - accuracy: 0.9342 - 820ms/epoch - 410ms/step
# Epoch 78/100
# 2/2 - 1s - loss: 0.0901 - accuracy: 0.9276 - 817ms/epoch - 408ms/step
# Epoch 79/100
# 2/2 - 1s - loss: 0.0772 - accuracy: 0.9342 - 806ms/epoch - 403ms/step
# Epoch 80/100
# 2/2 - 1s - loss: 0.1009 - accuracy: 0.9342 - 812ms/epoch - 406ms/step
# Epoch 81/100
# 2/2 - 1s - loss: 0.0867 - accuracy: 0.9342 - 796ms/epoch - 398ms/step
# Epoch 82/100
# 2/2 - 1s - loss: 0.0836 - accuracy: 0.9276 - 817ms/epoch - 409ms/step
# Epoch 83/100
# 2/2 - 1s - loss: 0.0646 - accuracy: 0.9342 - 837ms/epoch - 418ms/step
# Epoch 84/100
# 2/2 - 1s - loss: 0.0712 - accuracy: 0.9145 - 1s/epoch - 634ms/step
# Epoch 85/100
# 2/2 - 1s - loss: 0.0689 - accuracy: 0.9211 - 1s/epoch - 686ms/step
# Epoch 86/100
# 2/2 - 1s - loss: 0.0635 - accuracy: 0.9342 - 1s/epoch - 665ms/step
# Epoch 87/100
# 2/2 - 1s - loss: 0.0648 - accuracy: 0.9539 - 1s/epoch - 727ms/step
# Epoch 88/100
# 2/2 - 1s - loss: 0.0585 - accuracy: 0.9474 - 1s/epoch - 504ms/step
# Epoch 89/100
# 2/2 - 1s - loss: 0.0559 - accuracy: 0.9342 - 868ms/epoch - 434ms/step
# Epoch 90/100
# 2/2 - 1s - loss: 0.0547 - accuracy: 0.9474 - 815ms/epoch - 408ms/step
# Epoch 91/100
# 2/2 - 1s - loss: 0.0511 - accuracy: 0.9408 - 810ms/epoch - 405ms/step
# Epoch 92/100
# 2/2 - 1s - loss: 0.0447 - accuracy: 0.9408 - 834ms/epoch - 417ms/step
# Epoch 93/100
# 2/2 - 1s - loss: 0.0496 - accuracy: 0.9276 - 823ms/epoch - 411ms/step
# Epoch 94/100
# 2/2 - 1s - loss: 0.0518 - accuracy: 0.9342 - 826ms/epoch - 413ms/step
# Epoch 95/100
# 2/2 - 1s - loss: 0.0459 - accuracy: 0.9408 - 816ms/epoch - 408ms/step
# Epoch 96/100
# 2/2 - 1s - loss: 0.0363 - accuracy: 0.9539 - 806ms/epoch - 403ms/step
# Epoch 97/100
# 2/2 - 1s - loss: 0.0379 - accuracy: 0.9803 - 823ms/epoch - 412ms/step
# Epoch 98/100
# 2/2 - 1s - loss: 0.0522 - accuracy: 0.9671 - 818ms/epoch - 409ms/step
# Epoch 99/100
# 2/2 - 1s - loss: 0.0370 - accuracy: 0.9671 - 825ms/epoch - 413ms/step
# Epoch 100/100
# 2/2 - 1s - loss: 0.0395 - accuracy: 0.9474 - 1s/epoch - 548ms/step

# %% [markdown]
# ### Prediction without rounding up or down the results

# %%
df1.rename(columns={'date': 'Date'},inplace=True)

# %%
print('-' * 40)
print('Prediction vs. GoundTruth without rounding up or down')
for i in range(1,10):
  test = df1.copy()
  test = test.tail((window_length+10-i))
  test = test.head((window_length+1))
  test_Date = df1.iloc[ (test.tail().index[-1]) ]['Date']
  test1 = test.head((window_length))
  test1.drop(['Date'], axis=1, inplace=True)
  test1 = np.array(test1)
  x_test = scaler.transform(test1)
  y_test_pred = model.predict(np.array([x_test]))
  y_test_true = test.drop(['Date'], axis=1, inplace=True)
  y_test_true = test.tail(1)
  print('Drawing  Date', test_Date)
  print('Prediction:\t', scaler.inverse_transform(y_test_pred).astype(int)[0])
  print('GoundTruth:\t', np.array(y_test_true)[0])
  print('-' * 40)
# Out:
# ----------------------------------------
# Prediction vs. GoundTruth without rounding up or down
# 1/1 [==============================] - 3s 3s/step
# Drawing  Date 2023-05-29 00:00:00
# Prediction:	 [66 36]
# GoundTruth:	 [68 35]
# ----------------------------------------
# 1/1 [==============================] - 0s 37ms/step
# Drawing  Date 2023-05-26 00:00:00
# Prediction:	 [43 62]
# GoundTruth:	 [46 67]
# ----------------------------------------
# 1/1 [==============================] - 0s 40ms/step
# Drawing  Date 2023-05-24 00:00:00
# Prediction:	 [24 74]
# GoundTruth:	 [25 72]
# ----------------------------------------
# 1/1 [==============================] - 0s 37ms/step
# Drawing  Date 2023-05-22 00:00:00
# Prediction:	 [47 86]
# GoundTruth:	 [54 87]
# ----------------------------------------
# 1/1 [==============================] - 0s 37ms/step
# Drawing  Date 2023-05-19 00:00:00
# Prediction:	 [76 77]
# GoundTruth:	 [85 73]
# ----------------------------------------
# 1/1 [==============================] - 0s 35ms/step
# Drawing  Date 2023-05-17 00:00:00
# Prediction:	 [87 47]
# GoundTruth:	 [98 46]
# ----------------------------------------
# 1/1 [==============================] - 0s 36ms/step
# Drawing  Date 2023-05-15 00:00:00
# Prediction:	 [84 46]
# GoundTruth:	 [86 49]
# ----------------------------------------
# 1/1 [==============================] - 0s 33ms/step
# Drawing  Date 2023-05-12 00:00:00
# Prediction:	 [34 76]
# GoundTruth:	 [40 77]
# ----------------------------------------
# 1/1 [==============================] - 0s 34ms/step
# Drawing  Date 2023-05-10 00:00:00
# Prediction:	 [76 31]
# GoundTruth:	 [85 21]
# ----------------------------------------

# %% [markdown]
# ### Predict the Future Drawing Results on June 1, 2o24

# %%
next_Date = '2024-05-20'
print('-' * 40)
print('Predict the Future Drawing on',next_Date)
next = df.copy()
next = next.tail(window_length)
next = np.array(next)
x_next = scaler.transform(next)
y_next_pred = model.predict(np.array([x_next]))
filtered_df = lt_2[lt_2['date'] == next_Date]

# Extract the actual values and convert to a list
actual_values = filtered_df[['เลขล่าง','เลขบน']].values.flatten().tolist()

print('Drawing  Date', next_Date)
print('Prediction:\t', scaler.inverse_transform(y_next_pred).astype(int)[0])
print('GoundTruth:   \t', actual_values)
print('-' * 40)
# Out:
# ----------------------------------------
# Predict the Future Drawing on 2024-05-20
# 1/1 [==============================] - 0s 149ms/step
# Drawing  Date 2024-05-20
# Prediction:	 [83 26]
# GoundTruth:   	 [1, 47]
# ----------------------------------------
