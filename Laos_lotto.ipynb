# %% [markdown]
# <a href="https://colab.research.google.com/github/Tonry12/Data_joyx2/blob/main/Laos_lotto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
lotto = pd.read_csv('/content/drive/MyDrive/SPN/Laos_Lotto.csv')

# %%
lotto_ai = pd.read_csv('/content/drive/MyDrive/SPN/Laos_Lotto_pre.csv')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy
import os
import pickle
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
lotto
# Out:
#           date  เลข 4 ตัว  เลข 3 ตัว  เลข 2 ตัว  weekday_dum    weekday
# 0     5/3/2024       7999        999         99            6     Friday
# 1    4/29/2024       4351        351         51            2     Monday
# 2    4/26/2024       8721        721         21            6     Friday
# 3    4/24/2024       2552        552         52            4  Wednesday
# 4    4/22/2024       9490        490         90            2     Monday
# ..         ...        ...        ...        ...          ...        ...
# 144  5/19/2023       8573        573         73            6     Friday
# 145  5/17/2023       9846        846         46            4  Wednesday
# 146  5/15/2023       8649        649         49            2     Monday
# 147  5/12/2023       4077         77         77            6     Friday
# 148  5/10/2023       8521        521         21            4  Wednesday
#
# [149 rows x 6 columns]

# %%
lotto.isnull().any()
# Out:
# date           False
# เลข 4 ตัว      False
# เลข 3 ตัว      False
# เลข 2 ตัว      False
# weekday_dum    False
# weekday        False
# dtype: bool

# %%
lotto.rename(columns={'เลข 4 ตัว': 'top4','เลข 3 ตัว':'top3','เลข 2 ตัว':'top2'},inplace=True)

# %%
lt = lotto.drop(columns=['weekday_dum'])

# %%
lt['date'] = pd.to_datetime(lt['date'])

# %%
lt.dtypes
# Out:
# date       datetime64[ns]
# top4                int64
# top3                int64
# top2                int64
# weekday            object
# dtype: object

# %%
lt['top4'] = lt['top4'].apply(lambda x: '{:04}'.format(x))

# %%
lt
# Out:
#           date  top4  top3  top2    weekday
# 0   2024-05-03  7999   999    99     Friday
# 1   2024-04-29  4351   351    51     Monday
# 2   2024-04-26  8721   721    21     Friday
# 3   2024-04-24  2552   552    52  Wednesday
# 4   2024-04-22  9490   490    90     Monday
# ..         ...   ...   ...   ...        ...
# 144 2023-05-19  8573   573    73     Friday
# 145 2023-05-17  9846   846    46  Wednesday
# 146 2023-05-15  8649   649    49     Monday
# 147 2023-05-12  4077    77    77     Friday
# 148 2023-05-10  8521   521    21  Wednesday
#
# [149 rows x 5 columns]

# %%
lt_1 = lt

# %%
lt_1['top4'] = lt_1['top4'].astype(str)

# Split each value in the 'digi' column into its individual digits
lt_1['r1'] = lt_1['top4'].apply(lambda x: int(x[0]))
lt_1['r2'] = lt_1['top4'].apply(lambda x: int(x[1]))
lt_1['r3'] = lt_1['top4'].apply(lambda x: int(x[2]))
lt_1['r4'] = lt_1['top4'].apply(lambda x: int(x[3]))

# %%
lt_1= lt_1.drop(columns=['top3','top2'])

# %%
lt_1
# Out:
#           date  top4    weekday  r1  r2  r3  r4
# 0   2024-05-03  7999     Friday   7   9   9   9
# 1   2024-04-29  4351     Monday   4   3   5   1
# 2   2024-04-26  8721     Friday   8   7   2   1
# 3   2024-04-24  2552  Wednesday   2   5   5   2
# 4   2024-04-22  9490     Monday   9   4   9   0
# ..         ...   ...        ...  ..  ..  ..  ..
# 144 2023-05-19  8573     Friday   8   5   7   3
# 145 2023-05-17  9846  Wednesday   9   8   4   6
# 146 2023-05-15  8649     Monday   8   6   4   9
# 147 2023-05-12  4077     Friday   4   0   7   7
# 148 2023-05-10  8521  Wednesday   8   5   2   1
#
# [149 rows x 7 columns]

# %% [markdown]
# # วันจันทร์

# %% [markdown]
# ## เลขท้าย 4 ตัว

# %%
monday = lt_1[lt_1['weekday'] == "Monday"]

# %%
monday.head()
# Out:
#          date  top4 weekday  r1  r2  r3  r4
# 1  2024-04-29  4351  Monday   4   3   5   1
# 4  2024-04-22  9490  Monday   9   4   9   0
# 8  2024-04-08  9545  Monday   9   5   4   5
# 11 2024-04-01  1596  Monday   1   5   9   6
# 16 2024-03-18  8302  Monday   8   3   0   2

# %%
# เลขท้ายสี่ตัวหลักที่ 1 ที่ออกบ่อยสุด
grouped_counts = monday.groupby('r1').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#    r1  Count
# 9   9     10

# %%
# เลขท้ายสี่ตัวหลักที่ 2 ที่ออกบ่อยสุด
grouped_counts = monday.groupby('r2').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#    r2  Count
# 8   8      9

# %%
# เลขท้ายสี่ตัวหลักที่ 3 ที่ออกบ่อยสุด
grouped_counts = monday.groupby('r3').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#    r3  Count
# 2   2      8
# 9   9      8

# %%
# เลขท้ายสี่ตัวหลักที่ 4 ที่ออกบ่อยสุด
grouped_counts = monday.groupby('r4').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#    r4  Count
# 5   5      8

# %% [markdown]
# ### สรุป เลขท้าย 4 ตัวที่ออกบ่อยที่สุดคือ 9825 หรือ 9895

# %% [markdown]
# # งวดวันพุธ

# %%
wed = lt_1[lt_1['weekday'] == "Wednesday"]

# %%
wed
# Out:
#           date  top4    weekday  r1  r2  r3  r4
# 3   2024-04-24  2552  Wednesday   2   5   5   2
# 7   2024-04-10  4389  Wednesday   4   3   8   9
# 10  2024-04-03  1959  Wednesday   1   9   5   9
# 13  2024-03-27  0911  Wednesday   0   9   1   1
# 15  2024-03-20  7706  Wednesday   7   7   0   6
# 18  2024-03-13  1857  Wednesday   1   8   5   7
# 20  2024-03-06  6478  Wednesday   6   4   7   8
# 23  2024-02-28  6118  Wednesday   6   1   1   8
# 26  2024-02-21  3890  Wednesday   3   8   9   0
# 29  2024-02-14  7243  Wednesday   7   2   4   3
# 32  2024-02-07  8368  Wednesday   8   3   6   8
# 35  2024-01-31  8932  Wednesday   8   9   3   2
# 38  2024-01-24  7380  Wednesday   7   3   8   0
# 41  2024-01-17  1226  Wednesday   1   2   2   6
# 44  2024-01-10  8391  Wednesday   8   3   9   1
# 47  2024-01-03  3873  Wednesday   3   8   7   3
# 49  2023-12-27  8785  Wednesday   8   7   8   5
# 52  2023-12-20  9922  Wednesday   9   9   2   2
# 55  2023-12-13  2232  Wednesday   2   2   3   2
# 58  2023-12-06  4186  Wednesday   4   1   8   6
# 61  2023-11-29  5288  Wednesday   5   2   8   8
# 64  2023-11-22  4264  Wednesday   4   2   6   4
# 67  2023-11-15  5514  Wednesday   5   5   1   4
# 70  2023-11-08  7939  Wednesday   7   9   3   9
# 73  2023-11-01  5402  Wednesday   5   4   0   2
# 76  2023-10-25  0480  Wednesday   0   4   8   0
# 79  2023-10-18  6273  Wednesday   6   2   7   3
# 82  2023-10-11  9264  Wednesday   9   2   6   4
# 85  2023-10-04  9629  Wednesday   9   6   2   9
# 88  2023-09-27  0210  Wednesday   0   2   1   0
# 91  2023-09-20  7372  Wednesday   7   3   7   2
# 94  2023-09-13  8831  Wednesday   8   8   3   1
# 97  2023-09-06  1717  Wednesday   1   7   1   7
# 100 2023-08-30  2529  Wednesday   2   5   2   9
# 103 2023-08-23  3061  Wednesday   3   0   6   1
# 106 2023-08-16  1697  Wednesday   1   6   9   7
# 109 2023-08-09  3116  Wednesday   3   1   1   6
# 112 2023-08-02  7809  Wednesday   7   8   0   9
# 115 2023-07-26  1350  Wednesday   1   3   5   0
# 118 2023-07-19  5878  Wednesday   5   8   7   8
# 121 2023-07-12  1034  Wednesday   1   0   3   4
# 124 2023-07-05  0908  Wednesday   0   9   0   8
# 127 2023-06-28  2229  Wednesday   2   2   2   9
# 130 2023-06-21  7341  Wednesday   7   3   4   1
# 133 2023-06-14  2952  Wednesday   2   9   5   2
# 136 2023-06-07  0318  Wednesday   0   3   1   8
# 139 2023-05-31  7922  Wednesday   7   9   2   2
# 142 2023-05-24  2572  Wednesday   2   5   7   2
# 145 2023-05-17  9846  Wednesday   9   8   4   6
# 148 2023-05-10  8521  Wednesday   8   5   2   1

# %%
# เลขท้ายสี่ตัวหลักที่ 1 ที่ออกบ่อยสุด
grouped_counts = wed.groupby('r1').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#    r1  Count
# 7   7      8

# %%
# เลขท้ายสี่ตัวหลักที่ 2 ที่ออกบ่อยสุด
grouped_counts = wed.groupby('r2').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#    r2  Count
# 2   2      9

# %%
# เลขท้ายสี่ตัวหลักที่ 3 ที่ออกบ่อยสุด
grouped_counts = wed.groupby('r3').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#    r3  Count
# 1   1      7
# 2   2      7

# %%
# เลขท้ายสี่ตัวหลักที่ 4 ที่ออกบ่อยสุด
grouped_counts = wed.groupby('r4').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#    r4  Count
# 2   2      9

# %% [markdown]
# ### สรุป เลขท้าย 4 ตัวที่ออกบ่อยที่สุดคือ 7212 หรือ 7222

# %%
wed_1 = lt[lt['weekday'] == "Wednesday"]

# %%
wed_1
# Out:
#           date  top4  top3  top2    weekday  r1  r2  r3  r4
# 3   2024-04-24  2552   552    52  Wednesday   2   5   5   2
# 7   2024-04-10  4389   389    89  Wednesday   4   3   8   9
# 10  2024-04-03  1959   959    59  Wednesday   1   9   5   9
# 13  2024-03-27  0911   911    11  Wednesday   0   9   1   1
# 15  2024-03-20  7706   706     6  Wednesday   7   7   0   6
# 18  2024-03-13  1857   857    57  Wednesday   1   8   5   7
# 20  2024-03-06  6478   478    78  Wednesday   6   4   7   8
# 23  2024-02-28  6118   118    18  Wednesday   6   1   1   8
# 26  2024-02-21  3890   890    90  Wednesday   3   8   9   0
# 29  2024-02-14  7243   243    43  Wednesday   7   2   4   3
# 32  2024-02-07  8368   368    68  Wednesday   8   3   6   8
# 35  2024-01-31  8932   932    32  Wednesday   8   9   3   2
# 38  2024-01-24  7380   380    80  Wednesday   7   3   8   0
# 41  2024-01-17  1226   226    26  Wednesday   1   2   2   6
# 44  2024-01-10  8391   391    91  Wednesday   8   3   9   1
# 47  2024-01-03  3873   873    73  Wednesday   3   8   7   3
# 49  2023-12-27  8785   785    85  Wednesday   8   7   8   5
# 52  2023-12-20  9922   922    22  Wednesday   9   9   2   2
# 55  2023-12-13  2232   232    32  Wednesday   2   2   3   2
# 58  2023-12-06  4186   186    86  Wednesday   4   1   8   6
# 61  2023-11-29  5288   288    88  Wednesday   5   2   8   8
# 64  2023-11-22  4264   264    64  Wednesday   4   2   6   4
# 67  2023-11-15  5514   514    14  Wednesday   5   5   1   4
# 70  2023-11-08  7939   939    39  Wednesday   7   9   3   9
# 73  2023-11-01  5402   402     2  Wednesday   5   4   0   2
# 76  2023-10-25  0480   480    80  Wednesday   0   4   8   0
# 79  2023-10-18  6273   273    73  Wednesday   6   2   7   3
# 82  2023-10-11  9264   264    64  Wednesday   9   2   6   4
# 85  2023-10-04  9629   629    29  Wednesday   9   6   2   9
# 88  2023-09-27  0210   210    10  Wednesday   0   2   1   0
# 91  2023-09-20  7372   372    72  Wednesday   7   3   7   2
# 94  2023-09-13  8831   831    31  Wednesday   8   8   3   1
# 97  2023-09-06  1717   717    17  Wednesday   1   7   1   7
# 100 2023-08-30  2529   529    29  Wednesday   2   5   2   9
# 103 2023-08-23  3061    61    61  Wednesday   3   0   6   1
# 106 2023-08-16  1697   697    97  Wednesday   1   6   9   7
# 109 2023-08-09  3116   116    16  Wednesday   3   1   1   6
# 112 2023-08-02  7809   809     9  Wednesday   7   8   0   9
# 115 2023-07-26  1350   350    50  Wednesday   1   3   5   0
# 118 2023-07-19  5878   878    78  Wednesday   5   8   7   8
# 121 2023-07-12  1034    34    34  Wednesday   1   0   3   4
# 124 2023-07-05  0908   908     8  Wednesday   0   9   0   8
# 127 2023-06-28  2229   229    29  Wednesday   2   2   2   9
# 130 2023-06-21  7341   341    41  Wednesday   7   3   4   1
# 133 2023-06-14  2952   952    52  Wednesday   2   9   5   2
# 136 2023-06-07  0318   318    18  Wednesday   0   3   1   8
# 139 2023-05-31  7922   922    22  Wednesday   7   9   2   2
# 142 2023-05-24  2572   572    72  Wednesday   2   5   7   2
# 145 2023-05-17  9846   846    46  Wednesday   9   8   4   6
# 148 2023-05-10  8521   521    21  Wednesday   8   5   2   1

# %%
grouped_counts
# Out:
#    r4  Count
# 0   0      5
# 1   1      6
# 2   2      9
# 3   3      3
# 4   4      4
# 5   5      1
# 6   6      5
# 7   7      3
# 8   8      7
# 9   9      7

# %%
# เลขท้าย2ตัวที่ออกบ่อยสุด
grouped_counts = wed_1.groupby('top2').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#     top2  Count
# 13    29      3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy
import os
import pickle

# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
lotto_ai
# Out:
#           date  เลข 4 ตัว  เลข 3 ตัว  เลข 2 ตัว  เลขล่าง  เลขบน  weekday_dum  \
# 0     6/5/2024       1493        493         93       14     93          NaN
# 1     6/3/2024       1399        399         99       13     99          NaN
# 2    5/31/2024       3303        303          3       33      3          NaN
# 3    5/29/2024       5419        419         19       54     19          NaN
# 4    5/27/2024       9853        853         53       98     53          NaN
# ..         ...        ...        ...        ...      ...    ...          ...
# 158  5/19/2023       8573        573         73       85     73          6.0
# 159  5/17/2023       9846        846         46       98     46          4.0
# 160  5/15/2023       8649        649         49       86     49          2.0
# 161  5/12/2023       4077         77         77       40     77          6.0
# 162  5/10/2023       8521        521         21       85     21          4.0
#
#        weekday
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 158     Friday
# 159  Wednesday
# 160     Monday
# 161     Friday
# 162  Wednesday
#
# [163 rows x 8 columns]

# %%
lotto_ai['date'] = pd.to_datetime(lotto_ai['date'])

# %%
lotto_ai
# Out:
#           date  เลข 4 ตัว  เลข 3 ตัว  เลข 2 ตัว  เลขล่าง  เลขบน  weekday_dum  \
# 0   2024-06-05       1493        493         93       14     93          NaN
# 1   2024-06-03       1399        399         99       13     99          NaN
# 2   2024-05-31       3303        303          3       33      3          NaN
# 3   2024-05-29       5419        419         19       54     19          NaN
# 4   2024-05-27       9853        853         53       98     53          NaN
# ..         ...        ...        ...        ...      ...    ...          ...
# 158 2023-05-19       8573        573         73       85     73          6.0
# 159 2023-05-17       9846        846         46       98     46          4.0
# 160 2023-05-15       8649        649         49       86     49          2.0
# 161 2023-05-12       4077         77         77       40     77          6.0
# 162 2023-05-10       8521        521         21       85     21          4.0
#
#        weekday
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 158     Friday
# 159  Wednesday
# 160     Monday
# 161     Friday
# 162  Wednesday
#
# [163 rows x 8 columns]

# %%
lt_2 = lotto_ai.copy()

# %%
lt_2
# Out:
#           date  เลข 4 ตัว  เลข 3 ตัว  เลข 2 ตัว  เลขล่าง  เลขบน  weekday_dum  \
# 0   2024-06-05       1493        493         93       14     93          NaN
# 1   2024-06-03       1399        399         99       13     99          NaN
# 2   2024-05-31       3303        303          3       33      3          NaN
# 3   2024-05-29       5419        419         19       54     19          NaN
# 4   2024-05-27       9853        853         53       98     53          NaN
# ..         ...        ...        ...        ...      ...    ...          ...
# 158 2023-05-19       8573        573         73       85     73          6.0
# 159 2023-05-17       9846        846         46       98     46          4.0
# 160 2023-05-15       8649        649         49       86     49          2.0
# 161 2023-05-12       4077         77         77       40     77          6.0
# 162 2023-05-10       8521        521         21       85     21          4.0
#
#        weekday
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 158     Friday
# 159  Wednesday
# 160     Monday
# 161     Friday
# 162  Wednesday
#
# [163 rows x 8 columns]

# %%
sh = lt_2.shape

# %%
z = 3

# %%
lt_3 = lt_2.iloc[z:sh[0], 0:sh[1]]

# %%
lt_3
# Out:
#           date  เลข 4 ตัว  เลข 3 ตัว  เลข 2 ตัว  เลขล่าง  เลขบน  weekday_dum  \
# 3   2024-05-29       5419        419         19       54     19          NaN
# 4   2024-05-27       9853        853         53       98     53          NaN
# 5   2024-05-24       9057         57         57       90     57          NaN
# 6   2024-05-22       3710        710         10       37     10          NaN
# 7   2024-05-20        147        147         47        1     47          NaN
# ..         ...        ...        ...        ...      ...    ...          ...
# 158 2023-05-19       8573        573         73       85     73          6.0
# 159 2023-05-17       9846        846         46       98     46          4.0
# 160 2023-05-15       8649        649         49       86     49          2.0
# 161 2023-05-12       4077         77         77       40     77          6.0
# 162 2023-05-10       8521        521         21       85     21          4.0
#
#        weekday
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# ..         ...
# 158     Friday
# 159  Wednesday
# 160     Monday
# 161     Friday
# 162  Wednesday
#
# [160 rows x 8 columns]

# %% [markdown]
# # LSTM

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
dfp = lt_3.copy()

# %%
df = dfp.reset_index()

# %%
df
# Out:
#      index       date  เลข 4 ตัว  เลข 3 ตัว  เลข 2 ตัว  เลขล่าง  เลขบน  \
# 0        3 2024-05-29       5419        419         19       54     19
# 1        4 2024-05-27       9853        853         53       98     53
# 2        5 2024-05-24       9057         57         57       90     57
# 3        6 2024-05-22       3710        710         10       37     10
# 4        7 2024-05-20        147        147         47        1     47
# ..     ...        ...        ...        ...        ...      ...    ...
# 155    158 2023-05-19       8573        573         73       85     73
# 156    159 2023-05-17       9846        846         46       98     46
# 157    160 2023-05-15       8649        649         49       86     49
# 158    161 2023-05-12       4077         77         77       40     77
# 159    162 2023-05-10       8521        521         21       85     21
#
#      weekday_dum    weekday
# 0            NaN        NaN
# 1            NaN        NaN
# 2            NaN        NaN
# 3            NaN        NaN
# 4            NaN        NaN
# ..           ...        ...
# 155          6.0     Friday
# 156          4.0  Wednesday
# 157          2.0     Monday
# 158          6.0     Friday
# 159          4.0  Wednesday
#
# [160 rows x 9 columns]

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
df2 = df.copy()

# %%
df1 = df.copy()
df.drop(['index','date','เลข 4 ตัว','เลข 3 ตัว','เลข 2 ตัว','weekday_dum','weekday'], axis=1, inplace=True)

number_of_features = df.shape[1]

# %%
df
# Out:
#      เลขล่าง  เลขบน
# 0         54     19
# 1         98     53
# 2         90     57
# 3         37     10
# 4          1     47
# ..       ...    ...
# 155       85     73
# 156       98     46
# 157       86     49
# 158       40     77
# 159       85     21
#
# [160 rows x 2 columns]

# %%
df1.drop(['index','เลข 4 ตัว','เลข 3 ตัว','เลข 2 ตัว','weekday_dum','weekday'], axis=1, inplace=True)

# %%
df1
# Out:
#           date  เลขล่าง  เลขบน
# 0   2024-05-29       54     19
# 1   2024-05-27       98     53
# 2   2024-05-24       90     57
# 3   2024-05-22       37     10
# 4   2024-05-20        1     47
# ..         ...      ...    ...
# 155 2023-05-19       85     73
# 156 2023-05-17       98     46
# 157 2023-05-15       86     49
# 158 2023-05-12       40     77
# 159 2023-05-10       85     21
#
# [160 rows x 3 columns]

# %%
window_length = 7
window_length
# Out:
# 7

# %%
train = df.copy()
train.head((window_length+1))
# Out:
#    เลขล่าง  เลขบน
# 0       54     19
# 1       98     53
# 2       90     57
# 3       37     10
# 4        1     47
# 5       87     17
# 6       99      2
# 7       35     98

# %%
train_rows = train.values.shape[0]
train_samples = np.empty([ train_rows - window_length, window_length, number_of_features], dtype=float)
train_labels = np.empty([ train_rows - window_length, number_of_features], dtype=float)
for i in range(0, train_rows-window_length):
    train_samples[i] = train.iloc[i : i+window_length, 0 : number_of_features]
    train_labels[i] = train.iloc[i+window_length : i+window_length+1, 0 : number_of_features]

# %%
train.values.shape[0]
# Out:
# 160

# %%
train_samples[0]
# Out:
# array([[54., 19.],
#        [98., 53.],
#        [90., 57.],
#        [37., 10.],
#        [ 1., 47.],
#        [87., 17.],
#        [99.,  2.]])

# %%
train_labels[0]
# Out:
# array([35., 98.])

# %%
scaler = StandardScaler()
transformed_dataset = scaler.fit_transform(train.values)
scaled_train_samples = pd.DataFrame(data=transformed_dataset, index=train.index)

# %%
scaled_train_samples.head(window_length+1)
# Out:
#           0         1
# 0  0.008262 -0.963973
# 1  1.499651  0.176030
# 2  1.228489  0.310148
# 3 -0.567956 -1.265738
# 4 -1.788184 -0.025147
# 5  1.126804 -1.031032
# 6  1.533546 -1.533974
# 7 -0.635747  1.684857

# %%
x_train = np.empty([ train_rows - window_length, window_length, number_of_features], dtype=float)
y_train = np.empty([ train_rows - window_length, number_of_features], dtype=float)

for i in range(0, train_rows-window_length):
    x_train[i] = scaled_train_samples.iloc[i : i+window_length, 0 : number_of_features]
    y_train[i] = scaled_train_samples.iloc[i+window_length : i+window_length+1, 0 : number_of_features]

# %%
y_train
# Out:
# array([[-0.63574689,  1.68485717],
#        [-1.44923174,  0.24308885],
#        [ 0.41500438, -0.96397301],
#        [-1.41533654,  0.71250179],
#        [ 0.85564201,  1.71838666],
#        [-0.36458527,  0.10897086],
#        [ 1.12680363, -0.89691401],
#        [-0.97469891,  0.14250036],
#        [ 1.36407005,  1.4166212 ],
#        [-0.39848047,  0.77956078],
#        [ 1.36407005, -0.52808956],
#        [-0.36458527,  1.3830917 ],
#        [ 1.39796525, -0.09220611],
#        [ 0.48279479, -1.46691544],
#        [-1.17807012,  0.37720683],
#        [-1.31365093,  1.61779818],
#        [-1.00859411, -0.93044351],
#        [-1.51702215, -1.23220897],
#        [-0.8730133 ,  0.34367733],
#        [ 0.78785161, -1.39985645],
#        [ 0.99122282, -1.53397444],
#        [ 0.00826196,  1.34956221],
#        [-1.21196533,  0.31014784],
#        [-0.19510926,  0.27661834],
#        [ 0.34721398,  1.01426725],
#        [ 0.17773797, -1.09809099],
#        [ 0.44889958, -0.69573704],
#        [ 0.24552837, -0.9975025 ],
#        [ 1.05901323,  1.61779818],
#        [-0.56795648,  0.81309028],
#        [-0.53406128,  1.4166212 ],
#        [ 1.53354606, -0.32691258],
#        [ 1.33017484,  1.4166212 ],
#        [ 0.6183756 , -0.15926511],
#        [ 0.6183756 , -1.09809099],
#        [ 0.95732762,  0.10897086],
#        [ 0.99122282,  0.67897229],
#        [-1.07638452,  0.51132481],
#        [-0.33069007, -1.16514998],
#        [ 1.19459403, -0.52808956],
#        [ 1.02511802,  1.71838666],
#        [-1.27975573, -0.86338452],
#        [ 0.6522708 ,  1.08132624],
#        [-0.8052229 ,  1.71838666],
#        [ 1.39796525, -0.66220754],
#        [-1.41533654, -0.72926654],
#        [-1.24586053, -0.79632553],
#        [-1.24586053, -0.79632553],
#        [ 0.99122282,  1.4501507 ],
#        [-0.33069007,  0.91367876],
#        [-0.60185169,  0.91367876],
#        [-0.53406128,  0.84661977],
#        [ 0.55058519,  1.58426868],
#        [ 1.12680363,  1.24897372],
#        [ 0.10994756,  0.6454428 ],
#        [-0.36458527,  0.20955935],
#        [ 1.53354606, -0.86338452],
#        [ 1.22848924, -0.79632553],
#        [ 0.92343242,  1.28250322],
#        [-1.07638452, -0.52808956],
#        [ 0.24552837,  1.3830917 ],
#        [ 0.00826196,  0.67897229],
#        [-0.43237567,  1.28250322],
#        [ 0.95732762, -0.05867662],
#        [-1.00859411,  1.71838666],
#        [-0.05952845,  1.34956221],
#        [ 0.04215716, -1.33279746],
#        [-0.50016608, -1.26573847],
#        [-0.39848047,  0.54485431],
#        [ 0.04215716,  0.10897086],
#        [ 0.00826196,  0.84661977],
#        [ 0.04215716, -1.13162049],
#        [ 0.27942357,  0.20955935],
#        [-1.55091735,  1.04779675],
#        [ 0.85564201, -0.29338309],
#        [-1.21196533, -0.66220754],
#        [-1.07638452, -0.79632553],
#        [ 0.00826196, -1.53397444],
#        [-1.51702215, -0.79632553],
#        [-1.41533654, -0.86338452],
#        [-1.68649816,  1.08132624],
#        [ 1.02511802,  1.31603271],
#        [-1.14417492, -1.36632696],
#        [ 0.27942357,  0.84661977],
#        [ 1.29627964,  0.00838237],
#        [ 0.21163317, -0.72926654],
#        [ 1.29627964,  0.54485431],
#        [ 0.14384276, -1.60103343],
#        [-1.17807012,  0.94720826],
#        [ 1.43186045, -0.62867805],
#        [ 1.49965085,  0.47779532],
#        [-0.46627088, -1.26573847],
#        [-1.75428856, -1.26573847],
#        [-0.19510926, -0.72926654],
#        [-0.22900446, -1.39985645],
#        [ 0.6522708 ,  0.81309028],
#        [-0.22900446, -1.60103343],
#        [-0.39848047,  1.71838666],
#        [ 1.16069883, -0.56161906],
#        [ 1.26238444, -0.32691258],
#        [-1.14417492, -0.46103057],
#        [-1.24586053, -1.031032  ],
#        [ 1.49965085,  1.71838666],
#        [ 0.95732762, -0.49456006],
#        [-0.97469891, -0.62867805],
#        [ 0.34721398,  1.08132624],
#        [ 0.14384276, -1.50044494],
#        [-0.8052229 ,  0.44426582],
#        [ 1.22848924, -1.50044494],
#        [ 1.33017484, -0.12573561],
#        [-1.27975573,  1.65132767],
#        [ 0.686166  , -0.49456006],
#        [ 1.12680363, -1.09809099],
#        [-0.7713277 , -1.06456149],
#        [ 0.58448039, -0.42750107],
#        [-1.65260295, -0.39397158],
#        [ 0.82174681, -1.29926797],
#        [-0.26289966, -1.43338595],
#        [ 0.55058519, -1.56750393],
#        [-1.38144134,  0.07544137],
#        [-1.72039336,  1.4166212 ],
#        [ 1.19459403, -0.52808956],
#        [ 0.14384276,  1.01426725],
#        [ 0.10994756, -0.93044351],
#        [-0.97469891,  1.34956221],
#        [-1.48312694, -0.46103057],
#        [ 1.49965085, -0.79632553],
#        [ 1.33017484, -0.29338309],
#        [-1.51702215, -1.33279746],
#        [ 0.41500438,  0.77956078],
#        [-1.21196533, -0.42750107],
#        [-1.07638452, -0.62867805],
#        [ 0.88953721,  0.6119133 ],
#        [-0.19510926,  0.74603128],
#        [ 0.6522708 , -0.2263241 ],
#        [-1.51702215,  1.14838523],
#        [-1.65260295, -1.06456149],
#        [-0.8391181 ,  0.14250036],
#        [ 1.12680363, -0.82985502],
#        [ 0.38110918,  0.71250179],
#        [-1.72039336, -0.9975025 ],
#        [ 0.48279479,  1.58426868],
#        [-1.31365093,  0.27661834],
#        [ 0.85564201, -0.86338452],
#        [ 0.48279479, -0.42750107],
#        [-0.26289966,  0.6454428 ],
#        [-0.97469891,  0.81309028],
#        [ 0.00826196,  1.31603271],
#        [ 1.05901323,  0.84661977],
#        [ 1.49965085, -0.05867662],
#        [ 1.09290843,  0.04191187],
#        [-0.46627088,  0.98073775],
#        [ 1.05901323, -0.89691401]])

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Bidirectional, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import mse

# %%
# Initialising the RNN
model = Sequential()
# Adding the input layer and the LSTM layer
model.add(Bidirectional(LSTM(240,
                        input_shape = (window_length, number_of_features),
                        return_sequences = True)))
# Adding a first Dropout layer
model.add(Dropout(0.2))
# Adding a second LSTM layer
model.add(Bidirectional(LSTM(240,
                        input_shape = (window_length, number_of_features),
                        return_sequences = True)))
# Adding a second Dropout layer
model.add(Dropout(0.2))
# Adding a third LSTM layer
model.add(Bidirectional(LSTM(240,
                        input_shape = (window_length, number_of_features),
                        return_sequences = True)))
# Adding a fourth LSTM layer
model.add(Bidirectional(LSTM(240,
                        input_shape = (window_length, number_of_features),
                        return_sequences = False)))
# Adding a third Dropout layer
model.add(Dropout(0.2))
# Adding the first output layer
model.add(Dense(70))
# Adding the last output layer
model.add(Dense(number_of_features))

# %%
model.compile(optimizer=Adam(learning_rate=0.01), loss ='mse', metrics=['accuracy'])

# %%
model.fit(x=x_train, y=y_train, batch_size=128, epochs=200, verbose=2)
# Out:
# Epoch 1/200
# 2/2 - 19s - loss: 1.0885 - accuracy: 0.5098 - 19s/epoch - 9s/step
# Epoch 2/200
# 2/2 - 1s - loss: 3.2507 - accuracy: 0.5098 - 892ms/epoch - 446ms/step
# Epoch 3/200
# 2/2 - 1s - loss: 2.2783 - accuracy: 0.4248 - 844ms/epoch - 422ms/step
# Epoch 4/200
# 2/2 - 1s - loss: 1.0901 - accuracy: 0.4444 - 827ms/epoch - 413ms/step
# Epoch 5/200
# 2/2 - 1s - loss: 1.0795 - accuracy: 0.5621 - 845ms/epoch - 423ms/step
# Epoch 6/200
# 2/2 - 1s - loss: 1.6896 - accuracy: 0.4967 - 1s/epoch - 531ms/step
# Epoch 7/200
# 2/2 - 1s - loss: 1.0495 - accuracy: 0.4967 - 1s/epoch - 732ms/step
# Epoch 8/200
# 2/2 - 1s - loss: 1.0718 - accuracy: 0.5294 - 1s/epoch - 731ms/step
# Epoch 9/200
# 2/2 - 1s - loss: 1.0292 - accuracy: 0.6078 - 1s/epoch - 735ms/step
# Epoch 10/200
# 2/2 - 1s - loss: 1.1800 - accuracy: 0.4967 - 1s/epoch - 580ms/step
# Epoch 11/200
# 2/2 - 1s - loss: 0.9891 - accuracy: 0.6078 - 862ms/epoch - 431ms/step
# Epoch 12/200
# 2/2 - 1s - loss: 0.9696 - accuracy: 0.5425 - 858ms/epoch - 429ms/step
# Epoch 13/200
# 2/2 - 1s - loss: 0.8954 - accuracy: 0.6078 - 932ms/epoch - 466ms/step
# Epoch 14/200
# 2/2 - 1s - loss: 0.9205 - accuracy: 0.5948 - 1s/epoch - 724ms/step
# Epoch 15/200
# 2/2 - 1s - loss: 0.8691 - accuracy: 0.6405 - 1s/epoch - 734ms/step
# Epoch 16/200
# 2/2 - 1s - loss: 0.8013 - accuracy: 0.6732 - 1s/epoch - 698ms/step
# Epoch 17/200
# 2/2 - 1s - loss: 0.7778 - accuracy: 0.6471 - 1s/epoch - 550ms/step
# Epoch 18/200
# 2/2 - 1s - loss: 0.7648 - accuracy: 0.6667 - 853ms/epoch - 426ms/step
# Epoch 19/200
# 2/2 - 1s - loss: 0.7392 - accuracy: 0.6732 - 1s/epoch - 514ms/step
# Epoch 20/200
# 2/2 - 1s - loss: 0.7590 - accuracy: 0.6471 - 1s/epoch - 740ms/step
# Epoch 21/200
# 2/2 - 1s - loss: 0.7260 - accuracy: 0.7255 - 1s/epoch - 732ms/step
# Epoch 22/200
# 2/2 - 2s - loss: 0.6912 - accuracy: 0.7386 - 2s/epoch - 761ms/step
# Epoch 23/200
# 2/2 - 1s - loss: 0.6848 - accuracy: 0.6863 - 992ms/epoch - 496ms/step
# Epoch 24/200
# 2/2 - 1s - loss: 0.6248 - accuracy: 0.7320 - 856ms/epoch - 428ms/step
# Epoch 25/200
# 2/2 - 1s - loss: 0.7505 - accuracy: 0.6601 - 831ms/epoch - 416ms/step
# Epoch 26/200
# 2/2 - 1s - loss: 0.7447 - accuracy: 0.6667 - 843ms/epoch - 422ms/step
# Epoch 27/200
# 2/2 - 1s - loss: 0.6764 - accuracy: 0.6667 - 857ms/epoch - 428ms/step
# Epoch 28/200
# 2/2 - 1s - loss: 0.6553 - accuracy: 0.7124 - 841ms/epoch - 420ms/step
# Epoch 29/200
# 2/2 - 1s - loss: 0.6066 - accuracy: 0.6732 - 842ms/epoch - 421ms/step
# Epoch 30/200
# 2/2 - 1s - loss: 0.6942 - accuracy: 0.7124 - 845ms/epoch - 423ms/step
# Epoch 31/200
# 2/2 - 1s - loss: 0.5110 - accuracy: 0.7647 - 851ms/epoch - 425ms/step
# Epoch 32/200
# 2/2 - 1s - loss: 0.4994 - accuracy: 0.7516 - 839ms/epoch - 420ms/step
# Epoch 33/200
# 2/2 - 1s - loss: 0.5903 - accuracy: 0.7582 - 875ms/epoch - 438ms/step
# Epoch 34/200
# 2/2 - 1s - loss: 0.6329 - accuracy: 0.6405 - 906ms/epoch - 453ms/step
# Epoch 35/200
# 2/2 - 1s - loss: 0.6888 - accuracy: 0.6797 - 1s/epoch - 731ms/step
# Epoch 36/200
# 2/2 - 1s - loss: 0.6572 - accuracy: 0.6863 - 1s/epoch - 725ms/step
# Epoch 37/200
# 2/2 - 1s - loss: 0.5660 - accuracy: 0.7059 - 1s/epoch - 692ms/step
# Epoch 38/200
# 2/2 - 1s - loss: 0.6221 - accuracy: 0.6667 - 1s/epoch - 696ms/step
# Epoch 39/200
# 2/2 - 1s - loss: 0.5001 - accuracy: 0.7647 - 850ms/epoch - 425ms/step
# Epoch 40/200
# 2/2 - 1s - loss: 0.5093 - accuracy: 0.7451 - 860ms/epoch - 430ms/step
# Epoch 41/200
# 2/2 - 1s - loss: 0.4529 - accuracy: 0.7386 - 862ms/epoch - 431ms/step
# Epoch 42/200
# 2/2 - 1s - loss: 0.4081 - accuracy: 0.7647 - 859ms/epoch - 430ms/step
# Epoch 43/200
# 2/2 - 1s - loss: 0.4085 - accuracy: 0.7255 - 861ms/epoch - 431ms/step
# Epoch 44/200
# 2/2 - 1s - loss: 0.3248 - accuracy: 0.7778 - 848ms/epoch - 424ms/step
# Epoch 45/200
# 2/2 - 1s - loss: 0.2901 - accuracy: 0.8170 - 859ms/epoch - 429ms/step
# Epoch 46/200
# 2/2 - 1s - loss: 0.2676 - accuracy: 0.8627 - 864ms/epoch - 432ms/step
# Epoch 47/200
# 2/2 - 1s - loss: 0.2380 - accuracy: 0.8889 - 870ms/epoch - 435ms/step
# Epoch 48/200
# 2/2 - 1s - loss: 0.2168 - accuracy: 0.8693 - 868ms/epoch - 434ms/step
# Epoch 49/200
# 2/2 - 1s - loss: 0.2560 - accuracy: 0.8889 - 854ms/epoch - 427ms/step
# Epoch 50/200
# 2/2 - 1s - loss: 0.2738 - accuracy: 0.8693 - 1s/epoch - 572ms/step
# Epoch 51/200
# 2/2 - 1s - loss: 0.2068 - accuracy: 0.8889 - 1s/epoch - 735ms/step
# Epoch 52/200
# 2/2 - 1s - loss: 0.2516 - accuracy: 0.8497 - 1s/epoch - 681ms/step
# Epoch 53/200
# 2/2 - 1s - loss: 0.2238 - accuracy: 0.8758 - 1s/epoch - 741ms/step
# Epoch 54/200
# 2/2 - 1s - loss: 0.1905 - accuracy: 0.8693 - 1s/epoch - 544ms/step
# Epoch 55/200
# 2/2 - 1s - loss: 0.1805 - accuracy: 0.9085 - 868ms/epoch - 434ms/step
# Epoch 56/200
# 2/2 - 1s - loss: 0.1516 - accuracy: 0.8693 - 828ms/epoch - 414ms/step
# Epoch 57/200
# 2/2 - 1s - loss: 0.1799 - accuracy: 0.8889 - 854ms/epoch - 427ms/step
# Epoch 58/200
# 2/2 - 1s - loss: 0.1296 - accuracy: 0.8889 - 859ms/epoch - 429ms/step
# Epoch 59/200
# 2/2 - 1s - loss: 0.1271 - accuracy: 0.9216 - 859ms/epoch - 429ms/step
# Epoch 60/200
# 2/2 - 1s - loss: 0.1282 - accuracy: 0.9216 - 852ms/epoch - 426ms/step
# Epoch 61/200
# 2/2 - 1s - loss: 0.1060 - accuracy: 0.9412 - 874ms/epoch - 437ms/step
# Epoch 62/200
# 2/2 - 1s - loss: 0.1055 - accuracy: 0.9542 - 844ms/epoch - 422ms/step
# Epoch 63/200
# 2/2 - 1s - loss: 0.0833 - accuracy: 0.9542 - 852ms/epoch - 426ms/step
# Epoch 64/200
# 2/2 - 1s - loss: 0.1131 - accuracy: 0.8889 - 848ms/epoch - 424ms/step
# Epoch 65/200
# 2/2 - 1s - loss: 0.1040 - accuracy: 0.9346 - 875ms/epoch - 438ms/step
# Epoch 66/200
# 2/2 - 1s - loss: 0.0939 - accuracy: 0.9542 - 1s/epoch - 711ms/step
# Epoch 67/200
# 2/2 - 1s - loss: 0.0818 - accuracy: 0.9281 - 1s/epoch - 727ms/step
# Epoch 68/200
# 2/2 - 2s - loss: 0.0922 - accuracy: 0.9216 - 2s/epoch - 969ms/step
# Epoch 69/200
# 2/2 - 1s - loss: 0.0890 - accuracy: 0.9150 - 1s/epoch - 631ms/step
# Epoch 70/200
# 2/2 - 1s - loss: 0.1014 - accuracy: 0.9020 - 825ms/epoch - 413ms/step
# Epoch 71/200
# 2/2 - 1s - loss: 0.0682 - accuracy: 0.9281 - 863ms/epoch - 431ms/step
# Epoch 72/200
# 2/2 - 1s - loss: 0.0760 - accuracy: 0.9542 - 859ms/epoch - 429ms/step
# Epoch 73/200
# 2/2 - 1s - loss: 0.0836 - accuracy: 0.9739 - 876ms/epoch - 438ms/step
# Epoch 74/200
# 2/2 - 1s - loss: 0.0675 - accuracy: 1.0000 - 869ms/epoch - 435ms/step
# Epoch 75/200
# 2/2 - 1s - loss: 0.0634 - accuracy: 0.9804 - 884ms/epoch - 442ms/step
# Epoch 76/200
# 2/2 - 1s - loss: 0.0462 - accuracy: 0.9608 - 852ms/epoch - 426ms/step
# Epoch 77/200
# 2/2 - 1s - loss: 0.0435 - accuracy: 0.9542 - 852ms/epoch - 426ms/step
# Epoch 78/200
# 2/2 - 1s - loss: 0.0445 - accuracy: 0.9346 - 859ms/epoch - 430ms/step
# Epoch 79/200
# 2/2 - 1s - loss: 0.0484 - accuracy: 0.9608 - 875ms/epoch - 438ms/step
# Epoch 80/200
# 2/2 - 1s - loss: 0.0424 - accuracy: 0.9673 - 866ms/epoch - 433ms/step
# Epoch 81/200
# 2/2 - 1s - loss: 0.0383 - accuracy: 0.9542 - 1s/epoch - 694ms/step
# Epoch 82/200
# 2/2 - 1s - loss: 0.0405 - accuracy: 0.9477 - 1s/epoch - 711ms/step
# Epoch 83/200
# 2/2 - 1s - loss: 0.0322 - accuracy: 0.9804 - 1s/epoch - 695ms/step
# Epoch 84/200
# 2/2 - 2s - loss: 0.0326 - accuracy: 0.9412 - 2s/epoch - 756ms/step
# Epoch 85/200
# 2/2 - 1s - loss: 0.0340 - accuracy: 0.9673 - 924ms/epoch - 462ms/step
# Epoch 86/200
# 2/2 - 1s - loss: 0.0286 - accuracy: 0.9935 - 873ms/epoch - 437ms/step
# Epoch 87/200
# 2/2 - 1s - loss: 0.0259 - accuracy: 0.9935 - 849ms/epoch - 425ms/step
# Epoch 88/200
# 2/2 - 1s - loss: 0.0295 - accuracy: 0.9804 - 838ms/epoch - 419ms/step
# Epoch 89/200
# 2/2 - 1s - loss: 0.0326 - accuracy: 0.9804 - 862ms/epoch - 431ms/step
# Epoch 90/200
# 2/2 - 1s - loss: 0.0316 - accuracy: 0.9412 - 853ms/epoch - 427ms/step
# Epoch 91/200
# 2/2 - 1s - loss: 0.0314 - accuracy: 0.9542 - 854ms/epoch - 427ms/step
# Epoch 92/200
# 2/2 - 1s - loss: 0.0269 - accuracy: 0.9869 - 860ms/epoch - 430ms/step
# Epoch 93/200
# 2/2 - 1s - loss: 0.0303 - accuracy: 0.9869 - 846ms/epoch - 423ms/step
# Epoch 94/200
# 2/2 - 1s - loss: 0.0257 - accuracy: 0.9739 - 833ms/epoch - 416ms/step
# Epoch 95/200
# 2/2 - 1s - loss: 0.0326 - accuracy: 0.9281 - 856ms/epoch - 428ms/step
# Epoch 96/200
# 2/2 - 1s - loss: 0.0309 - accuracy: 0.9346 - 1s/epoch - 538ms/step
# Epoch 97/200
# 2/2 - 1s - loss: 0.0243 - accuracy: 0.9608 - 1s/epoch - 727ms/step
# Epoch 98/200
# 2/2 - 1s - loss: 0.0287 - accuracy: 0.9608 - 1s/epoch - 737ms/step
# Epoch 99/200
# 2/2 - 1s - loss: 0.0255 - accuracy: 0.9804 - 1s/epoch - 722ms/step
# Epoch 100/200
# 2/2 - 1s - loss: 0.0237 - accuracy: 0.9608 - 1s/epoch - 576ms/step
# Epoch 101/200
# 2/2 - 1s - loss: 0.0192 - accuracy: 0.9935 - 854ms/epoch - 427ms/step
# Epoch 102/200
# 2/2 - 1s - loss: 0.0264 - accuracy: 0.9804 - 847ms/epoch - 423ms/step
# Epoch 103/200
# 2/2 - 1s - loss: 0.0191 - accuracy: 0.9935 - 847ms/epoch - 424ms/step
# Epoch 104/200
# 2/2 - 1s - loss: 0.0201 - accuracy: 0.9673 - 854ms/epoch - 427ms/step
# Epoch 105/200
# 2/2 - 1s - loss: 0.0204 - accuracy: 0.9673 - 857ms/epoch - 428ms/step
# Epoch 106/200
# 2/2 - 1s - loss: 0.0211 - accuracy: 0.9673 - 850ms/epoch - 425ms/step
# Epoch 107/200
# 2/2 - 1s - loss: 0.0199 - accuracy: 0.9804 - 871ms/epoch - 435ms/step
# Epoch 108/200
# 2/2 - 1s - loss: 0.0192 - accuracy: 0.9869 - 849ms/epoch - 424ms/step
# Epoch 109/200
# 2/2 - 1s - loss: 0.0183 - accuracy: 0.9739 - 835ms/epoch - 418ms/step
# Epoch 110/200
# 2/2 - 1s - loss: 0.0195 - accuracy: 0.9804 - 857ms/epoch - 429ms/step
# Epoch 111/200
# 2/2 - 1s - loss: 0.0177 - accuracy: 0.9804 - 834ms/epoch - 417ms/step
# Epoch 112/200
# 2/2 - 1s - loss: 0.0197 - accuracy: 0.9869 - 1s/epoch - 681ms/step
# Epoch 113/200
# 2/2 - 1s - loss: 0.0199 - accuracy: 0.9804 - 1s/epoch - 706ms/step
# Epoch 114/200
# 2/2 - 1s - loss: 0.0160 - accuracy: 0.9804 - 1s/epoch - 730ms/step
# Epoch 115/200
# 2/2 - 1s - loss: 0.0187 - accuracy: 0.9869 - 1s/epoch - 676ms/step
# Epoch 116/200
# 2/2 - 1s - loss: 0.0157 - accuracy: 0.9869 - 849ms/epoch - 425ms/step
# Epoch 117/200
# 2/2 - 1s - loss: 0.0177 - accuracy: 0.9673 - 818ms/epoch - 409ms/step
# Epoch 118/200
# 2/2 - 1s - loss: 0.0171 - accuracy: 0.9804 - 842ms/epoch - 421ms/step
# Epoch 119/200
# 2/2 - 1s - loss: 0.0170 - accuracy: 0.9869 - 840ms/epoch - 420ms/step
# Epoch 120/200
# 2/2 - 1s - loss: 0.0142 - accuracy: 0.9739 - 854ms/epoch - 427ms/step
# Epoch 121/200
# 2/2 - 1s - loss: 0.0194 - accuracy: 0.9673 - 872ms/epoch - 436ms/step
# Epoch 122/200
# 2/2 - 1s - loss: 0.0147 - accuracy: 0.9739 - 891ms/epoch - 446ms/step
# Epoch 123/200
# 2/2 - 1s - loss: 0.0166 - accuracy: 0.9542 - 850ms/epoch - 425ms/step
# Epoch 124/200
# 2/2 - 1s - loss: 0.0165 - accuracy: 0.9477 - 854ms/epoch - 427ms/step
# Epoch 125/200
# 2/2 - 1s - loss: 0.0188 - accuracy: 0.9673 - 880ms/epoch - 440ms/step
# Epoch 126/200
# 2/2 - 1s - loss: 0.0187 - accuracy: 0.9673 - 850ms/epoch - 425ms/step
# Epoch 127/200
# 2/2 - 1s - loss: 0.0162 - accuracy: 0.9804 - 1s/epoch - 606ms/step
# Epoch 128/200
# 2/2 - 1s - loss: 0.0156 - accuracy: 0.9804 - 1s/epoch - 736ms/step
# Epoch 129/200
# 2/2 - 1s - loss: 0.0167 - accuracy: 0.9608 - 1s/epoch - 716ms/step
# Epoch 130/200
# 2/2 - 1s - loss: 0.0178 - accuracy: 0.9739 - 1s/epoch - 735ms/step
# Epoch 131/200
# 2/2 - 1s - loss: 0.0186 - accuracy: 0.9869 - 923ms/epoch - 462ms/step
# Epoch 132/200
# 2/2 - 1s - loss: 0.0138 - accuracy: 0.9869 - 845ms/epoch - 422ms/step
# Epoch 133/200
# 2/2 - 1s - loss: 0.0160 - accuracy: 0.9673 - 851ms/epoch - 425ms/step
# Epoch 134/200
# 2/2 - 1s - loss: 0.0154 - accuracy: 1.0000 - 839ms/epoch - 419ms/step
# Epoch 135/200
# 2/2 - 1s - loss: 0.0176 - accuracy: 0.9935 - 848ms/epoch - 424ms/step
# Epoch 136/200
# 2/2 - 1s - loss: 0.0155 - accuracy: 0.9869 - 843ms/epoch - 421ms/step
# Epoch 137/200
# 2/2 - 1s - loss: 0.0247 - accuracy: 0.9673 - 860ms/epoch - 430ms/step
# Epoch 138/200
# 2/2 - 1s - loss: 0.0156 - accuracy: 0.9739 - 847ms/epoch - 424ms/step
# Epoch 139/200
# 2/2 - 1s - loss: 0.0180 - accuracy: 0.9935 - 828ms/epoch - 414ms/step
# Epoch 140/200
# 2/2 - 1s - loss: 0.0180 - accuracy: 0.9869 - 845ms/epoch - 423ms/step
# Epoch 141/200
# 2/2 - 1s - loss: 0.0161 - accuracy: 0.9739 - 857ms/epoch - 429ms/step
# Epoch 142/200
# 2/2 - 1s - loss: 0.0166 - accuracy: 0.9804 - 901ms/epoch - 450ms/step
# Epoch 143/200
# 2/2 - 1s - loss: 0.0183 - accuracy: 0.9869 - 1s/epoch - 713ms/step
# Epoch 144/200
# 2/2 - 1s - loss: 0.0154 - accuracy: 0.9739 - 1s/epoch - 734ms/step
# Epoch 145/200
# 2/2 - 1s - loss: 0.0172 - accuracy: 0.9804 - 1s/epoch - 716ms/step
# Epoch 146/200
# 2/2 - 1s - loss: 0.0158 - accuracy: 0.9935 - 1s/epoch - 597ms/step
# Epoch 147/200
# 2/2 - 1s - loss: 0.0128 - accuracy: 0.9869 - 871ms/epoch - 435ms/step
# Epoch 148/200
# 2/2 - 1s - loss: 0.0165 - accuracy: 0.9869 - 857ms/epoch - 428ms/step
# Epoch 149/200
# 2/2 - 1s - loss: 0.0213 - accuracy: 0.9869 - 859ms/epoch - 429ms/step
# Epoch 150/200
# 2/2 - 1s - loss: 0.0165 - accuracy: 0.9804 - 862ms/epoch - 431ms/step
# Epoch 151/200
# 2/2 - 1s - loss: 0.0148 - accuracy: 0.9804 - 830ms/epoch - 415ms/step
# Epoch 152/200
# 2/2 - 1s - loss: 0.0196 - accuracy: 0.9739 - 849ms/epoch - 425ms/step
# Epoch 153/200
# 2/2 - 1s - loss: 0.0162 - accuracy: 0.9935 - 856ms/epoch - 428ms/step
# Epoch 154/200
# 2/2 - 1s - loss: 0.0232 - accuracy: 0.9804 - 843ms/epoch - 421ms/step
# Epoch 155/200
# 2/2 - 1s - loss: 0.0155 - accuracy: 0.9673 - 866ms/epoch - 433ms/step
# Epoch 156/200
# 2/2 - 1s - loss: 0.0224 - accuracy: 0.9739 - 836ms/epoch - 418ms/step
# Epoch 157/200
# 2/2 - 1s - loss: 0.0147 - accuracy: 0.9804 - 855ms/epoch - 427ms/step
# Epoch 158/200
# 2/2 - 1s - loss: 0.0168 - accuracy: 0.9739 - 1s/epoch - 649ms/step
# Epoch 159/200
# 2/2 - 1s - loss: 0.0179 - accuracy: 0.9804 - 1s/epoch - 739ms/step
# Epoch 160/200
# 2/2 - 1s - loss: 0.0166 - accuracy: 0.9804 - 1s/epoch - 682ms/step
# Epoch 161/200
# 2/2 - 2s - loss: 0.0182 - accuracy: 0.9804 - 2s/epoch - 768ms/step
# Epoch 162/200
# 2/2 - 1s - loss: 0.0158 - accuracy: 0.9935 - 866ms/epoch - 433ms/step
# Epoch 163/200
# 2/2 - 1s - loss: 0.0160 - accuracy: 0.9804 - 846ms/epoch - 423ms/step
# Epoch 164/200
# 2/2 - 1s - loss: 0.0126 - accuracy: 0.9869 - 855ms/epoch - 428ms/step
# Epoch 165/200
# 2/2 - 1s - loss: 0.0160 - accuracy: 0.9935 - 855ms/epoch - 428ms/step
# Epoch 166/200
# 2/2 - 1s - loss: 0.0186 - accuracy: 1.0000 - 850ms/epoch - 425ms/step
# Epoch 167/200
# 2/2 - 1s - loss: 0.0180 - accuracy: 1.0000 - 840ms/epoch - 420ms/step
# Epoch 168/200
# 2/2 - 1s - loss: 0.0163 - accuracy: 0.9739 - 825ms/epoch - 413ms/step
# Epoch 169/200
# 2/2 - 1s - loss: 0.0171 - accuracy: 1.0000 - 858ms/epoch - 429ms/step
# Epoch 170/200
# 2/2 - 1s - loss: 0.0207 - accuracy: 0.9739 - 859ms/epoch - 430ms/step
# Epoch 171/200
# 2/2 - 1s - loss: 0.0162 - accuracy: 0.9869 - 860ms/epoch - 430ms/step
# Epoch 172/200
# 2/2 - 1s - loss: 0.0178 - accuracy: 0.9935 - 866ms/epoch - 433ms/step
# Epoch 173/200
# 2/2 - 1s - loss: 0.0144 - accuracy: 1.0000 - 950ms/epoch - 475ms/step
# Epoch 174/200
# 2/2 - 2s - loss: 0.0193 - accuracy: 0.9935 - 2s/epoch - 994ms/step
# Epoch 175/200
# 2/2 - 1s - loss: 0.0133 - accuracy: 0.9739 - 1s/epoch - 700ms/step
# Epoch 176/200
# 2/2 - 2s - loss: 0.0144 - accuracy: 0.9608 - 2s/epoch - 755ms/step
# Epoch 177/200
# 2/2 - 1s - loss: 0.0134 - accuracy: 0.9739 - 886ms/epoch - 443ms/step
# Epoch 178/200
# 2/2 - 1s - loss: 0.0155 - accuracy: 0.9804 - 853ms/epoch - 426ms/step
# Epoch 179/200
# 2/2 - 1s - loss: 0.0149 - accuracy: 0.9869 - 848ms/epoch - 424ms/step
# Epoch 180/200
# 2/2 - 1s - loss: 0.0146 - accuracy: 0.9935 - 851ms/epoch - 425ms/step
# Epoch 181/200
# 2/2 - 1s - loss: 0.0168 - accuracy: 0.9804 - 844ms/epoch - 422ms/step
# Epoch 182/200
# 2/2 - 1s - loss: 0.0136 - accuracy: 0.9739 - 862ms/epoch - 431ms/step
# Epoch 183/200
# 2/2 - 1s - loss: 0.0151 - accuracy: 0.9935 - 850ms/epoch - 425ms/step
# Epoch 184/200
# 2/2 - 1s - loss: 0.0158 - accuracy: 1.0000 - 865ms/epoch - 432ms/step
# Epoch 185/200
# 2/2 - 1s - loss: 0.0161 - accuracy: 0.9869 - 892ms/epoch - 446ms/step
# Epoch 186/200
# 2/2 - 1s - loss: 0.0141 - accuracy: 0.9935 - 830ms/epoch - 415ms/step
# Epoch 187/200
# 2/2 - 1s - loss: 0.0161 - accuracy: 0.9869 - 846ms/epoch - 423ms/step
# Epoch 188/200
# 2/2 - 1s - loss: 0.0184 - accuracy: 0.9935 - 997ms/epoch - 498ms/step
# Epoch 189/200
# 2/2 - 1s - loss: 0.0144 - accuracy: 0.9935 - 1s/epoch - 712ms/step
# Epoch 190/200
# 2/2 - 1s - loss: 0.0153 - accuracy: 0.9935 - 1s/epoch - 720ms/step
# Epoch 191/200
# 2/2 - 1s - loss: 0.0142 - accuracy: 0.9608 - 1s/epoch - 742ms/step
# Epoch 192/200
# 2/2 - 1s - loss: 0.0186 - accuracy: 0.9739 - 1s/epoch - 550ms/step
# Epoch 193/200
# 2/2 - 1s - loss: 0.0138 - accuracy: 0.9608 - 847ms/epoch - 424ms/step
# Epoch 194/200
# 2/2 - 1s - loss: 0.0166 - accuracy: 0.9804 - 851ms/epoch - 425ms/step
# Epoch 195/200
# 2/2 - 1s - loss: 0.0140 - accuracy: 0.9869 - 844ms/epoch - 422ms/step
# Epoch 196/200
# 2/2 - 1s - loss: 0.0128 - accuracy: 0.9869 - 855ms/epoch - 427ms/step
# Epoch 197/200
# 2/2 - 1s - loss: 0.0137 - accuracy: 0.9869 - 832ms/epoch - 416ms/step
# Epoch 198/200
# 2/2 - 1s - loss: 0.0155 - accuracy: 0.9935 - 858ms/epoch - 429ms/step
# Epoch 199/200
# 2/2 - 1s - loss: 0.0116 - accuracy: 0.9869 - 853ms/epoch - 427ms/step
# Epoch 200/200
# 2/2 - 1s - loss: 0.0162 - accuracy: 0.9869 - 843ms/epoch - 422ms/step

# %% [markdown]
# ### Prediction without rounding up or down the results

# %%
df1.rename(columns={'date': 'Date'},inplace=True)

# %%
print('-' * 40)
print('Prediction vs. GoundTruth without rounding up or down')
for i in range(1,10):
  test = df1.copy()
  test = test.tail((window_length+10-i))
  test = test.head((window_length+1))
  test_Date = df1.iloc[ (test.tail().index[-1]) ]['Date']
  test1 = test.head((window_length))
  test1.drop(['Date'], axis=1, inplace=True)
  test1 = np.array(test1)
  x_test = scaler.transform(test1)
  y_test_pred = model.predict(np.array([x_test]))
  y_test_true = test.drop(['Date'], axis=1, inplace=True)
  y_test_true = test.tail(1)
  print('Drawing  Date', test_Date)
  print('Prediction:\t', scaler.inverse_transform(y_test_pred).astype(int)[0])
  print('GoundTruth:\t', np.array(y_test_true)[0])
  print('-' * 40)
# Out:
# ----------------------------------------
# Prediction vs. GoundTruth without rounding up or down
# 1/1 [==============================] - 4s 4s/step
# Drawing  Date 2023-05-29 00:00:00
# Prediction:	 [69 31]
# GoundTruth:	 [68 35]
# ----------------------------------------
# 1/1 [==============================] - 0s 39ms/step
# Drawing  Date 2023-05-26 00:00:00
# Prediction:	 [45 67]
# GoundTruth:	 [46 67]
# ----------------------------------------
# 1/1 [==============================] - 0s 40ms/step
# Drawing  Date 2023-05-24 00:00:00
# Prediction:	 [25 70]
# GoundTruth:	 [25 72]
# ----------------------------------------
# 1/1 [==============================] - 0s 45ms/step
# Drawing  Date 2023-05-22 00:00:00
# Prediction:	 [53 88]
# GoundTruth:	 [54 87]
# ----------------------------------------
# 1/1 [==============================] - 0s 40ms/step
# Drawing  Date 2023-05-19 00:00:00
# Prediction:	 [86 71]
# GoundTruth:	 [85 73]
# ----------------------------------------
# 1/1 [==============================] - 0s 36ms/step
# Drawing  Date 2023-05-17 00:00:00
# Prediction:	 [98 41]
# GoundTruth:	 [98 46]
# ----------------------------------------
# 1/1 [==============================] - 0s 38ms/step
# Drawing  Date 2023-05-15 00:00:00
# Prediction:	 [87 47]
# GoundTruth:	 [86 49]
# ----------------------------------------
# 1/1 [==============================] - 0s 40ms/step
# Drawing  Date 2023-05-12 00:00:00
# Prediction:	 [41 76]
# GoundTruth:	 [40 77]
# ----------------------------------------
# 1/1 [==============================] - 0s 41ms/step
# Drawing  Date 2023-05-10 00:00:00
# Prediction:	 [86 20]
# GoundTruth:	 [85 21]
# ----------------------------------------

# %% [markdown]
# ### Predict the Future Drawing Results on June 1, 2o24

# %%
next_Date = '2024-05-31'
print('-' * 40)
print('Predict the Future Drawing on',next_Date)

# Copy and prepare the data for prediction
next = df.copy()
next = next.tail(window_length)
next = np.array(next)
x_next = scaler.transform(next)

# Predict the next values
y_next_pred = model.predict(np.array([x_next]))

# Filter the actual values based on the next date
filtered_df = lt_2[lt_2['date'] == next_Date]

# Extract the actual values and convert them to a list
actual_values = filtered_df[['เลขล่าง','เลขบน']].values.flatten().tolist()

# Calculate the absolute difference
prediction = scaler.inverse_transform(y_next_pred).astype(int)[0].tolist()
diff = [abs(pred - actual) for pred, actual in zip(prediction, actual_values)]

# Print the results
print('Drawing  Date', next_Date)
print('Prediction:\t', prediction)
print('GoundTruth:\t', actual_values)
print('Diff:   \t', diff)
print('-' * 40)
# Out:
# ----------------------------------------
# Predict the Future Drawing on 2024-05-31
# 1/1 [==============================] - 0s 38ms/step
# Drawing  Date 2024-05-31
# Prediction:	 [67, 19]
# GoundTruth:	 [33, 3]
# Diff:   	 [34, 16]
# ----------------------------------------
