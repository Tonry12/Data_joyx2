# %% [markdown]
# <a href="https://colab.research.google.com/github/Tonry12/Data_joyx2/blob/main/Laos_lotto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
lotto = pd.read_csv('/content/drive/MyDrive/SPN/Laos_Lotto.csv')

# %%
lotto_ai = pd.read_csv('/content/drive/MyDrive/SPN/Laos_Lotto_pre.csv')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy
import os
import pickle
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
lotto
# Out:
#           date  เลข 4 ตัว  เลข 3 ตัว  เลข 2 ตัว  weekday_dum    weekday
# 0     5/3/2024       7999        999         99            6     Friday
# 1    4/29/2024       4351        351         51            2     Monday
# 2    4/26/2024       8721        721         21            6     Friday
# 3    4/24/2024       2552        552         52            4  Wednesday
# 4    4/22/2024       9490        490         90            2     Monday
# ..         ...        ...        ...        ...          ...        ...
# 144  5/19/2023       8573        573         73            6     Friday
# 145  5/17/2023       9846        846         46            4  Wednesday
# 146  5/15/2023       8649        649         49            2     Monday
# 147  5/12/2023       4077         77         77            6     Friday
# 148  5/10/2023       8521        521         21            4  Wednesday
#
# [149 rows x 6 columns]

# %%
lotto.isnull().any()
# Out:
# date           False
# เลข 4 ตัว      False
# เลข 3 ตัว      False
# เลข 2 ตัว      False
# weekday_dum    False
# weekday        False
# dtype: bool

# %%
lotto.rename(columns={'เลข 4 ตัว': 'top4','เลข 3 ตัว':'top3','เลข 2 ตัว':'top2'},inplace=True)

# %%
lt = lotto.drop(columns=['weekday_dum'])

# %%
lt['date'] = pd.to_datetime(lt['date'])

# %%
lt.dtypes
# Out:
# date       datetime64[ns]
# top4                int64
# top3                int64
# top2                int64
# weekday            object
# dtype: object

# %%
lt['top4'] = lt['top4'].apply(lambda x: '{:04}'.format(x))

# %%
lt
# Out:
#           date  top4  top3  top2    weekday
# 0   2024-05-03  7999   999    99     Friday
# 1   2024-04-29  4351   351    51     Monday
# 2   2024-04-26  8721   721    21     Friday
# 3   2024-04-24  2552   552    52  Wednesday
# 4   2024-04-22  9490   490    90     Monday
# ..         ...   ...   ...   ...        ...
# 144 2023-05-19  8573   573    73     Friday
# 145 2023-05-17  9846   846    46  Wednesday
# 146 2023-05-15  8649   649    49     Monday
# 147 2023-05-12  4077    77    77     Friday
# 148 2023-05-10  8521   521    21  Wednesday
#
# [149 rows x 5 columns]

# %%
lt_1 = lt

# %%
lt_1['top4'] = lt_1['top4'].astype(str)

# Split each value in the 'digi' column into its individual digits
lt_1['r1'] = lt_1['top4'].apply(lambda x: int(x[0]))
lt_1['r2'] = lt_1['top4'].apply(lambda x: int(x[1]))
lt_1['r3'] = lt_1['top4'].apply(lambda x: int(x[2]))
lt_1['r4'] = lt_1['top4'].apply(lambda x: int(x[3]))

# %%
lt_1= lt_1.drop(columns=['top3','top2'])

# %%
lt_1
# Out:
#           date  top4    weekday  r1  r2  r3  r4
# 0   2024-05-03  7999     Friday   7   9   9   9
# 1   2024-04-29  4351     Monday   4   3   5   1
# 2   2024-04-26  8721     Friday   8   7   2   1
# 3   2024-04-24  2552  Wednesday   2   5   5   2
# 4   2024-04-22  9490     Monday   9   4   9   0
# ..         ...   ...        ...  ..  ..  ..  ..
# 144 2023-05-19  8573     Friday   8   5   7   3
# 145 2023-05-17  9846  Wednesday   9   8   4   6
# 146 2023-05-15  8649     Monday   8   6   4   9
# 147 2023-05-12  4077     Friday   4   0   7   7
# 148 2023-05-10  8521  Wednesday   8   5   2   1
#
# [149 rows x 7 columns]

# %% [markdown]
# # วันจันทร์

# %% [markdown]
# ## เลขท้าย 4 ตัว

# %%
monday = lt_1[lt_1['weekday'] == "Monday"]

# %%
monday.head()
# Out:
#          date  top4 weekday  r1  r2  r3  r4
# 1  2024-04-29  4351  Monday   4   3   5   1
# 4  2024-04-22  9490  Monday   9   4   9   0
# 8  2024-04-08  9545  Monday   9   5   4   5
# 11 2024-04-01  1596  Monday   1   5   9   6
# 16 2024-03-18  8302  Monday   8   3   0   2

# %%
# เลขท้ายสี่ตัวหลักที่ 1 ที่ออกบ่อยสุด
grouped_counts = monday.groupby('r1').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#    r1  Count
# 9   9     10

# %%
# เลขท้ายสี่ตัวหลักที่ 2 ที่ออกบ่อยสุด
grouped_counts = monday.groupby('r2').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#    r2  Count
# 8   8      9

# %%
# เลขท้ายสี่ตัวหลักที่ 3 ที่ออกบ่อยสุด
grouped_counts = monday.groupby('r3').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#    r3  Count
# 2   2      8
# 9   9      8

# %%
# เลขท้ายสี่ตัวหลักที่ 4 ที่ออกบ่อยสุด
grouped_counts = monday.groupby('r4').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#    r4  Count
# 5   5      8

# %% [markdown]
# ### สรุป เลขท้าย 4 ตัวที่ออกบ่อยที่สุดคือ 9825 หรือ 9895

# %% [markdown]
# # งวดวันพุธ

# %%
wed = lt_1[lt_1['weekday'] == "Wednesday"]

# %%
wed
# Out:
#           date  top4    weekday  r1  r2  r3  r4
# 3   2024-04-24  2552  Wednesday   2   5   5   2
# 7   2024-04-10  4389  Wednesday   4   3   8   9
# 10  2024-04-03  1959  Wednesday   1   9   5   9
# 13  2024-03-27  0911  Wednesday   0   9   1   1
# 15  2024-03-20  7706  Wednesday   7   7   0   6
# 18  2024-03-13  1857  Wednesday   1   8   5   7
# 20  2024-03-06  6478  Wednesday   6   4   7   8
# 23  2024-02-28  6118  Wednesday   6   1   1   8
# 26  2024-02-21  3890  Wednesday   3   8   9   0
# 29  2024-02-14  7243  Wednesday   7   2   4   3
# 32  2024-02-07  8368  Wednesday   8   3   6   8
# 35  2024-01-31  8932  Wednesday   8   9   3   2
# 38  2024-01-24  7380  Wednesday   7   3   8   0
# 41  2024-01-17  1226  Wednesday   1   2   2   6
# 44  2024-01-10  8391  Wednesday   8   3   9   1
# 47  2024-01-03  3873  Wednesday   3   8   7   3
# 49  2023-12-27  8785  Wednesday   8   7   8   5
# 52  2023-12-20  9922  Wednesday   9   9   2   2
# 55  2023-12-13  2232  Wednesday   2   2   3   2
# 58  2023-12-06  4186  Wednesday   4   1   8   6
# 61  2023-11-29  5288  Wednesday   5   2   8   8
# 64  2023-11-22  4264  Wednesday   4   2   6   4
# 67  2023-11-15  5514  Wednesday   5   5   1   4
# 70  2023-11-08  7939  Wednesday   7   9   3   9
# 73  2023-11-01  5402  Wednesday   5   4   0   2
# 76  2023-10-25  0480  Wednesday   0   4   8   0
# 79  2023-10-18  6273  Wednesday   6   2   7   3
# 82  2023-10-11  9264  Wednesday   9   2   6   4
# 85  2023-10-04  9629  Wednesday   9   6   2   9
# 88  2023-09-27  0210  Wednesday   0   2   1   0
# 91  2023-09-20  7372  Wednesday   7   3   7   2
# 94  2023-09-13  8831  Wednesday   8   8   3   1
# 97  2023-09-06  1717  Wednesday   1   7   1   7
# 100 2023-08-30  2529  Wednesday   2   5   2   9
# 103 2023-08-23  3061  Wednesday   3   0   6   1
# 106 2023-08-16  1697  Wednesday   1   6   9   7
# 109 2023-08-09  3116  Wednesday   3   1   1   6
# 112 2023-08-02  7809  Wednesday   7   8   0   9
# 115 2023-07-26  1350  Wednesday   1   3   5   0
# 118 2023-07-19  5878  Wednesday   5   8   7   8
# 121 2023-07-12  1034  Wednesday   1   0   3   4
# 124 2023-07-05  0908  Wednesday   0   9   0   8
# 127 2023-06-28  2229  Wednesday   2   2   2   9
# 130 2023-06-21  7341  Wednesday   7   3   4   1
# 133 2023-06-14  2952  Wednesday   2   9   5   2
# 136 2023-06-07  0318  Wednesday   0   3   1   8
# 139 2023-05-31  7922  Wednesday   7   9   2   2
# 142 2023-05-24  2572  Wednesday   2   5   7   2
# 145 2023-05-17  9846  Wednesday   9   8   4   6
# 148 2023-05-10  8521  Wednesday   8   5   2   1

# %%
# เลขท้ายสี่ตัวหลักที่ 1 ที่ออกบ่อยสุด
grouped_counts = wed.groupby('r1').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#    r1  Count
# 7   7      8

# %%
# เลขท้ายสี่ตัวหลักที่ 2 ที่ออกบ่อยสุด
grouped_counts = wed.groupby('r2').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#    r2  Count
# 2   2      9

# %%
# เลขท้ายสี่ตัวหลักที่ 3 ที่ออกบ่อยสุด
grouped_counts = wed.groupby('r3').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#    r3  Count
# 1   1      7
# 2   2      7

# %%
# เลขท้ายสี่ตัวหลักที่ 4 ที่ออกบ่อยสุด
grouped_counts = wed.groupby('r4').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#    r4  Count
# 2   2      9

# %% [markdown]
# ### สรุป เลขท้าย 4 ตัวที่ออกบ่อยที่สุดคือ 7212 หรือ 7222

# %%
wed_1 = lt[lt['weekday'] == "Wednesday"]

# %%
wed_1
# Out:
#           date  top4  top3  top2    weekday  r1  r2  r3  r4
# 3   2024-04-24  2552   552    52  Wednesday   2   5   5   2
# 7   2024-04-10  4389   389    89  Wednesday   4   3   8   9
# 10  2024-04-03  1959   959    59  Wednesday   1   9   5   9
# 13  2024-03-27  0911   911    11  Wednesday   0   9   1   1
# 15  2024-03-20  7706   706     6  Wednesday   7   7   0   6
# 18  2024-03-13  1857   857    57  Wednesday   1   8   5   7
# 20  2024-03-06  6478   478    78  Wednesday   6   4   7   8
# 23  2024-02-28  6118   118    18  Wednesday   6   1   1   8
# 26  2024-02-21  3890   890    90  Wednesday   3   8   9   0
# 29  2024-02-14  7243   243    43  Wednesday   7   2   4   3
# 32  2024-02-07  8368   368    68  Wednesday   8   3   6   8
# 35  2024-01-31  8932   932    32  Wednesday   8   9   3   2
# 38  2024-01-24  7380   380    80  Wednesday   7   3   8   0
# 41  2024-01-17  1226   226    26  Wednesday   1   2   2   6
# 44  2024-01-10  8391   391    91  Wednesday   8   3   9   1
# 47  2024-01-03  3873   873    73  Wednesday   3   8   7   3
# 49  2023-12-27  8785   785    85  Wednesday   8   7   8   5
# 52  2023-12-20  9922   922    22  Wednesday   9   9   2   2
# 55  2023-12-13  2232   232    32  Wednesday   2   2   3   2
# 58  2023-12-06  4186   186    86  Wednesday   4   1   8   6
# 61  2023-11-29  5288   288    88  Wednesday   5   2   8   8
# 64  2023-11-22  4264   264    64  Wednesday   4   2   6   4
# 67  2023-11-15  5514   514    14  Wednesday   5   5   1   4
# 70  2023-11-08  7939   939    39  Wednesday   7   9   3   9
# 73  2023-11-01  5402   402     2  Wednesday   5   4   0   2
# 76  2023-10-25  0480   480    80  Wednesday   0   4   8   0
# 79  2023-10-18  6273   273    73  Wednesday   6   2   7   3
# 82  2023-10-11  9264   264    64  Wednesday   9   2   6   4
# 85  2023-10-04  9629   629    29  Wednesday   9   6   2   9
# 88  2023-09-27  0210   210    10  Wednesday   0   2   1   0
# 91  2023-09-20  7372   372    72  Wednesday   7   3   7   2
# 94  2023-09-13  8831   831    31  Wednesday   8   8   3   1
# 97  2023-09-06  1717   717    17  Wednesday   1   7   1   7
# 100 2023-08-30  2529   529    29  Wednesday   2   5   2   9
# 103 2023-08-23  3061    61    61  Wednesday   3   0   6   1
# 106 2023-08-16  1697   697    97  Wednesday   1   6   9   7
# 109 2023-08-09  3116   116    16  Wednesday   3   1   1   6
# 112 2023-08-02  7809   809     9  Wednesday   7   8   0   9
# 115 2023-07-26  1350   350    50  Wednesday   1   3   5   0
# 118 2023-07-19  5878   878    78  Wednesday   5   8   7   8
# 121 2023-07-12  1034    34    34  Wednesday   1   0   3   4
# 124 2023-07-05  0908   908     8  Wednesday   0   9   0   8
# 127 2023-06-28  2229   229    29  Wednesday   2   2   2   9
# 130 2023-06-21  7341   341    41  Wednesday   7   3   4   1
# 133 2023-06-14  2952   952    52  Wednesday   2   9   5   2
# 136 2023-06-07  0318   318    18  Wednesday   0   3   1   8
# 139 2023-05-31  7922   922    22  Wednesday   7   9   2   2
# 142 2023-05-24  2572   572    72  Wednesday   2   5   7   2
# 145 2023-05-17  9846   846    46  Wednesday   9   8   4   6
# 148 2023-05-10  8521   521    21  Wednesday   8   5   2   1

# %%
grouped_counts
# Out:
#    r4  Count
# 0   0      5
# 1   1      6
# 2   2      9
# 3   3      3
# 4   4      4
# 5   5      1
# 6   6      5
# 7   7      3
# 8   8      7
# 9   9      7

# %%
# เลขท้าย2ตัวที่ออกบ่อยสุด
grouped_counts = wed_1.groupby('top2').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#     top2  Count
# 13    29      3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy
import os
import pickle

# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
lotto_ai
# Out:
#           date  เลข 4 ตัว  เลข 3 ตัว  เลข 2 ตัว  เลขล่าง  เลขบน  weekday_dum  \
# 0     6/5/2024       1493        493         93       14     93          NaN
# 1     6/3/2024       1399        399         99       13     99          NaN
# 2    5/31/2024       3303        303          3       33      3          NaN
# 3    5/29/2024       5419        419         19       54     19          NaN
# 4    5/27/2024       9853        853         53       98     53          NaN
# ..         ...        ...        ...        ...      ...    ...          ...
# 158  5/19/2023       8573        573         73       85     73          6.0
# 159  5/17/2023       9846        846         46       98     46          4.0
# 160  5/15/2023       8649        649         49       86     49          2.0
# 161  5/12/2023       4077         77         77       40     77          6.0
# 162  5/10/2023       8521        521         21       85     21          4.0
#
#        weekday
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 158     Friday
# 159  Wednesday
# 160     Monday
# 161     Friday
# 162  Wednesday
#
# [163 rows x 8 columns]

# %%
lotto_ai['date'] = pd.to_datetime(lotto_ai['date'])

# %%
lotto_ai
# Out:
#           date  เลข 4 ตัว  เลข 3 ตัว  เลข 2 ตัว  เลขล่าง  เลขบน  weekday_dum  \
# 0   2024-06-05       1493        493         93       14     93          NaN
# 1   2024-06-03       1399        399         99       13     99          NaN
# 2   2024-05-31       3303        303          3       33      3          NaN
# 3   2024-05-29       5419        419         19       54     19          NaN
# 4   2024-05-27       9853        853         53       98     53          NaN
# ..         ...        ...        ...        ...      ...    ...          ...
# 158 2023-05-19       8573        573         73       85     73          6.0
# 159 2023-05-17       9846        846         46       98     46          4.0
# 160 2023-05-15       8649        649         49       86     49          2.0
# 161 2023-05-12       4077         77         77       40     77          6.0
# 162 2023-05-10       8521        521         21       85     21          4.0
#
#        weekday
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 158     Friday
# 159  Wednesday
# 160     Monday
# 161     Friday
# 162  Wednesday
#
# [163 rows x 8 columns]

# %%
lt_2 = lotto_ai.copy()

# %%
lt_2
# Out:
#           date  เลข 4 ตัว  เลข 3 ตัว  เลข 2 ตัว  เลขล่าง  เลขบน  weekday_dum  \
# 0   2024-06-05       1493        493         93       14     93          NaN
# 1   2024-06-03       1399        399         99       13     99          NaN
# 2   2024-05-31       3303        303          3       33      3          NaN
# 3   2024-05-29       5419        419         19       54     19          NaN
# 4   2024-05-27       9853        853         53       98     53          NaN
# ..         ...        ...        ...        ...      ...    ...          ...
# 158 2023-05-19       8573        573         73       85     73          6.0
# 159 2023-05-17       9846        846         46       98     46          4.0
# 160 2023-05-15       8649        649         49       86     49          2.0
# 161 2023-05-12       4077         77         77       40     77          6.0
# 162 2023-05-10       8521        521         21       85     21          4.0
#
#        weekday
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 158     Friday
# 159  Wednesday
# 160     Monday
# 161     Friday
# 162  Wednesday
#
# [163 rows x 8 columns]

# %%
sh = lt_2.shape

# %%
z = 0

# %%
lt_3 = lt_2.iloc[z:sh[0], 0:sh[1]]

# %%
lt_3
# Out:
#           date  เลข 4 ตัว  เลข 3 ตัว  เลข 2 ตัว  เลขล่าง  เลขบน  weekday_dum  \
# 0   2024-06-05       1493        493         93       14     93          NaN
# 1   2024-06-03       1399        399         99       13     99          NaN
# 2   2024-05-31       3303        303          3       33      3          NaN
# 3   2024-05-29       5419        419         19       54     19          NaN
# 4   2024-05-27       9853        853         53       98     53          NaN
# ..         ...        ...        ...        ...      ...    ...          ...
# 158 2023-05-19       8573        573         73       85     73          6.0
# 159 2023-05-17       9846        846         46       98     46          4.0
# 160 2023-05-15       8649        649         49       86     49          2.0
# 161 2023-05-12       4077         77         77       40     77          6.0
# 162 2023-05-10       8521        521         21       85     21          4.0
#
#        weekday
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 158     Friday
# 159  Wednesday
# 160     Monday
# 161     Friday
# 162  Wednesday
#
# [163 rows x 8 columns]

# %% [markdown]
# # LSTM

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
dfp = lt_3.copy()

# %%
df = dfp.reset_index()

# %%
df
# Out:
#      index       date  เลข 4 ตัว  เลข 3 ตัว  เลข 2 ตัว  เลขล่าง  เลขบน  \
# 0        0 2024-06-05       1493        493         93       14     93
# 1        1 2024-06-03       1399        399         99       13     99
# 2        2 2024-05-31       3303        303          3       33      3
# 3        3 2024-05-29       5419        419         19       54     19
# 4        4 2024-05-27       9853        853         53       98     53
# ..     ...        ...        ...        ...        ...      ...    ...
# 158    158 2023-05-19       8573        573         73       85     73
# 159    159 2023-05-17       9846        846         46       98     46
# 160    160 2023-05-15       8649        649         49       86     49
# 161    161 2023-05-12       4077         77         77       40     77
# 162    162 2023-05-10       8521        521         21       85     21
#
#      weekday_dum    weekday
# 0            NaN        NaN
# 1            NaN        NaN
# 2            NaN        NaN
# 3            NaN        NaN
# 4            NaN        NaN
# ..           ...        ...
# 158          6.0     Friday
# 159          4.0  Wednesday
# 160          2.0     Monday
# 161          6.0     Friday
# 162          4.0  Wednesday
#
# [163 rows x 9 columns]

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
df2 = df.copy()

# %%
df1 = df.copy()
df.drop(['index','date','เลข 4 ตัว','เลข 3 ตัว','เลข 2 ตัว','weekday_dum','weekday'], axis=1, inplace=True)

number_of_features = df.shape[1]

# %%
df
# Out:
#      เลขล่าง  เลขบน
# 0         14     93
# 1         13     99
# 2         33      3
# 3         54     19
# 4         98     53
# ..       ...    ...
# 158       85     73
# 159       98     46
# 160       86     49
# 161       40     77
# 162       85     21
#
# [163 rows x 2 columns]

# %%
df1.drop(['index','เลข 4 ตัว','เลข 3 ตัว','เลข 2 ตัว','weekday_dum','weekday'], axis=1, inplace=True)

# %%
df1
# Out:
#           date  เลขล่าง  เลขบน
# 0   2024-06-05       14     93
# 1   2024-06-03       13     99
# 2   2024-05-31       33      3
# 3   2024-05-29       54     19
# 4   2024-05-27       98     53
# ..         ...      ...    ...
# 158 2023-05-19       85     73
# 159 2023-05-17       98     46
# 160 2023-05-15       86     49
# 161 2023-05-12       40     77
# 162 2023-05-10       85     21
#
# [163 rows x 3 columns]

# %%
window_length = 7
window_length
# Out:
# 7

# %%
train = df.copy()
train.head((window_length+1))
# Out:
#    เลขล่าง  เลขบน
# 0       14     93
# 1       13     99
# 2       33      3
# 3       54     19
# 4       98     53
# 5       90     57
# 6       37     10
# 7        1     47

# %%
train_rows = train.values.shape[0]
train_samples = np.empty([ train_rows - window_length, window_length, number_of_features], dtype=float)
train_labels = np.empty([ train_rows - window_length, number_of_features], dtype=float)
for i in range(0, train_rows-window_length):
    train_samples[i] = train.iloc[i : i+window_length, 0 : number_of_features]
    train_labels[i] = train.iloc[i+window_length : i+window_length+1, 0 : number_of_features]

# %%
train.values.shape[0]
# Out:
# 163

# %%
train_samples[0]
# Out:
# array([[14., 93.],
#        [13., 99.],
#        [33.,  3.],
#        [54., 19.],
#        [98., 53.],
#        [90., 57.],
#        [37., 10.]])

# %%
train_labels[0]
# Out:
# array([ 1., 47.])

# %%
scaler = StandardScaler()
transformed_dataset = scaler.fit_transform(train.values)
scaled_train_samples = pd.DataFrame(data=transformed_dataset, index=train.index)

# %%
scaled_train_samples.head(window_length+1)
# Out:
#           0         1
# 0 -1.321845  1.486244
# 1 -1.355622  1.684708
# 2 -0.680090 -1.490709
# 3  0.029218 -0.961473
# 4  1.515387  0.163154
# 5  1.245175  0.295463
# 6 -0.544984 -1.259168
# 7 -1.760941 -0.035309

# %%
x_train = np.empty([ train_rows - window_length, window_length, number_of_features], dtype=float)
y_train = np.empty([ train_rows - window_length, number_of_features], dtype=float)

for i in range(0, train_rows-window_length):
    x_train[i] = scaled_train_samples.iloc[i : i+window_length, 0 : number_of_features]
    y_train[i] = scaled_train_samples.iloc[i+window_length : i+window_length+1, 0 : number_of_features]

# %%
y_train
# Out:
# array([[-1.7609408 , -0.03530946],
#        [ 1.14384481, -1.02762707],
#        [ 1.54916374, -1.52378587],
#        [-0.61253719,  1.65163047],
#        [-1.42317503,  0.22930857],
#        [ 0.4345367 , -0.96147256],
#        [-1.38939846,  0.69239012],
#        [ 0.8736322 ,  1.68470772],
#        [-0.34232457,  0.09699955],
#        [ 1.14384481, -0.89531805],
#        [-0.95030296,  0.13007681],
#        [ 1.38028085,  1.38701244],
#        [-0.37610115,  0.75854462],
#        [ 1.38028085, -0.53146826],
#        [-0.34232457,  1.35393519],
#        [ 1.41405743, -0.10146397],
#        [ 0.50208985, -1.45763136],
#        [-1.15296242,  0.36161758],
#        [-1.28806872,  1.58547596],
#        [-0.98407953, -0.92839531],
#        [-1.49072819, -1.22609059],
#        [-0.84897322,  0.32854033],
#        [ 0.80607904, -1.39147685],
#        [ 1.00873851, -1.52378587],
#        [ 0.02921778,  1.32085793],
#        [-1.18673899,  0.29546307],
#        [-0.17344169,  0.26238582],
#        [ 0.36698354,  0.9900854 ],
#        [ 0.19810066, -1.09378157],
#        [ 0.46831327, -0.69685453],
#        [ 0.26565381, -0.99454981],
#        [ 1.07629166,  1.58547596],
#        [-0.54498403,  0.79162188],
#        [-0.51120746,  1.38701244],
#        [ 1.54916374, -0.33300474],
#        [ 1.34650427,  1.38701244],
#        [ 0.63719616, -0.16761847],
#        [ 0.63719616, -1.09378157],
#        [ 0.97496193,  0.09699955],
#        [ 1.00873851,  0.65931286],
#        [-1.05163269,  0.4939266 ],
#        [-0.30854799, -1.15993608],
#        [ 1.21139797, -0.53146826],
#        [ 1.04251508,  1.68470772],
#        [-1.25429215, -0.8622408 ],
#        [ 0.67097274,  1.0562399 ],
#        [-0.78142007,  1.68470772],
#        [ 1.41405743, -0.66377728],
#        [-1.38939846, -0.72993178],
#        [-1.22051557, -0.79608629],
#        [-1.22051557, -0.79608629],
#        [ 1.00873851,  1.42008969],
#        [-0.30854799,  0.89085364],
#        [-0.57876061,  0.89085364],
#        [-0.51120746,  0.82469913],
#        [ 0.56964301,  1.55239871],
#        [ 1.14384481,  1.22162617],
#        [ 0.13054751,  0.62623561],
#        [-0.34232457,  0.19623131],
#        [ 1.54916374, -0.8622408 ],
#        [ 1.24517454, -0.79608629],
#        [ 0.94118535,  1.25470343],
#        [-1.05163269, -0.53146826],
#        [ 0.26565381,  1.35393519],
#        [ 0.02921778,  0.65931286],
#        [-0.40987772,  1.25470343],
#        [ 0.97496193, -0.06838671],
#        [-0.98407953,  1.68470772],
#        [-0.03833538,  1.32085793],
#        [ 0.06299435, -1.32532235],
#        [-0.47743088, -1.25916784],
#        [-0.37610115,  0.52700385],
#        [ 0.06299435,  0.09699955],
#        [ 0.02921778,  0.82469913],
#        [ 0.06299435, -1.12685883],
#        [ 0.29943039,  0.19623131],
#        [-1.52450476,  1.02316265],
#        [ 0.8736322 , -0.29992749],
#        [-1.18673899, -0.66377728],
#        [-1.05163269, -0.79608629],
#        [ 0.02921778, -1.52378587],
#        [-1.49072819, -0.79608629],
#        [-1.38939846, -0.8622408 ],
#        [-1.65961107,  1.0562399 ],
#        [ 1.04251508,  1.28778068],
#        [-1.11918584, -1.3583996 ],
#        [ 0.29943039,  0.82469913],
#        [ 1.3127277 , -0.00223221],
#        [ 0.23187724, -0.72993178],
#        [ 1.3127277 ,  0.52700385],
#        [ 0.16432408, -1.58994038],
#        [-1.15296242,  0.92393089],
#        [ 1.44783401, -0.63070002],
#        [ 1.51538716,  0.46084934],
#        [-0.4436543 , -1.25916784],
#        [-1.72716422, -1.25916784],
#        [-0.17344169, -0.72993178],
#        [-0.20721826, -1.39147685],
#        [ 0.67097274,  0.79162188],
#        [-0.20721826, -1.58994038],
#        [-0.37610115,  1.68470772],
#        [ 1.17762139, -0.56454552],
#        [ 1.27895112, -0.33300474],
#        [-1.11918584, -0.46531376],
#        [-1.22051557, -1.02762707],
#        [ 1.51538716,  1.68470772],
#        [ 0.97496193, -0.49839101],
#        [-0.95030296, -0.63070002],
#        [ 0.36698354,  1.0562399 ],
#        [ 0.16432408, -1.49070861],
#        [-0.78142007,  0.42777209],
#        [ 1.24517454, -1.49070861],
#        [ 1.34650427, -0.13454122],
#        [-1.25429215,  1.61855321],
#        [ 0.70474931, -0.49839101],
#        [ 1.14384481, -1.09378157],
#        [-0.74764349, -1.06070432],
#        [ 0.60341958, -0.4322365 ],
#        [-1.62583449, -0.39915925],
#        [ 0.83985562, -1.29224509],
#        [-0.24099484, -1.42455411],
#        [ 0.56964301, -1.55686312],
#        [-1.35562188,  0.0639223 ],
#        [-1.69338765,  1.38701244],
#        [ 1.21139797, -0.53146826],
#        [ 0.16432408,  0.9900854 ],
#        [ 0.13054751, -0.92839531],
#        [-0.95030296,  1.32085793],
#        [-1.45695161, -0.46531376],
#        [ 1.51538716, -0.79608629],
#        [ 1.34650427, -0.29992749],
#        [-1.49072819, -1.32532235],
#        [ 0.4345367 ,  0.75854462],
#        [-1.18673899, -0.4322365 ],
#        [-1.05163269, -0.63070002],
#        [ 0.90740877,  0.59315836],
#        [-0.17344169,  0.72546737],
#        [ 0.67097274, -0.23377298],
#        [-1.49072819,  1.12239441],
#        [-1.62583449, -1.06070432],
#        [-0.81519665,  0.13007681],
#        [ 1.14384481, -0.82916354],
#        [ 0.40076012,  0.69239012],
#        [-1.69338765, -0.99454981],
#        [ 0.50208985,  1.55239871],
#        [-1.28806872,  0.26238582],
#        [ 0.8736322 , -0.8622408 ],
#        [ 0.50208985, -0.4322365 ],
#        [-0.24099484,  0.62623561],
#        [-0.95030296,  0.79162188],
#        [ 0.02921778,  1.28778068],
#        [ 1.07629166,  0.82469913],
#        [ 1.51538716, -0.06838671],
#        [ 1.11006824,  0.03084505],
#        [-0.4436543 ,  0.95700814],
#        [ 1.07629166, -0.89531805]])

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Bidirectional, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import mse

# %%
# Initialising the RNN
model = Sequential()
# Adding the input layer and the LSTM layer
model.add(Bidirectional(LSTM(240,
                        input_shape = (window_length, number_of_features),
                        return_sequences = True)))
# Adding a first Dropout layer
model.add(Dropout(0.2))
# Adding a second LSTM layer
model.add(Bidirectional(LSTM(240,
                        input_shape = (window_length, number_of_features),
                        return_sequences = True)))
# Adding a second Dropout layer
model.add(Dropout(0.2))
# Adding a third LSTM layer
model.add(Bidirectional(LSTM(240,
                        input_shape = (window_length, number_of_features),
                        return_sequences = True)))
# Adding a fourth LSTM layer
model.add(Bidirectional(LSTM(240,
                        input_shape = (window_length, number_of_features),
                        return_sequences = False)))
# Adding a third Dropout layer
model.add(Dropout(0.2))
# Adding the first output layer
model.add(Dense(70))
# Adding the last output layer
model.add(Dense(number_of_features))

# %%
model.compile(optimizer=Adam(learning_rate=0.01), loss ='mse', metrics=['accuracy'])

# %%
model.fit(x=x_train, y=y_train, batch_size=128, epochs=200, verbose=2)
# Out:
# Epoch 1/200
# 2/2 - 22s - loss: 1.0531 - accuracy: 0.4487 - 22s/epoch - 11s/step
# Epoch 2/200
# 2/2 - 1s - loss: 4.6552 - accuracy: 0.5641 - 912ms/epoch - 456ms/step
# Epoch 3/200
# 2/2 - 1s - loss: 1.3921 - accuracy: 0.5000 - 929ms/epoch - 464ms/step
# Epoch 4/200
# 2/2 - 1s - loss: 2.4211 - accuracy: 0.4295 - 911ms/epoch - 455ms/step
# Epoch 5/200
# 2/2 - 1s - loss: 1.2070 - accuracy: 0.4615 - 972ms/epoch - 486ms/step
# Epoch 6/200
# 2/2 - 1s - loss: 1.5128 - accuracy: 0.5641 - 1s/epoch - 531ms/step
# Epoch 7/200
# 2/2 - 2s - loss: 1.2252 - accuracy: 0.4744 - 2s/epoch - 760ms/step
# Epoch 8/200
# 2/2 - 1s - loss: 1.1356 - accuracy: 0.5962 - 1s/epoch - 723ms/step
# Epoch 9/200
# 2/2 - 1s - loss: 1.0268 - accuracy: 0.5385 - 1s/epoch - 730ms/step
# Epoch 10/200
# 2/2 - 1s - loss: 1.0152 - accuracy: 0.5449 - 1s/epoch - 660ms/step
# Epoch 11/200
# 2/2 - 1s - loss: 1.0363 - accuracy: 0.4615 - 887ms/epoch - 444ms/step
# Epoch 12/200
# 2/2 - 1s - loss: 0.9696 - accuracy: 0.4936 - 897ms/epoch - 448ms/step
# Epoch 13/200
# 2/2 - 1s - loss: 1.0071 - accuracy: 0.5641 - 945ms/epoch - 473ms/step
# Epoch 14/200
# 2/2 - 1s - loss: 0.9525 - accuracy: 0.5000 - 937ms/epoch - 469ms/step
# Epoch 15/200
# 2/2 - 1s - loss: 0.9517 - accuracy: 0.5256 - 953ms/epoch - 477ms/step
# Epoch 16/200
# 2/2 - 1s - loss: 0.9084 - accuracy: 0.5449 - 922ms/epoch - 461ms/step
# Epoch 17/200
# 2/2 - 1s - loss: 0.9055 - accuracy: 0.5705 - 889ms/epoch - 445ms/step
# Epoch 18/200
# 2/2 - 1s - loss: 0.8847 - accuracy: 0.5513 - 886ms/epoch - 443ms/step
# Epoch 19/200
# 2/2 - 1s - loss: 0.8847 - accuracy: 0.6474 - 894ms/epoch - 447ms/step
# Epoch 20/200
# 2/2 - 1s - loss: 0.8436 - accuracy: 0.6731 - 901ms/epoch - 450ms/step
# Epoch 21/200
# 2/2 - 1s - loss: 0.8257 - accuracy: 0.6282 - 1s/epoch - 551ms/step
# Epoch 22/200
# 2/2 - 2s - loss: 0.7720 - accuracy: 0.6218 - 2s/epoch - 771ms/step
# Epoch 23/200
# 2/2 - 2s - loss: 0.7795 - accuracy: 0.6282 - 2s/epoch - 788ms/step
# Epoch 24/200
# 2/2 - 2s - loss: 0.7583 - accuracy: 0.6154 - 2s/epoch - 759ms/step
# Epoch 25/200
# 2/2 - 1s - loss: 0.7028 - accuracy: 0.6795 - 1s/epoch - 668ms/step
# Epoch 26/200
# 2/2 - 1s - loss: 0.6850 - accuracy: 0.6731 - 868ms/epoch - 434ms/step
# Epoch 27/200
# 2/2 - 1s - loss: 0.6946 - accuracy: 0.6154 - 923ms/epoch - 462ms/step
# Epoch 28/200
# 2/2 - 1s - loss: 0.6142 - accuracy: 0.7179 - 906ms/epoch - 453ms/step
# Epoch 29/200
# 2/2 - 1s - loss: 0.6396 - accuracy: 0.6795 - 874ms/epoch - 437ms/step
# Epoch 30/200
# 2/2 - 1s - loss: 0.5519 - accuracy: 0.7179 - 870ms/epoch - 435ms/step
# Epoch 31/200
# 2/2 - 1s - loss: 0.5184 - accuracy: 0.6923 - 884ms/epoch - 442ms/step
# Epoch 32/200
# 2/2 - 1s - loss: 0.5128 - accuracy: 0.7372 - 913ms/epoch - 456ms/step
# Epoch 33/200
# 2/2 - 1s - loss: 0.4775 - accuracy: 0.7115 - 924ms/epoch - 462ms/step
# Epoch 34/200
# 2/2 - 1s - loss: 0.4815 - accuracy: 0.7628 - 906ms/epoch - 453ms/step
# Epoch 35/200
# 2/2 - 1s - loss: 0.4267 - accuracy: 0.7821 - 887ms/epoch - 444ms/step
# Epoch 36/200
# 2/2 - 1s - loss: 0.3687 - accuracy: 0.8205 - 1s/epoch - 525ms/step
# Epoch 37/200
# 2/2 - 1s - loss: 0.3492 - accuracy: 0.8590 - 1s/epoch - 725ms/step
# Epoch 38/200
# 2/2 - 1s - loss: 0.2961 - accuracy: 0.8654 - 1s/epoch - 736ms/step
# Epoch 39/200
# 2/2 - 1s - loss: 0.2708 - accuracy: 0.8590 - 1s/epoch - 675ms/step
# Epoch 40/200
# 2/2 - 2s - loss: 0.2774 - accuracy: 0.8269 - 2s/epoch - 760ms/step
# Epoch 41/200
# 2/2 - 1s - loss: 0.2288 - accuracy: 0.8846 - 926ms/epoch - 463ms/step
# Epoch 42/200
# 2/2 - 1s - loss: 0.1670 - accuracy: 0.8910 - 873ms/epoch - 437ms/step
# Epoch 43/200
# 2/2 - 1s - loss: 0.2048 - accuracy: 0.9038 - 901ms/epoch - 451ms/step
# Epoch 44/200
# 2/2 - 1s - loss: 0.1845 - accuracy: 0.8974 - 891ms/epoch - 445ms/step
# Epoch 45/200
# 2/2 - 1s - loss: 0.1516 - accuracy: 0.9038 - 879ms/epoch - 439ms/step
# Epoch 46/200
# 2/2 - 1s - loss: 0.1946 - accuracy: 0.9231 - 897ms/epoch - 449ms/step
# Epoch 47/200
# 2/2 - 1s - loss: 0.1541 - accuracy: 0.8974 - 890ms/epoch - 445ms/step
# Epoch 48/200
# 2/2 - 1s - loss: 0.1658 - accuracy: 0.8910 - 881ms/epoch - 441ms/step
# Epoch 49/200
# 2/2 - 1s - loss: 0.1586 - accuracy: 0.9359 - 856ms/epoch - 428ms/step
# Epoch 50/200
# 2/2 - 1s - loss: 0.1288 - accuracy: 0.9295 - 854ms/epoch - 427ms/step
# Epoch 51/200
# 2/2 - 1s - loss: 0.1314 - accuracy: 0.9487 - 901ms/epoch - 451ms/step
# Epoch 52/200
# 2/2 - 1s - loss: 0.1390 - accuracy: 0.8910 - 1s/epoch - 713ms/step
# Epoch 53/200
# 2/2 - 2s - loss: 0.1178 - accuracy: 0.8846 - 2s/epoch - 752ms/step
# Epoch 54/200
# 2/2 - 1s - loss: 0.1031 - accuracy: 0.9167 - 1s/epoch - 700ms/step
# Epoch 55/200
# 2/2 - 2s - loss: 0.1005 - accuracy: 0.9551 - 2s/epoch - 760ms/step
# Epoch 56/200
# 2/2 - 1s - loss: 0.0846 - accuracy: 0.9359 - 987ms/epoch - 493ms/step
# Epoch 57/200
# 2/2 - 1s - loss: 0.0856 - accuracy: 0.9295 - 877ms/epoch - 438ms/step
# Epoch 58/200
# 2/2 - 1s - loss: 0.0766 - accuracy: 0.9551 - 880ms/epoch - 440ms/step
# Epoch 59/200
# 2/2 - 1s - loss: 0.0750 - accuracy: 0.9167 - 888ms/epoch - 444ms/step
# Epoch 60/200
# 2/2 - 1s - loss: 0.0722 - accuracy: 0.9359 - 918ms/epoch - 459ms/step
# Epoch 61/200
# 2/2 - 1s - loss: 0.0731 - accuracy: 0.9615 - 923ms/epoch - 462ms/step
# Epoch 62/200
# 2/2 - 1s - loss: 0.0684 - accuracy: 0.9551 - 899ms/epoch - 450ms/step
# Epoch 63/200
# 2/2 - 1s - loss: 0.0658 - accuracy: 0.9487 - 858ms/epoch - 429ms/step
# Epoch 64/200
# 2/2 - 1s - loss: 0.0632 - accuracy: 0.9359 - 855ms/epoch - 428ms/step
# Epoch 65/200
# 2/2 - 1s - loss: 0.0610 - accuracy: 0.9231 - 859ms/epoch - 430ms/step
# Epoch 66/200
# 2/2 - 1s - loss: 0.0526 - accuracy: 0.9487 - 872ms/epoch - 436ms/step
# Epoch 67/200
# 2/2 - 1s - loss: 0.0503 - accuracy: 0.9615 - 1s/epoch - 551ms/step
# Epoch 68/200
# 2/2 - 1s - loss: 0.0433 - accuracy: 0.9423 - 1s/epoch - 708ms/step
# Epoch 69/200
# 2/2 - 2s - loss: 0.0531 - accuracy: 0.9679 - 2s/epoch - 753ms/step
# Epoch 70/200
# 2/2 - 1s - loss: 0.0479 - accuracy: 0.9359 - 1s/epoch - 722ms/step
# Epoch 71/200
# 2/2 - 1s - loss: 0.0441 - accuracy: 0.9551 - 1s/epoch - 713ms/step
# Epoch 72/200
# 2/2 - 1s - loss: 0.0362 - accuracy: 0.9744 - 880ms/epoch - 440ms/step
# Epoch 73/200
# 2/2 - 1s - loss: 0.0358 - accuracy: 0.9936 - 903ms/epoch - 452ms/step
# Epoch 74/200
# 2/2 - 1s - loss: 0.0448 - accuracy: 0.9744 - 869ms/epoch - 435ms/step
# Epoch 75/200
# 2/2 - 1s - loss: 0.0388 - accuracy: 0.9679 - 882ms/epoch - 441ms/step
# Epoch 76/200
# 2/2 - 1s - loss: 0.0330 - accuracy: 0.9551 - 884ms/epoch - 442ms/step
# Epoch 77/200
# 2/2 - 1s - loss: 0.0435 - accuracy: 0.9551 - 881ms/epoch - 440ms/step
# Epoch 78/200
# 2/2 - 1s - loss: 0.0353 - accuracy: 0.9872 - 857ms/epoch - 429ms/step
# Epoch 79/200
# 2/2 - 1s - loss: 0.0320 - accuracy: 0.9679 - 897ms/epoch - 449ms/step
# Epoch 80/200
# 2/2 - 1s - loss: 0.0303 - accuracy: 0.9615 - 921ms/epoch - 460ms/step
# Epoch 81/200
# 2/2 - 1s - loss: 0.0297 - accuracy: 0.9679 - 907ms/epoch - 453ms/step
# Epoch 82/200
# 2/2 - 1s - loss: 0.0350 - accuracy: 0.9423 - 894ms/epoch - 447ms/step
# Epoch 83/200
# 2/2 - 1s - loss: 0.0356 - accuracy: 0.9679 - 1s/epoch - 728ms/step
# Epoch 84/200
# 2/2 - 2s - loss: 0.0325 - accuracy: 0.9679 - 2s/epoch - 1s/step
# Epoch 85/200
# 2/2 - 1s - loss: 0.0237 - accuracy: 0.9615 - 1s/epoch - 721ms/step
# Epoch 86/200
# 2/2 - 1s - loss: 0.0332 - accuracy: 0.9487 - 1s/epoch - 641ms/step
# Epoch 87/200
# 2/2 - 1s - loss: 0.0231 - accuracy: 0.9615 - 878ms/epoch - 439ms/step
# Epoch 88/200
# 2/2 - 1s - loss: 0.0316 - accuracy: 0.9744 - 888ms/epoch - 444ms/step
# Epoch 89/200
# 2/2 - 1s - loss: 0.0262 - accuracy: 0.9872 - 932ms/epoch - 466ms/step
# Epoch 90/200
# 2/2 - 1s - loss: 0.0273 - accuracy: 0.9744 - 899ms/epoch - 450ms/step
# Epoch 91/200
# 2/2 - 1s - loss: 0.0256 - accuracy: 0.9551 - 862ms/epoch - 431ms/step
# Epoch 92/200
# 2/2 - 1s - loss: 0.0233 - accuracy: 0.9744 - 865ms/epoch - 433ms/step
# Epoch 93/200
# 2/2 - 1s - loss: 0.0279 - accuracy: 0.9744 - 885ms/epoch - 442ms/step
# Epoch 94/200
# 2/2 - 1s - loss: 0.0306 - accuracy: 0.9551 - 894ms/epoch - 447ms/step
# Epoch 95/200
# 2/2 - 1s - loss: 0.0350 - accuracy: 0.9679 - 851ms/epoch - 426ms/step
# Epoch 96/200
# 2/2 - 1s - loss: 0.0281 - accuracy: 0.9679 - 860ms/epoch - 430ms/step
# Epoch 97/200
# 2/2 - 1s - loss: 0.0233 - accuracy: 0.9679 - 919ms/epoch - 459ms/step
# Epoch 98/200
# 2/2 - 1s - loss: 0.0259 - accuracy: 0.9551 - 1s/epoch - 733ms/step
# Epoch 99/200
# 2/2 - 2s - loss: 0.0284 - accuracy: 0.9679 - 2s/epoch - 755ms/step
# Epoch 100/200
# 2/2 - 1s - loss: 0.0256 - accuracy: 0.9615 - 1s/epoch - 703ms/step
# Epoch 101/200
# 2/2 - 2s - loss: 0.0265 - accuracy: 0.9551 - 2s/epoch - 787ms/step
# Epoch 102/200
# 2/2 - 1s - loss: 0.0272 - accuracy: 0.9744 - 882ms/epoch - 441ms/step
# Epoch 103/200
# 2/2 - 1s - loss: 0.0253 - accuracy: 0.9679 - 846ms/epoch - 423ms/step
# Epoch 104/200
# 2/2 - 1s - loss: 0.0196 - accuracy: 0.9744 - 882ms/epoch - 441ms/step
# Epoch 105/200
# 2/2 - 1s - loss: 0.0221 - accuracy: 0.9615 - 877ms/epoch - 438ms/step
# Epoch 106/200
# 2/2 - 1s - loss: 0.0226 - accuracy: 0.9808 - 890ms/epoch - 445ms/step
# Epoch 107/200
# 2/2 - 1s - loss: 0.0229 - accuracy: 0.9679 - 869ms/epoch - 434ms/step
# Epoch 108/200
# 2/2 - 1s - loss: 0.0220 - accuracy: 0.9872 - 1s/epoch - 594ms/step
# Epoch 109/200
# 2/2 - 1s - loss: 0.0214 - accuracy: 0.9872 - 872ms/epoch - 436ms/step
# Epoch 110/200
# 2/2 - 1s - loss: 0.0271 - accuracy: 0.9808 - 864ms/epoch - 432ms/step
# Epoch 111/200
# 2/2 - 1s - loss: 0.0164 - accuracy: 0.9808 - 868ms/epoch - 434ms/step
# Epoch 112/200
# 2/2 - 1s - loss: 0.0273 - accuracy: 0.9808 - 905ms/epoch - 453ms/step
# Epoch 113/200
# 2/2 - 1s - loss: 0.0214 - accuracy: 0.9615 - 1s/epoch - 742ms/step
# Epoch 114/200
# 2/2 - 1s - loss: 0.0220 - accuracy: 0.9808 - 1s/epoch - 744ms/step
# Epoch 115/200
# 2/2 - 1s - loss: 0.0192 - accuracy: 0.9679 - 1s/epoch - 723ms/step
# Epoch 116/200
# 2/2 - 2s - loss: 0.0219 - accuracy: 0.9872 - 2s/epoch - 776ms/step
# Epoch 117/200
# 2/2 - 1s - loss: 0.0184 - accuracy: 0.9615 - 908ms/epoch - 454ms/step
# Epoch 118/200
# 2/2 - 1s - loss: 0.0226 - accuracy: 0.9679 - 868ms/epoch - 434ms/step
# Epoch 119/200
# 2/2 - 1s - loss: 0.0222 - accuracy: 0.9872 - 871ms/epoch - 436ms/step
# Epoch 120/200
# 2/2 - 1s - loss: 0.0239 - accuracy: 0.9744 - 866ms/epoch - 433ms/step
# Epoch 121/200
# 2/2 - 1s - loss: 0.0196 - accuracy: 0.9808 - 870ms/epoch - 435ms/step
# Epoch 122/200
# 2/2 - 1s - loss: 0.0192 - accuracy: 0.9936 - 910ms/epoch - 455ms/step
# Epoch 123/200
# 2/2 - 1s - loss: 0.0197 - accuracy: 0.9936 - 890ms/epoch - 445ms/step
# Epoch 124/200
# 2/2 - 1s - loss: 0.0188 - accuracy: 0.9615 - 851ms/epoch - 426ms/step
# Epoch 125/200
# 2/2 - 1s - loss: 0.0172 - accuracy: 0.9744 - 841ms/epoch - 420ms/step
# Epoch 126/200
# 2/2 - 1s - loss: 0.0201 - accuracy: 0.9744 - 872ms/epoch - 436ms/step
# Epoch 127/200
# 2/2 - 1s - loss: 0.0186 - accuracy: 0.9744 - 888ms/epoch - 444ms/step
# Epoch 128/200
# 2/2 - 1s - loss: 0.0193 - accuracy: 0.9615 - 1s/epoch - 639ms/step
# Epoch 129/200
# 2/2 - 1s - loss: 0.0232 - accuracy: 0.9615 - 1s/epoch - 743ms/step
# Epoch 130/200
# 2/2 - 1s - loss: 0.0232 - accuracy: 0.9679 - 1s/epoch - 725ms/step
# Epoch 131/200
# 2/2 - 2s - loss: 0.0199 - accuracy: 0.9615 - 2s/epoch - 752ms/step
# Epoch 132/200
# 2/2 - 1s - loss: 0.0177 - accuracy: 0.9808 - 1s/epoch - 594ms/step
# Epoch 133/200
# 2/2 - 1s - loss: 0.0175 - accuracy: 0.9679 - 870ms/epoch - 435ms/step
# Epoch 134/200
# 2/2 - 1s - loss: 0.0236 - accuracy: 0.9487 - 883ms/epoch - 442ms/step
# Epoch 135/200
# 2/2 - 1s - loss: 0.0199 - accuracy: 0.9744 - 884ms/epoch - 442ms/step
# Epoch 136/200
# 2/2 - 1s - loss: 0.0199 - accuracy: 0.9744 - 905ms/epoch - 452ms/step
# Epoch 137/200
# 2/2 - 1s - loss: 0.0178 - accuracy: 0.9679 - 894ms/epoch - 447ms/step
# Epoch 138/200
# 2/2 - 1s - loss: 0.0211 - accuracy: 0.9679 - 916ms/epoch - 458ms/step
# Epoch 139/200
# 2/2 - 1s - loss: 0.0164 - accuracy: 0.9808 - 889ms/epoch - 444ms/step
# Epoch 140/200
# 2/2 - 1s - loss: 0.0175 - accuracy: 0.9808 - 857ms/epoch - 428ms/step
# Epoch 141/200
# 2/2 - 1s - loss: 0.0167 - accuracy: 0.9615 - 878ms/epoch - 439ms/step
# Epoch 142/200
# 2/2 - 1s - loss: 0.0181 - accuracy: 0.9744 - 889ms/epoch - 444ms/step
# Epoch 143/200
# 2/2 - 1s - loss: 0.0177 - accuracy: 1.0000 - 1s/epoch - 512ms/step
# Epoch 144/200
# 2/2 - 1s - loss: 0.0149 - accuracy: 0.9808 - 1s/epoch - 731ms/step
# Epoch 145/200
# 2/2 - 1s - loss: 0.0161 - accuracy: 0.9744 - 1s/epoch - 719ms/step
# Epoch 146/200
# 2/2 - 2s - loss: 0.0160 - accuracy: 0.9808 - 2s/epoch - 751ms/step
# Epoch 147/200
# 2/2 - 1s - loss: 0.0177 - accuracy: 0.9744 - 1s/epoch - 700ms/step
# Epoch 148/200
# 2/2 - 1s - loss: 0.0171 - accuracy: 0.9936 - 863ms/epoch - 431ms/step
# Epoch 149/200
# 2/2 - 1s - loss: 0.0146 - accuracy: 0.9936 - 870ms/epoch - 435ms/step
# Epoch 150/200
# 2/2 - 1s - loss: 0.0149 - accuracy: 0.9872 - 863ms/epoch - 431ms/step
# Epoch 151/200
# 2/2 - 1s - loss: 0.0166 - accuracy: 0.9615 - 869ms/epoch - 434ms/step
# Epoch 152/200
# 2/2 - 1s - loss: 0.0181 - accuracy: 0.9744 - 896ms/epoch - 448ms/step
# Epoch 153/200
# 2/2 - 1s - loss: 0.0165 - accuracy: 0.9936 - 880ms/epoch - 440ms/step
# Epoch 154/200
# 2/2 - 1s - loss: 0.0169 - accuracy: 0.9872 - 863ms/epoch - 431ms/step
# Epoch 155/200
# 2/2 - 1s - loss: 0.0171 - accuracy: 0.9872 - 888ms/epoch - 444ms/step
# Epoch 156/200
# 2/2 - 1s - loss: 0.0130 - accuracy: 0.9872 - 892ms/epoch - 446ms/step
# Epoch 157/200
# 2/2 - 1s - loss: 0.0153 - accuracy: 0.9744 - 900ms/epoch - 450ms/step
# Epoch 158/200
# 2/2 - 1s - loss: 0.0123 - accuracy: 0.9679 - 1s/epoch - 572ms/step
# Epoch 159/200
# 2/2 - 2s - loss: 0.0140 - accuracy: 0.9744 - 2s/epoch - 827ms/step
# Epoch 160/200
# 2/2 - 2s - loss: 0.0123 - accuracy: 0.9872 - 2s/epoch - 787ms/step
# Epoch 161/200
# 2/2 - 2s - loss: 0.0152 - accuracy: 0.9679 - 2s/epoch - 825ms/step
# Epoch 162/200
# 2/2 - 2s - loss: 0.0134 - accuracy: 0.9936 - 2s/epoch - 818ms/step
# Epoch 163/200
# 2/2 - 2s - loss: 0.0141 - accuracy: 0.9872 - 2s/epoch - 807ms/step
# Epoch 164/200
# 2/2 - 2s - loss: 0.0124 - accuracy: 0.9679 - 2s/epoch - 813ms/step
# Epoch 165/200
# 2/2 - 1s - loss: 0.0137 - accuracy: 0.9872 - 887ms/epoch - 443ms/step
# Epoch 166/200
# 2/2 - 1s - loss: 0.0128 - accuracy: 0.9744 - 866ms/epoch - 433ms/step
# Epoch 167/200
# 2/2 - 1s - loss: 0.0136 - accuracy: 0.9808 - 880ms/epoch - 440ms/step
# Epoch 168/200
# 2/2 - 1s - loss: 0.0134 - accuracy: 0.9872 - 864ms/epoch - 432ms/step
# Epoch 169/200
# 2/2 - 1s - loss: 0.0112 - accuracy: 1.0000 - 881ms/epoch - 441ms/step
# Epoch 170/200
# 2/2 - 1s - loss: 0.0110 - accuracy: 0.9808 - 897ms/epoch - 449ms/step
# Epoch 171/200
# 2/2 - 1s - loss: 0.0139 - accuracy: 0.9679 - 876ms/epoch - 438ms/step
# Epoch 172/200
# 2/2 - 1s - loss: 0.0155 - accuracy: 0.9679 - 861ms/epoch - 431ms/step
# Epoch 173/200
# 2/2 - 1s - loss: 0.0113 - accuracy: 0.9872 - 883ms/epoch - 441ms/step
# Epoch 174/200
# 2/2 - 1s - loss: 0.0167 - accuracy: 0.9936 - 922ms/epoch - 461ms/step
# Epoch 175/200
# 2/2 - 1s - loss: 0.0124 - accuracy: 0.9808 - 879ms/epoch - 440ms/step
# Epoch 176/200
# 2/2 - 1s - loss: 0.0128 - accuracy: 0.9808 - 1s/epoch - 637ms/step
# Epoch 177/200
# 2/2 - 1s - loss: 0.0144 - accuracy: 1.0000 - 1s/epoch - 735ms/step
# Epoch 178/200
# 2/2 - 1s - loss: 0.0134 - accuracy: 0.9872 - 1s/epoch - 729ms/step
# Epoch 179/200
# 2/2 - 1s - loss: 0.0135 - accuracy: 0.9679 - 1s/epoch - 748ms/step
# Epoch 180/200
# 2/2 - 1s - loss: 0.0118 - accuracy: 0.9744 - 1s/epoch - 524ms/step
# Epoch 181/200
# 2/2 - 1s - loss: 0.0164 - accuracy: 0.9744 - 891ms/epoch - 445ms/step
# Epoch 182/200
# 2/2 - 1s - loss: 0.0115 - accuracy: 0.9744 - 865ms/epoch - 433ms/step
# Epoch 183/200
# 2/2 - 1s - loss: 0.0169 - accuracy: 0.9808 - 883ms/epoch - 442ms/step
# Epoch 184/200
# 2/2 - 1s - loss: 0.0119 - accuracy: 1.0000 - 892ms/epoch - 446ms/step
# Epoch 185/200
# 2/2 - 1s - loss: 0.0149 - accuracy: 0.9744 - 898ms/epoch - 449ms/step
# Epoch 186/200
# 2/2 - 1s - loss: 0.0142 - accuracy: 0.9872 - 887ms/epoch - 443ms/step
# Epoch 187/200
# 2/2 - 1s - loss: 0.0157 - accuracy: 0.9872 - 885ms/epoch - 443ms/step
# Epoch 188/200
# 2/2 - 1s - loss: 0.0143 - accuracy: 0.9872 - 881ms/epoch - 441ms/step
# Epoch 189/200
# 2/2 - 1s - loss: 0.0158 - accuracy: 0.9872 - 887ms/epoch - 444ms/step
# Epoch 190/200
# 2/2 - 1s - loss: 0.0148 - accuracy: 0.9808 - 895ms/epoch - 447ms/step
# Epoch 191/200
# 2/2 - 1s - loss: 0.0201 - accuracy: 0.9808 - 1s/epoch - 587ms/step
# Epoch 192/200
# 2/2 - 2s - loss: 0.0145 - accuracy: 0.9744 - 2s/epoch - 789ms/step
# Epoch 193/200
# 2/2 - 1s - loss: 0.0156 - accuracy: 0.9808 - 1s/epoch - 730ms/step
# Epoch 194/200
# 2/2 - 1s - loss: 0.0124 - accuracy: 0.9808 - 1s/epoch - 745ms/step
# Epoch 195/200
# 2/2 - 1s - loss: 0.0163 - accuracy: 0.9808 - 1s/epoch - 622ms/step
# Epoch 196/200
# 2/2 - 1s - loss: 0.0129 - accuracy: 0.9872 - 870ms/epoch - 435ms/step
# Epoch 197/200
# 2/2 - 1s - loss: 0.0145 - accuracy: 0.9936 - 877ms/epoch - 438ms/step
# Epoch 198/200
# 2/2 - 1s - loss: 0.0144 - accuracy: 0.9872 - 874ms/epoch - 437ms/step
# Epoch 199/200
# 2/2 - 1s - loss: 0.0129 - accuracy: 0.9872 - 884ms/epoch - 442ms/step
# Epoch 200/200
# 2/2 - 1s - loss: 0.0165 - accuracy: 0.9808 - 886ms/epoch - 443ms/step

# %% [markdown]
# ### Prediction without rounding up or down the results

# %%
df1.rename(columns={'date': 'Date'},inplace=True)

# %%
print('-' * 40)
print('Prediction vs. GoundTruth without rounding up or down')
for i in range(1,10):
  test = df1.copy()
  test = test.tail((window_length+10-i))
  test = test.head((window_length+1))
  test_Date = df1.iloc[ (test.tail().index[-1]) ]['Date']
  test1 = test.head((window_length))
  test1.drop(['Date'], axis=1, inplace=True)
  test1 = np.array(test1)
  x_test = scaler.transform(test1)
  y_test_pred = model.predict(np.array([x_test]))
  y_test_true = test.drop(['Date'], axis=1, inplace=True)
  y_test_true = test.tail(1)
  print('Drawing  Date', test_Date)
  print('Prediction:\t', scaler.inverse_transform(y_test_pred).astype(int)[0])
  print('GoundTruth:\t', np.array(y_test_true)[0])
  print('-' * 40)
# Out:
# ----------------------------------------
# Prediction vs. GoundTruth without rounding up or down
# 1/1 [==============================] - 3s 3s/step
# Drawing  Date 2023-05-29 00:00:00
# Prediction:	 [69 36]
# GoundTruth:	 [68 35]
# ----------------------------------------
# 1/1 [==============================] - 0s 36ms/step
# Drawing  Date 2023-05-26 00:00:00
# Prediction:	 [44 70]
# GoundTruth:	 [46 67]
# ----------------------------------------
# 1/1 [==============================] - 0s 45ms/step
# Drawing  Date 2023-05-24 00:00:00
# Prediction:	 [21 73]
# GoundTruth:	 [25 72]
# ----------------------------------------
# 1/1 [==============================] - 0s 50ms/step
# Drawing  Date 2023-05-22 00:00:00
# Prediction:	 [55 87]
# GoundTruth:	 [54 87]
# ----------------------------------------
# 1/1 [==============================] - 0s 42ms/step
# Drawing  Date 2023-05-19 00:00:00
# Prediction:	 [84 67]
# GoundTruth:	 [85 73]
# ----------------------------------------
# 1/1 [==============================] - 0s 42ms/step
# Drawing  Date 2023-05-17 00:00:00
# Prediction:	 [94 44]
# GoundTruth:	 [98 46]
# ----------------------------------------
# 1/1 [==============================] - 0s 41ms/step
# Drawing  Date 2023-05-15 00:00:00
# Prediction:	 [84 49]
# GoundTruth:	 [86 49]
# ----------------------------------------
# 1/1 [==============================] - 0s 39ms/step
# Drawing  Date 2023-05-12 00:00:00
# Prediction:	 [39 75]
# GoundTruth:	 [40 77]
# ----------------------------------------
# 1/1 [==============================] - 0s 41ms/step
# Drawing  Date 2023-05-10 00:00:00
# Prediction:	 [84 18]
# GoundTruth:	 [85 21]
# ----------------------------------------

# %% [markdown]
# ### Predict the Future Drawing Results on June 1, 2o24

# %%
next_Date = '2024-06-07'
print('-' * 40)
print('Predict the Future Drawing on',next_Date)

# Copy and prepare the data for prediction
next = df.copy()
next = next.tail(window_length)
next = np.array(next)
x_next = scaler.transform(next)

# Predict the next values
y_next_pred = model.predict(np.array([x_next]))

# Filter the actual values based on the next date
filtered_df = lt_2[lt_2['date'] == next_Date]

# Extract the actual values and convert them to a list
actual_values = filtered_df[['เลขล่าง','เลขบน']].values.flatten().tolist()

# Calculate the absolute difference
prediction = scaler.inverse_transform(y_next_pred).astype(int)[0].tolist()
diff = [abs(pred - actual) for pred, actual in zip(prediction, actual_values)]

# Print the results
print('Drawing  Date', next_Date)
print('Prediction:\t', prediction)
print('GoundTruth:\t', actual_values)
print('Diff:   \t', diff)
print('-' * 40)
# Out:
# ----------------------------------------
# Predict the Future Drawing on 2024-06-07
# 1/1 [==============================] - 0s 66ms/step
# Drawing  Date 2024-06-07
# Prediction:	 [49, 28]
# GoundTruth:	 []
# Diff:   	 []
# ----------------------------------------
