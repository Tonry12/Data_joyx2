# %% [markdown]
# <a href="https://colab.research.google.com/github/Tonry12/Data_joyx2/blob/main/Laos_lotto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
lotto = pd.read_csv('/content/drive/MyDrive/SPN/Laos_Lotto.csv')

# %%
lotto_ai = pd.read_csv('/content/drive/MyDrive/SPN/Laos_Lotto_pre.csv')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy
import os
import pickle
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
lotto
# Out:
#           date  เลข 4 ตัว  เลข 3 ตัว  เลข 2 ตัว  weekday_dum    weekday
# 0     5/3/2024       7999        999         99            6     Friday
# 1    4/29/2024       4351        351         51            2     Monday
# 2    4/26/2024       8721        721         21            6     Friday
# 3    4/24/2024       2552        552         52            4  Wednesday
# 4    4/22/2024       9490        490         90            2     Monday
# ..         ...        ...        ...        ...          ...        ...
# 144  5/19/2023       8573        573         73            6     Friday
# 145  5/17/2023       9846        846         46            4  Wednesday
# 146  5/15/2023       8649        649         49            2     Monday
# 147  5/12/2023       4077         77         77            6     Friday
# 148  5/10/2023       8521        521         21            4  Wednesday
#
# [149 rows x 6 columns]

# %%
lotto.isnull().any()
# Out:
# date           False
# เลข 4 ตัว      False
# เลข 3 ตัว      False
# เลข 2 ตัว      False
# weekday_dum    False
# weekday        False
# dtype: bool

# %%
lotto.rename(columns={'เลข 4 ตัว': 'top4','เลข 3 ตัว':'top3','เลข 2 ตัว':'top2'},inplace=True)

# %%
lt = lotto.drop(columns=['weekday_dum'])

# %%
lt['date'] = pd.to_datetime(lt['date'])

# %%
lt.dtypes
# Out:
# date       datetime64[ns]
# top4                int64
# top3                int64
# top2                int64
# weekday            object
# dtype: object

# %%
lt['top4'] = lt['top4'].apply(lambda x: '{:04}'.format(x))

# %%
lt
# Out:
#           date  top4  top3  top2    weekday
# 0   2024-05-03  7999   999    99     Friday
# 1   2024-04-29  4351   351    51     Monday
# 2   2024-04-26  8721   721    21     Friday
# 3   2024-04-24  2552   552    52  Wednesday
# 4   2024-04-22  9490   490    90     Monday
# ..         ...   ...   ...   ...        ...
# 144 2023-05-19  8573   573    73     Friday
# 145 2023-05-17  9846   846    46  Wednesday
# 146 2023-05-15  8649   649    49     Monday
# 147 2023-05-12  4077    77    77     Friday
# 148 2023-05-10  8521   521    21  Wednesday
#
# [149 rows x 5 columns]

# %%
lt_1 = lt

# %%
lt_1['top4'] = lt_1['top4'].astype(str)

# Split each value in the 'digi' column into its individual digits
lt_1['r1'] = lt_1['top4'].apply(lambda x: int(x[0]))
lt_1['r2'] = lt_1['top4'].apply(lambda x: int(x[1]))
lt_1['r3'] = lt_1['top4'].apply(lambda x: int(x[2]))
lt_1['r4'] = lt_1['top4'].apply(lambda x: int(x[3]))

# %%
lt_1= lt_1.drop(columns=['top3','top2'])

# %%
lt_1
# Out:
#           date  top4    weekday  r1  r2  r3  r4
# 0   2024-05-03  7999     Friday   7   9   9   9
# 1   2024-04-29  4351     Monday   4   3   5   1
# 2   2024-04-26  8721     Friday   8   7   2   1
# 3   2024-04-24  2552  Wednesday   2   5   5   2
# 4   2024-04-22  9490     Monday   9   4   9   0
# ..         ...   ...        ...  ..  ..  ..  ..
# 144 2023-05-19  8573     Friday   8   5   7   3
# 145 2023-05-17  9846  Wednesday   9   8   4   6
# 146 2023-05-15  8649     Monday   8   6   4   9
# 147 2023-05-12  4077     Friday   4   0   7   7
# 148 2023-05-10  8521  Wednesday   8   5   2   1
#
# [149 rows x 7 columns]

# %% [markdown]
# # วันจันทร์

# %% [markdown]
# ## เลขท้าย 4 ตัว

# %%
monday = lt_1[lt_1['weekday'] == "Monday"]

# %%
monday.head()
# Out:
#          date  top4 weekday  r1  r2  r3  r4
# 1  2024-04-29  4351  Monday   4   3   5   1
# 4  2024-04-22  9490  Monday   9   4   9   0
# 8  2024-04-08  9545  Monday   9   5   4   5
# 11 2024-04-01  1596  Monday   1   5   9   6
# 16 2024-03-18  8302  Monday   8   3   0   2

# %%
# เลขท้ายสี่ตัวหลักที่ 1 ที่ออกบ่อยสุด
grouped_counts = monday.groupby('r1').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#    r1  Count
# 9   9     10

# %%
# เลขท้ายสี่ตัวหลักที่ 2 ที่ออกบ่อยสุด
grouped_counts = monday.groupby('r2').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#    r2  Count
# 8   8      9

# %%
# เลขท้ายสี่ตัวหลักที่ 3 ที่ออกบ่อยสุด
grouped_counts = monday.groupby('r3').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#    r3  Count
# 2   2      8
# 9   9      8

# %%
# เลขท้ายสี่ตัวหลักที่ 4 ที่ออกบ่อยสุด
grouped_counts = monday.groupby('r4').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#    r4  Count
# 5   5      8

# %% [markdown]
# ### สรุป เลขท้าย 4 ตัวที่ออกบ่อยที่สุดคือ 9825 หรือ 9895

# %% [markdown]
# # งวดวันพุธ

# %%
wed = lt_1[lt_1['weekday'] == "Wednesday"]

# %%
wed
# Out:
#           date  top4    weekday  r1  r2  r3  r4
# 3   2024-04-24  2552  Wednesday   2   5   5   2
# 7   2024-04-10  4389  Wednesday   4   3   8   9
# 10  2024-04-03  1959  Wednesday   1   9   5   9
# 13  2024-03-27  0911  Wednesday   0   9   1   1
# 15  2024-03-20  7706  Wednesday   7   7   0   6
# 18  2024-03-13  1857  Wednesday   1   8   5   7
# 20  2024-03-06  6478  Wednesday   6   4   7   8
# 23  2024-02-28  6118  Wednesday   6   1   1   8
# 26  2024-02-21  3890  Wednesday   3   8   9   0
# 29  2024-02-14  7243  Wednesday   7   2   4   3
# 32  2024-02-07  8368  Wednesday   8   3   6   8
# 35  2024-01-31  8932  Wednesday   8   9   3   2
# 38  2024-01-24  7380  Wednesday   7   3   8   0
# 41  2024-01-17  1226  Wednesday   1   2   2   6
# 44  2024-01-10  8391  Wednesday   8   3   9   1
# 47  2024-01-03  3873  Wednesday   3   8   7   3
# 49  2023-12-27  8785  Wednesday   8   7   8   5
# 52  2023-12-20  9922  Wednesday   9   9   2   2
# 55  2023-12-13  2232  Wednesday   2   2   3   2
# 58  2023-12-06  4186  Wednesday   4   1   8   6
# 61  2023-11-29  5288  Wednesday   5   2   8   8
# 64  2023-11-22  4264  Wednesday   4   2   6   4
# 67  2023-11-15  5514  Wednesday   5   5   1   4
# 70  2023-11-08  7939  Wednesday   7   9   3   9
# 73  2023-11-01  5402  Wednesday   5   4   0   2
# 76  2023-10-25  0480  Wednesday   0   4   8   0
# 79  2023-10-18  6273  Wednesday   6   2   7   3
# 82  2023-10-11  9264  Wednesday   9   2   6   4
# 85  2023-10-04  9629  Wednesday   9   6   2   9
# 88  2023-09-27  0210  Wednesday   0   2   1   0
# 91  2023-09-20  7372  Wednesday   7   3   7   2
# 94  2023-09-13  8831  Wednesday   8   8   3   1
# 97  2023-09-06  1717  Wednesday   1   7   1   7
# 100 2023-08-30  2529  Wednesday   2   5   2   9
# 103 2023-08-23  3061  Wednesday   3   0   6   1
# 106 2023-08-16  1697  Wednesday   1   6   9   7
# 109 2023-08-09  3116  Wednesday   3   1   1   6
# 112 2023-08-02  7809  Wednesday   7   8   0   9
# 115 2023-07-26  1350  Wednesday   1   3   5   0
# 118 2023-07-19  5878  Wednesday   5   8   7   8
# 121 2023-07-12  1034  Wednesday   1   0   3   4
# 124 2023-07-05  0908  Wednesday   0   9   0   8
# 127 2023-06-28  2229  Wednesday   2   2   2   9
# 130 2023-06-21  7341  Wednesday   7   3   4   1
# 133 2023-06-14  2952  Wednesday   2   9   5   2
# 136 2023-06-07  0318  Wednesday   0   3   1   8
# 139 2023-05-31  7922  Wednesday   7   9   2   2
# 142 2023-05-24  2572  Wednesday   2   5   7   2
# 145 2023-05-17  9846  Wednesday   9   8   4   6
# 148 2023-05-10  8521  Wednesday   8   5   2   1

# %%
# เลขท้ายสี่ตัวหลักที่ 1 ที่ออกบ่อยสุด
grouped_counts = wed.groupby('r1').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#    r1  Count
# 7   7      8

# %%
# เลขท้ายสี่ตัวหลักที่ 2 ที่ออกบ่อยสุด
grouped_counts = wed.groupby('r2').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#    r2  Count
# 2   2      9

# %%
# เลขท้ายสี่ตัวหลักที่ 3 ที่ออกบ่อยสุด
grouped_counts = wed.groupby('r3').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#    r3  Count
# 1   1      7
# 2   2      7

# %%
# เลขท้ายสี่ตัวหลักที่ 4 ที่ออกบ่อยสุด
grouped_counts = wed.groupby('r4').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#    r4  Count
# 2   2      9

# %% [markdown]
# ### สรุป เลขท้าย 4 ตัวที่ออกบ่อยที่สุดคือ 7212 หรือ 7222

# %%
wed_1 = lt[lt['weekday'] == "Wednesday"]

# %%
wed_1
# Out:
#           date  top4  top3  top2    weekday  r1  r2  r3  r4
# 3   2024-04-24  2552   552    52  Wednesday   2   5   5   2
# 7   2024-04-10  4389   389    89  Wednesday   4   3   8   9
# 10  2024-04-03  1959   959    59  Wednesday   1   9   5   9
# 13  2024-03-27  0911   911    11  Wednesday   0   9   1   1
# 15  2024-03-20  7706   706     6  Wednesday   7   7   0   6
# 18  2024-03-13  1857   857    57  Wednesday   1   8   5   7
# 20  2024-03-06  6478   478    78  Wednesday   6   4   7   8
# 23  2024-02-28  6118   118    18  Wednesday   6   1   1   8
# 26  2024-02-21  3890   890    90  Wednesday   3   8   9   0
# 29  2024-02-14  7243   243    43  Wednesday   7   2   4   3
# 32  2024-02-07  8368   368    68  Wednesday   8   3   6   8
# 35  2024-01-31  8932   932    32  Wednesday   8   9   3   2
# 38  2024-01-24  7380   380    80  Wednesday   7   3   8   0
# 41  2024-01-17  1226   226    26  Wednesday   1   2   2   6
# 44  2024-01-10  8391   391    91  Wednesday   8   3   9   1
# 47  2024-01-03  3873   873    73  Wednesday   3   8   7   3
# 49  2023-12-27  8785   785    85  Wednesday   8   7   8   5
# 52  2023-12-20  9922   922    22  Wednesday   9   9   2   2
# 55  2023-12-13  2232   232    32  Wednesday   2   2   3   2
# 58  2023-12-06  4186   186    86  Wednesday   4   1   8   6
# 61  2023-11-29  5288   288    88  Wednesday   5   2   8   8
# 64  2023-11-22  4264   264    64  Wednesday   4   2   6   4
# 67  2023-11-15  5514   514    14  Wednesday   5   5   1   4
# 70  2023-11-08  7939   939    39  Wednesday   7   9   3   9
# 73  2023-11-01  5402   402     2  Wednesday   5   4   0   2
# 76  2023-10-25  0480   480    80  Wednesday   0   4   8   0
# 79  2023-10-18  6273   273    73  Wednesday   6   2   7   3
# 82  2023-10-11  9264   264    64  Wednesday   9   2   6   4
# 85  2023-10-04  9629   629    29  Wednesday   9   6   2   9
# 88  2023-09-27  0210   210    10  Wednesday   0   2   1   0
# 91  2023-09-20  7372   372    72  Wednesday   7   3   7   2
# 94  2023-09-13  8831   831    31  Wednesday   8   8   3   1
# 97  2023-09-06  1717   717    17  Wednesday   1   7   1   7
# 100 2023-08-30  2529   529    29  Wednesday   2   5   2   9
# 103 2023-08-23  3061    61    61  Wednesday   3   0   6   1
# 106 2023-08-16  1697   697    97  Wednesday   1   6   9   7
# 109 2023-08-09  3116   116    16  Wednesday   3   1   1   6
# 112 2023-08-02  7809   809     9  Wednesday   7   8   0   9
# 115 2023-07-26  1350   350    50  Wednesday   1   3   5   0
# 118 2023-07-19  5878   878    78  Wednesday   5   8   7   8
# 121 2023-07-12  1034    34    34  Wednesday   1   0   3   4
# 124 2023-07-05  0908   908     8  Wednesday   0   9   0   8
# 127 2023-06-28  2229   229    29  Wednesday   2   2   2   9
# 130 2023-06-21  7341   341    41  Wednesday   7   3   4   1
# 133 2023-06-14  2952   952    52  Wednesday   2   9   5   2
# 136 2023-06-07  0318   318    18  Wednesday   0   3   1   8
# 139 2023-05-31  7922   922    22  Wednesday   7   9   2   2
# 142 2023-05-24  2572   572    72  Wednesday   2   5   7   2
# 145 2023-05-17  9846   846    46  Wednesday   9   8   4   6
# 148 2023-05-10  8521   521    21  Wednesday   8   5   2   1

# %%
grouped_counts
# Out:
#    r4  Count
# 0   0      5
# 1   1      6
# 2   2      9
# 3   3      3
# 4   4      4
# 5   5      1
# 6   6      5
# 7   7      3
# 8   8      7
# 9   9      7

# %%
# เลขท้าย2ตัวที่ออกบ่อยสุด
grouped_counts = wed_1.groupby('top2').size().reset_index(name='Count')
max_count_row = grouped_counts[grouped_counts['Count'] == grouped_counts['Count'].max()]
max_count_row
# Out:
#     top2  Count
# 13    29      3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy
import os
import pickle

# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
lotto_ai
# Out:
#           date  เลข 4 ตัว  เลข 3 ตัว  เลข 2 ตัว  เลขล่าง  เลขบน  weekday_dum  \
# 0    5/22/2024       3710        710         10       37     10          NaN
# 1    5/20/2024        147        147         47        1     47          NaN
# 2    5/17/2024       8717        717         17       87     17          NaN
# 3    5/15/2024       9902        902          2       99      2          NaN
# 4    5/13/2024       3598        598         98       35     98          NaN
# ..         ...        ...        ...        ...      ...    ...          ...
# 152  5/19/2023       8573        573         73       85     73          6.0
# 153  5/17/2023       9846        846         46       98     46          4.0
# 154  5/15/2023       8649        649         49       86     49          2.0
# 155  5/12/2023       4077         77         77       40     77          6.0
# 156  5/10/2023       8521        521         21       85     21          4.0
#
#        weekday
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 152     Friday
# 153  Wednesday
# 154     Monday
# 155     Friday
# 156  Wednesday
#
# [157 rows x 8 columns]

# %%
lotto_ai['date'] = pd.to_datetime(lotto_ai['date'])

# %%
lotto_ai
# Out:
#           date  เลข 4 ตัว  เลข 3 ตัว  เลข 2 ตัว  เลขล่าง  เลขบน  weekday_dum  \
# 0   2024-05-22       3710        710         10       37     10          NaN
# 1   2024-05-20        147        147         47        1     47          NaN
# 2   2024-05-17       8717        717         17       87     17          NaN
# 3   2024-05-15       9902        902          2       99      2          NaN
# 4   2024-05-13       3598        598         98       35     98          NaN
# ..         ...        ...        ...        ...      ...    ...          ...
# 152 2023-05-19       8573        573         73       85     73          6.0
# 153 2023-05-17       9846        846         46       98     46          4.0
# 154 2023-05-15       8649        649         49       86     49          2.0
# 155 2023-05-12       4077         77         77       40     77          6.0
# 156 2023-05-10       8521        521         21       85     21          4.0
#
#        weekday
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 152     Friday
# 153  Wednesday
# 154     Monday
# 155     Friday
# 156  Wednesday
#
# [157 rows x 8 columns]

# %%
lt_2 = lotto_ai.copy()

# %%
lt_2
# Out:
#           date  เลข 4 ตัว  เลข 3 ตัว  เลข 2 ตัว  เลขล่าง  เลขบน  weekday_dum  \
# 0   2024-05-22       3710        710         10       37     10          NaN
# 1   2024-05-20        147        147         47        1     47          NaN
# 2   2024-05-17       8717        717         17       87     17          NaN
# 3   2024-05-15       9902        902          2       99      2          NaN
# 4   2024-05-13       3598        598         98       35     98          NaN
# ..         ...        ...        ...        ...      ...    ...          ...
# 152 2023-05-19       8573        573         73       85     73          6.0
# 153 2023-05-17       9846        846         46       98     46          4.0
# 154 2023-05-15       8649        649         49       86     49          2.0
# 155 2023-05-12       4077         77         77       40     77          6.0
# 156 2023-05-10       8521        521         21       85     21          4.0
#
#        weekday
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 152     Friday
# 153  Wednesday
# 154     Monday
# 155     Friday
# 156  Wednesday
#
# [157 rows x 8 columns]

# %%
sh = lt_2.shape

# %%
z = 1

# %%
lt_3 = lt_2.iloc[z:sh[0], 0:sh[1]]

# %%
lt_3
# Out:
#           date  เลข 4 ตัว  เลข 3 ตัว  เลข 2 ตัว  เลขล่าง  เลขบน  weekday_dum  \
# 1   2024-05-20        147        147         47        1     47          NaN
# 2   2024-05-17       8717        717         17       87     17          NaN
# 3   2024-05-15       9902        902          2       99      2          NaN
# 4   2024-05-13       3598        598         98       35     98          NaN
# 5   2024-05-10       1155        155         55       11     55          NaN
# ..         ...        ...        ...        ...      ...    ...          ...
# 152 2023-05-19       8573        573         73       85     73          6.0
# 153 2023-05-17       9846        846         46       98     46          4.0
# 154 2023-05-15       8649        649         49       86     49          2.0
# 155 2023-05-12       4077         77         77       40     77          6.0
# 156 2023-05-10       8521        521         21       85     21          4.0
#
#        weekday
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# ..         ...
# 152     Friday
# 153  Wednesday
# 154     Monday
# 155     Friday
# 156  Wednesday
#
# [156 rows x 8 columns]

# %% [markdown]
# # LSTM

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
dfp = lt_3.copy()

# %%
df = dfp.reset_index()

# %%
df
# Out:
#      index       date  เลข 4 ตัว  เลข 3 ตัว  เลข 2 ตัว  เลขล่าง  เลขบน  \
# 0        1 2024-05-20        147        147         47        1     47
# 1        2 2024-05-17       8717        717         17       87     17
# 2        3 2024-05-15       9902        902          2       99      2
# 3        4 2024-05-13       3598        598         98       35     98
# 4        5 2024-05-10       1155        155         55       11     55
# ..     ...        ...        ...        ...        ...      ...    ...
# 151    152 2023-05-19       8573        573         73       85     73
# 152    153 2023-05-17       9846        846         46       98     46
# 153    154 2023-05-15       8649        649         49       86     49
# 154    155 2023-05-12       4077         77         77       40     77
# 155    156 2023-05-10       8521        521         21       85     21
#
#      weekday_dum    weekday
# 0            NaN        NaN
# 1            NaN        NaN
# 2            NaN        NaN
# 3            NaN        NaN
# 4            NaN        NaN
# ..           ...        ...
# 151          6.0     Friday
# 152          4.0  Wednesday
# 153          2.0     Monday
# 154          6.0     Friday
# 155          4.0  Wednesday
#
# [156 rows x 9 columns]

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
df2 = df.copy()

# %%
df1 = df.copy()
df.drop(['index','date','เลข 4 ตัว','เลข 3 ตัว','เลข 2 ตัว','weekday_dum','weekday'], axis=1, inplace=True)

number_of_features = df.shape[1]

# %%
df
# Out:
#      เลขล่าง  เลขบน
# 0          1     47
# 1         87     17
# 2         99      2
# 3         35     98
# 4         11     55
# ..       ...    ...
# 151       85     73
# 152       98     46
# 153       86     49
# 154       40     77
# 155       85     21
#
# [156 rows x 2 columns]

# %%
df1.drop(['index','เลข 4 ตัว','เลข 3 ตัว','เลข 2 ตัว','weekday_dum','weekday'], axis=1, inplace=True)

# %%
df1
# Out:
#           date  เลขล่าง  เลขบน
# 0   2024-05-20        1     47
# 1   2024-05-17       87     17
# 2   2024-05-15       99      2
# 3   2024-05-13       35     98
# 4   2024-05-10       11     55
# ..         ...      ...    ...
# 151 2023-05-19       85     73
# 152 2023-05-17       98     46
# 153 2023-05-15       86     49
# 154 2023-05-12       40     77
# 155 2023-05-10       85     21
#
# [156 rows x 3 columns]

# %%
window_length = 7
window_length
# Out:
# 7

# %%
train = df.copy()
train.head((window_length+1))
# Out:
#    เลขล่าง  เลขบน
# 0        1     47
# 1       87     17
# 2       99      2
# 3       35     98
# 4       11     55
# 5       66     19
# 6       12     69
# 7       79     99

# %%
train_rows = train.values.shape[0]
train_samples = np.empty([ train_rows - window_length, window_length, number_of_features], dtype=float)
train_labels = np.empty([ train_rows - window_length, number_of_features], dtype=float)
for i in range(0, train_rows-window_length):
    train_samples[i] = train.iloc[i : i+window_length, 0 : number_of_features]
    train_labels[i] = train.iloc[i+window_length : i+window_length+1, 0 : number_of_features]

# %%
train.values.shape[0]
# Out:
# 156

# %%
train_samples[0]
# Out:
# array([[ 1., 47.],
#        [87., 17.],
#        [99.,  2.],
#        [35., 98.],
#        [11., 55.],
#        [66., 19.],
#        [12., 69.]])

# %%
train_labels[0]
# Out:
# array([79., 99.])

# %%
scaler = StandardScaler()
transformed_dataset = scaler.fit_transform(train.values)
scaled_train_samples = pd.DataFrame(data=transformed_dataset, index=train.index)

# %%
scaled_train_samples.head(window_length+1)
# Out:
#           0         1
# 0 -1.774915 -0.036171
# 1  1.141110 -1.037820
# 2  1.547997 -1.538645
# 3 -0.622068  1.666634
# 4 -1.435842  0.230936
# 5  0.429057 -0.971044
# 6 -1.401935  0.698372
# 7  0.869852  1.700022

# %%
x_train = np.empty([ train_rows - window_length, window_length, number_of_features], dtype=float)
y_train = np.empty([ train_rows - window_length, number_of_features], dtype=float)

for i in range(0, train_rows-window_length):
    x_train[i] = scaled_train_samples.iloc[i : i+window_length, 0 : number_of_features]
    y_train[i] = scaled_train_samples.iloc[i+window_length : i+window_length+1, 0 : number_of_features]

# %%
y_train
# Out:
# array([[ 0.86985161,  1.70002208],
#        [-0.35080972,  0.09738261],
#        [ 1.14110969, -0.90426706],
#        [-0.96114039,  0.13077093],
#        [ 1.3784605 ,  1.39952718],
#        [-0.38471698,  0.76514905],
#        [ 1.3784605 , -0.53699552],
#        [-0.35080972,  1.36613885],
#        [ 1.41236776, -0.10294733],
#        [ 0.49687176, -1.47186854],
#        [-1.16458394,  0.36448919],
#        [-1.30021298,  1.59985711],
#        [-0.99504765, -0.93765538],
#        [-1.50365653, -1.23815029],
#        [-0.85941861,  0.33110086],
#        [ 0.80203709, -1.4050919 ],
#        [ 1.00548065, -1.53864519],
#        [ 0.02217013,  1.33275053],
#        [-1.1984912 ,  0.29771254],
#        [-0.18127342,  0.26432422],
#        [ 0.36124272,  0.99886731],
#        [ 0.19170643, -1.104597  ],
#        [ 0.4629645 , -0.70393713],
#        [ 0.25952095, -1.00443203],
#        [ 1.07329517,  1.59985711],
#        [-0.55425328,  0.79853738],
#        [-0.52034602,  1.39952718],
#        [ 1.5479968 , -0.33666558],
#        [ 1.34455324,  1.39952718],
#        [ 0.6325008 , -0.16972397],
#        [ 0.6325008 , -1.104597  ],
#        [ 0.97157339,  0.09738261],
#        [ 1.00548065,  0.66498409],
#        [-1.06286216,  0.49804247],
#        [-0.31690246, -1.17137364],
#        [ 1.2089242 , -0.53699552],
#        [ 1.03938791,  1.70002208],
#        [-1.26630572, -0.87087874],
#        [ 0.66640806,  1.06564395],
#        [-0.79160409,  1.70002208],
#        [ 1.41236776, -0.67054881],
#        [-1.40193476, -0.73732545],
#        [-1.23239846, -0.8041021 ],
#        [-1.23239846, -0.8041021 ],
#        [ 1.00548065,  1.4329155 ],
#        [-0.31690246,  0.89870234],
#        [-0.58816054,  0.89870234],
#        [-0.52034602,  0.8319257 ],
#        [ 0.56468628,  1.56646879],
#        [ 1.14110969,  1.23258556],
#        [ 0.12389191,  0.63159576],
#        [-0.35080972,  0.19754757],
#        [ 1.5479968 , -0.87087874],
#        [ 1.24283146, -0.8041021 ],
#        [ 0.93766613,  1.26597389],
#        [-1.06286216, -0.53699552],
#        [ 0.25952095,  1.36613885],
#        [ 0.02217013,  0.66498409],
#        [-0.41862424,  1.26597389],
#        [ 0.97157339, -0.069559  ],
#        [-0.99504765,  1.70002208],
#        [-0.04564439,  1.33275053],
#        [ 0.05607739, -1.33831525],
#        [-0.48643876, -1.27153861],
#        [-0.38471698,  0.5314308 ],
#        [ 0.05607739,  0.09738261],
#        [ 0.02217013,  0.8319257 ],
#        [ 0.05607739, -1.13798532],
#        [ 0.2934282 ,  0.19754757],
#        [-1.53756379,  1.03225563],
#        [ 0.86985161, -0.30327726],
#        [-1.1984912 , -0.67054881],
#        [-1.06286216, -0.8041021 ],
#        [ 0.02217013, -1.53864519],
#        [-1.50365653, -0.8041021 ],
#        [-1.40193476, -0.87087874],
#        [-1.67319283,  1.06564395],
#        [ 1.03938791,  1.29936221],
#        [-1.13067668, -1.37170357],
#        [ 0.2934282 ,  0.8319257 ],
#        [ 1.31064598, -0.00278236],
#        [ 0.22561369, -0.73732545],
#        [ 1.31064598,  0.5314308 ],
#        [ 0.15779917, -1.60542183],
#        [-1.16458394,  0.93209066],
#        [ 1.44627502, -0.63716048],
#        [ 1.51408954,  0.46465415],
#        [-0.4525315 , -1.27153861],
#        [-1.74100735, -1.27153861],
#        [-0.18127342, -0.73732545],
#        [-0.21518068, -1.4050919 ],
#        [ 0.66640806,  0.79853738],
#        [-0.21518068, -1.60542183],
#        [-0.38471698,  1.70002208],
#        [ 1.17501694, -0.57038384],
#        [ 1.27673872, -0.33666558],
#        [-1.13067668, -0.47021887],
#        [-1.23239846, -1.03782035],
#        [ 1.51408954,  1.70002208],
#        [ 0.97157339, -0.50360719],
#        [-0.96114039, -0.63716048],
#        [ 0.36124272,  1.06564395],
#        [ 0.15779917, -1.50525686],
#        [-0.79160409,  0.43126583],
#        [ 1.24283146, -1.50525686],
#        [ 1.34455324, -0.13633565],
#        [-1.26630572,  1.63324543],
#        [ 0.70031532, -0.50360719],
#        [ 1.14110969, -1.104597  ],
#        [-0.75769683, -1.07120867],
#        [ 0.59859354, -0.43683055],
#        [-1.63928557, -0.40344223],
#        [ 0.83594435, -1.30492693],
#        [-0.24908794, -1.43848022],
#        [ 0.56468628, -1.57203351],
#        [-1.3680275 ,  0.06399428],
#        [-1.70710009,  1.39952718],
#        [ 1.2089242 , -0.53699552],
#        [ 0.15779917,  0.99886731],
#        [ 0.12389191, -0.93765538],
#        [-0.96114039,  1.33275053],
#        [-1.46974927, -0.47021887],
#        [ 1.51408954, -0.8041021 ],
#        [ 1.34455324, -0.30327726],
#        [-1.50365653, -1.33831525],
#        [ 0.42905724,  0.76514905],
#        [-1.1984912 , -0.43683055],
#        [-1.06286216, -0.63716048],
#        [ 0.90375887,  0.59820744],
#        [-0.18127342,  0.73176073],
#        [ 0.66640806, -0.23650062],
#        [-1.50365653,  1.1324206 ],
#        [-1.63928557, -1.07120867],
#        [-0.82551135,  0.13077093],
#        [ 1.14110969, -0.83749042],
#        [ 0.39514998,  0.69837241],
#        [-1.70710009, -1.00443203],
#        [ 0.49687176,  1.56646879],
#        [-1.30021298,  0.26432422],
#        [ 0.86985161, -0.87087874],
#        [ 0.49687176, -0.43683055],
#        [-0.24908794,  0.63159576],
#        [-0.96114039,  0.79853738],
#        [ 0.02217013,  1.29936221],
#        [ 1.07329517,  0.8319257 ],
#        [ 1.51408954, -0.069559  ],
#        [ 1.10720243,  0.03060596],
#        [-0.4525315 ,  0.96547899],
#        [ 1.07329517, -0.90426706]])

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Bidirectional, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import mse

# %%
# Initialising the RNN
model = Sequential()
# Adding the input layer and the LSTM layer
model.add(Bidirectional(LSTM(240,
                        input_shape = (window_length, number_of_features),
                        return_sequences = True)))
# Adding a first Dropout layer
model.add(Dropout(0.2))
# Adding a second LSTM layer
model.add(Bidirectional(LSTM(240,
                        input_shape = (window_length, number_of_features),
                        return_sequences = True)))
# Adding a second Dropout layer
model.add(Dropout(0.2))
# Adding a third LSTM layer
model.add(Bidirectional(LSTM(240,
                        input_shape = (window_length, number_of_features),
                        return_sequences = True)))
# Adding a fourth LSTM layer
model.add(Bidirectional(LSTM(240,
                        input_shape = (window_length, number_of_features),
                        return_sequences = False)))
# Adding a third Dropout layer
model.add(Dropout(0.2))
# Adding the first output layer
model.add(Dense(70))
# Adding the last output layer
model.add(Dense(number_of_features))

# %%
model.compile(optimizer=Adam(learning_rate=0.005), loss ='mse', metrics=['accuracy'])

# %%
model.fit(x=x_train, y=y_train, batch_size=128, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 2/2 - 18s - loss: 0.9903 - accuracy: 0.4698 - 18s/epoch - 9s/step
# Epoch 2/100
# 2/2 - 1s - loss: 1.4535 - accuracy: 0.4564 - 733ms/epoch - 367ms/step
# Epoch 3/100
# 2/2 - 1s - loss: 1.0331 - accuracy: 0.5302 - 742ms/epoch - 371ms/step
# Epoch 4/100
# 2/2 - 1s - loss: 1.0177 - accuracy: 0.4765 - 740ms/epoch - 370ms/step
# Epoch 5/100
# 2/2 - 1s - loss: 0.9804 - accuracy: 0.4295 - 743ms/epoch - 372ms/step
# Epoch 6/100
# 2/2 - 1s - loss: 1.0284 - accuracy: 0.5839 - 714ms/epoch - 357ms/step
# Epoch 7/100
# 2/2 - 1s - loss: 0.9990 - accuracy: 0.4228 - 733ms/epoch - 367ms/step
# Epoch 8/100
# 2/2 - 1s - loss: 0.9909 - accuracy: 0.4631 - 756ms/epoch - 378ms/step
# Epoch 9/100
# 2/2 - 1s - loss: 0.9700 - accuracy: 0.6107 - 1s/epoch - 604ms/step
# Epoch 10/100
# 2/2 - 1s - loss: 0.9960 - accuracy: 0.5705 - 1s/epoch - 624ms/step
# Epoch 11/100
# 2/2 - 1s - loss: 0.9535 - accuracy: 0.6040 - 1s/epoch - 601ms/step
# Epoch 12/100
# 2/2 - 1s - loss: 0.9785 - accuracy: 0.4698 - 1s/epoch - 663ms/step
# Epoch 13/100
# 2/2 - 1s - loss: 0.9627 - accuracy: 0.5503 - 725ms/epoch - 363ms/step
# Epoch 14/100
# 2/2 - 1s - loss: 0.9534 - accuracy: 0.5705 - 735ms/epoch - 367ms/step
# Epoch 15/100
# 2/2 - 1s - loss: 0.9369 - accuracy: 0.5503 - 745ms/epoch - 373ms/step
# Epoch 16/100
# 2/2 - 1s - loss: 0.9297 - accuracy: 0.5436 - 736ms/epoch - 368ms/step
# Epoch 17/100
# 2/2 - 1s - loss: 0.9221 - accuracy: 0.5839 - 745ms/epoch - 373ms/step
# Epoch 18/100
# 2/2 - 1s - loss: 0.9384 - accuracy: 0.5973 - 746ms/epoch - 373ms/step
# Epoch 19/100
# 2/2 - 1s - loss: 0.9334 - accuracy: 0.6577 - 733ms/epoch - 367ms/step
# Epoch 20/100
# 2/2 - 1s - loss: 0.9402 - accuracy: 0.5705 - 763ms/epoch - 382ms/step
# Epoch 21/100
# 2/2 - 1s - loss: 0.9496 - accuracy: 0.5436 - 730ms/epoch - 365ms/step
# Epoch 22/100
# 2/2 - 1s - loss: 0.9126 - accuracy: 0.5973 - 733ms/epoch - 366ms/step
# Epoch 23/100
# 2/2 - 1s - loss: 0.9097 - accuracy: 0.6174 - 723ms/epoch - 361ms/step
# Epoch 24/100
# 2/2 - 1s - loss: 0.8922 - accuracy: 0.5906 - 756ms/epoch - 378ms/step
# Epoch 25/100
# 2/2 - 1s - loss: 0.8791 - accuracy: 0.5772 - 747ms/epoch - 373ms/step
# Epoch 26/100
# 2/2 - 1s - loss: 0.8712 - accuracy: 0.5705 - 985ms/epoch - 492ms/step
# Epoch 27/100
# 2/2 - 1s - loss: 0.8716 - accuracy: 0.5973 - 1s/epoch - 622ms/step
# Epoch 28/100
# 2/2 - 1s - loss: 0.8787 - accuracy: 0.6040 - 1s/epoch - 617ms/step
# Epoch 29/100
# 2/2 - 1s - loss: 0.8501 - accuracy: 0.5906 - 1s/epoch - 644ms/step
# Epoch 30/100
# 2/2 - 1s - loss: 0.8694 - accuracy: 0.6174 - 960ms/epoch - 480ms/step
# Epoch 31/100
# 2/2 - 1s - loss: 0.8592 - accuracy: 0.6107 - 732ms/epoch - 366ms/step
# Epoch 32/100
# 2/2 - 1s - loss: 0.8603 - accuracy: 0.5638 - 740ms/epoch - 370ms/step
# Epoch 33/100
# 2/2 - 1s - loss: 0.8392 - accuracy: 0.5705 - 734ms/epoch - 367ms/step
# Epoch 34/100
# 2/2 - 1s - loss: 0.8000 - accuracy: 0.6107 - 729ms/epoch - 364ms/step
# Epoch 35/100
# 2/2 - 1s - loss: 0.8476 - accuracy: 0.6107 - 723ms/epoch - 362ms/step
# Epoch 36/100
# 2/2 - 1s - loss: 0.8305 - accuracy: 0.6443 - 732ms/epoch - 366ms/step
# Epoch 37/100
# 2/2 - 1s - loss: 0.7660 - accuracy: 0.6443 - 705ms/epoch - 353ms/step
# Epoch 38/100
# 2/2 - 1s - loss: 0.7770 - accuracy: 0.6040 - 734ms/epoch - 367ms/step
# Epoch 39/100
# 2/2 - 1s - loss: 0.7323 - accuracy: 0.6309 - 716ms/epoch - 358ms/step
# Epoch 40/100
# 2/2 - 1s - loss: 0.7192 - accuracy: 0.6913 - 723ms/epoch - 362ms/step
# Epoch 41/100
# 2/2 - 1s - loss: 0.7234 - accuracy: 0.6510 - 743ms/epoch - 372ms/step
# Epoch 42/100
# 2/2 - 1s - loss: 0.6862 - accuracy: 0.6174 - 728ms/epoch - 364ms/step
# Epoch 43/100
# 2/2 - 1s - loss: 0.6473 - accuracy: 0.6779 - 723ms/epoch - 361ms/step
# Epoch 44/100
# 2/2 - 1s - loss: 0.6619 - accuracy: 0.6779 - 1s/epoch - 578ms/step
# Epoch 45/100
# 2/2 - 1s - loss: 0.6153 - accuracy: 0.7248 - 1s/epoch - 596ms/step
# Epoch 46/100
# 2/2 - 1s - loss: 0.6074 - accuracy: 0.7114 - 1s/epoch - 609ms/step
# Epoch 47/100
# 2/2 - 1s - loss: 0.6065 - accuracy: 0.6846 - 1s/epoch - 645ms/step
# Epoch 48/100
# 2/2 - 1s - loss: 0.5452 - accuracy: 0.7047 - 801ms/epoch - 401ms/step
# Epoch 49/100
# 2/2 - 1s - loss: 0.5774 - accuracy: 0.7181 - 712ms/epoch - 356ms/step
# Epoch 50/100
# 2/2 - 1s - loss: 0.6624 - accuracy: 0.7181 - 717ms/epoch - 359ms/step
# Epoch 51/100
# 2/2 - 1s - loss: 0.6509 - accuracy: 0.6711 - 716ms/epoch - 358ms/step
# Epoch 52/100
# 2/2 - 1s - loss: 0.5960 - accuracy: 0.7651 - 742ms/epoch - 371ms/step
# Epoch 53/100
# 2/2 - 1s - loss: 0.5951 - accuracy: 0.6644 - 696ms/epoch - 348ms/step
# Epoch 54/100
# 2/2 - 1s - loss: 0.5524 - accuracy: 0.6846 - 723ms/epoch - 361ms/step
# Epoch 55/100
# 2/2 - 1s - loss: 0.4971 - accuracy: 0.7718 - 758ms/epoch - 379ms/step
# Epoch 56/100
# 2/2 - 1s - loss: 0.5199 - accuracy: 0.7315 - 766ms/epoch - 383ms/step
# Epoch 57/100
# 2/2 - 1s - loss: 0.4490 - accuracy: 0.7248 - 1s/epoch - 501ms/step
# Epoch 58/100
# 2/2 - 1s - loss: 0.4018 - accuracy: 0.7517 - 732ms/epoch - 366ms/step
# Epoch 59/100
# 2/2 - 1s - loss: 0.3537 - accuracy: 0.7785 - 748ms/epoch - 374ms/step
# Epoch 60/100
# 2/2 - 1s - loss: 0.2887 - accuracy: 0.8591 - 736ms/epoch - 368ms/step
# Epoch 61/100
# 2/2 - 1s - loss: 0.3170 - accuracy: 0.8188 - 1s/epoch - 506ms/step
# Epoch 62/100
# 2/2 - 1s - loss: 0.2722 - accuracy: 0.8255 - 1s/epoch - 623ms/step
# Epoch 63/100
# 2/2 - 1s - loss: 0.2544 - accuracy: 0.8389 - 1s/epoch - 614ms/step
# Epoch 64/100
# 2/2 - 1s - loss: 0.2970 - accuracy: 0.7987 - 1s/epoch - 635ms/step
# Epoch 65/100
# 2/2 - 1s - loss: 0.2467 - accuracy: 0.8591 - 938ms/epoch - 469ms/step
# Epoch 66/100
# 2/2 - 1s - loss: 0.2478 - accuracy: 0.8591 - 728ms/epoch - 364ms/step
# Epoch 67/100
# 2/2 - 1s - loss: 0.2136 - accuracy: 0.9128 - 732ms/epoch - 366ms/step
# Epoch 68/100
# 2/2 - 1s - loss: 0.2539 - accuracy: 0.8591 - 738ms/epoch - 369ms/step
# Epoch 69/100
# 2/2 - 1s - loss: 0.1884 - accuracy: 0.8926 - 742ms/epoch - 371ms/step
# Epoch 70/100
# 2/2 - 1s - loss: 0.2092 - accuracy: 0.8725 - 733ms/epoch - 366ms/step
# Epoch 71/100
# 2/2 - 1s - loss: 0.1805 - accuracy: 0.8322 - 720ms/epoch - 360ms/step
# Epoch 72/100
# 2/2 - 1s - loss: 0.1587 - accuracy: 0.8255 - 724ms/epoch - 362ms/step
# Epoch 73/100
# 2/2 - 1s - loss: 0.1432 - accuracy: 0.8792 - 732ms/epoch - 366ms/step
# Epoch 74/100
# 2/2 - 1s - loss: 0.1729 - accuracy: 0.8859 - 723ms/epoch - 361ms/step
# Epoch 75/100
# 2/2 - 1s - loss: 0.1474 - accuracy: 0.9128 - 725ms/epoch - 362ms/step
# Epoch 76/100
# 2/2 - 1s - loss: 0.1348 - accuracy: 0.9128 - 746ms/epoch - 373ms/step
# Epoch 77/100
# 2/2 - 1s - loss: 0.1187 - accuracy: 0.9329 - 749ms/epoch - 375ms/step
# Epoch 78/100
# 2/2 - 1s - loss: 0.1157 - accuracy: 0.9396 - 711ms/epoch - 356ms/step
# Epoch 79/100
# 2/2 - 1s - loss: 0.1418 - accuracy: 0.9128 - 1s/epoch - 596ms/step
# Epoch 80/100
# 2/2 - 1s - loss: 0.1157 - accuracy: 0.9329 - 1s/epoch - 619ms/step
# Epoch 81/100
# 2/2 - 1s - loss: 0.1162 - accuracy: 0.9195 - 1s/epoch - 588ms/step
# Epoch 82/100
# 2/2 - 1s - loss: 0.1163 - accuracy: 0.9262 - 1s/epoch - 665ms/step
# Epoch 83/100
# 2/2 - 1s - loss: 0.1006 - accuracy: 0.9597 - 795ms/epoch - 398ms/step
# Epoch 84/100
# 2/2 - 1s - loss: 0.0905 - accuracy: 0.9329 - 712ms/epoch - 356ms/step
# Epoch 85/100
# 2/2 - 1s - loss: 0.1007 - accuracy: 0.8859 - 728ms/epoch - 364ms/step
# Epoch 86/100
# 2/2 - 1s - loss: 0.0840 - accuracy: 0.9128 - 733ms/epoch - 366ms/step
# Epoch 87/100
# 2/2 - 1s - loss: 0.0923 - accuracy: 0.9463 - 719ms/epoch - 359ms/step
# Epoch 88/100
# 2/2 - 1s - loss: 0.0924 - accuracy: 0.9195 - 732ms/epoch - 366ms/step
# Epoch 89/100
# 2/2 - 1s - loss: 0.0830 - accuracy: 0.9396 - 732ms/epoch - 366ms/step
# Epoch 90/100
# 2/2 - 1s - loss: 0.0697 - accuracy: 0.9262 - 781ms/epoch - 391ms/step
# Epoch 91/100
# 2/2 - 1s - loss: 0.0760 - accuracy: 0.9597 - 729ms/epoch - 365ms/step
# Epoch 92/100
# 2/2 - 1s - loss: 0.0717 - accuracy: 0.9597 - 749ms/epoch - 375ms/step
# Epoch 93/100
# 2/2 - 1s - loss: 0.0640 - accuracy: 0.9664 - 746ms/epoch - 373ms/step
# Epoch 94/100
# 2/2 - 1s - loss: 0.0883 - accuracy: 0.9128 - 731ms/epoch - 365ms/step
# Epoch 95/100
# 2/2 - 1s - loss: 0.0689 - accuracy: 0.9128 - 763ms/epoch - 381ms/step
# Epoch 96/100
# 2/2 - 1s - loss: 0.0630 - accuracy: 0.9530 - 928ms/epoch - 464ms/step
# Epoch 97/100
# 2/2 - 1s - loss: 0.0569 - accuracy: 0.9732 - 1s/epoch - 625ms/step
# Epoch 98/100
# 2/2 - 1s - loss: 0.0486 - accuracy: 0.9732 - 1s/epoch - 624ms/step
# Epoch 99/100
# 2/2 - 1s - loss: 0.0455 - accuracy: 0.9664 - 1s/epoch - 642ms/step
# Epoch 100/100
# 2/2 - 1s - loss: 0.0475 - accuracy: 0.9396 - 1s/epoch - 533ms/step

# %% [markdown]
# ### Prediction without rounding up or down the results

# %%
df1.rename(columns={'date': 'Date'},inplace=True)

# %%
print('-' * 40)
print('Prediction vs. GoundTruth without rounding up or down')
for i in range(1,10):
  test = df1.copy()
  test = test.tail((window_length+10-i))
  test = test.head((window_length+1))
  test_Date = df1.iloc[ (test.tail().index[-1]) ]['Date']
  test1 = test.head((window_length))
  test1.drop(['Date'], axis=1, inplace=True)
  test1 = np.array(test1)
  x_test = scaler.transform(test1)
  y_test_pred = model.predict(np.array([x_test]))
  y_test_true = test.drop(['Date'], axis=1, inplace=True)
  y_test_true = test.tail(1)
  print('Drawing  Date', test_Date)
  print('Prediction:\t', scaler.inverse_transform(y_test_pred).astype(int)[0])
  print('GoundTruth:\t', np.array(y_test_true)[0])
  print('-' * 40)
# Out:
# ----------------------------------------
# Prediction vs. GoundTruth without rounding up or down
# 1/1 [==============================] - 4s 4s/step
# Drawing  Date 2023-05-29 00:00:00
# Prediction:	 [72 40]
# GoundTruth:	 [68 35]
# ----------------------------------------
# 1/1 [==============================] - 0s 50ms/step
# Drawing  Date 2023-05-26 00:00:00
# Prediction:	 [48 54]
# GoundTruth:	 [46 67]
# ----------------------------------------
# 1/1 [==============================] - 0s 66ms/step
# Drawing  Date 2023-05-24 00:00:00
# Prediction:	 [29 67]
# GoundTruth:	 [25 72]
# ----------------------------------------
# 1/1 [==============================] - 0s 63ms/step
# Drawing  Date 2023-05-22 00:00:00
# Prediction:	 [56 85]
# GoundTruth:	 [54 87]
# ----------------------------------------
# 1/1 [==============================] - 0s 59ms/step
# Drawing  Date 2023-05-19 00:00:00
# Prediction:	 [78 63]
# GoundTruth:	 [85 73]
# ----------------------------------------
# 1/1 [==============================] - 0s 55ms/step
# Drawing  Date 2023-05-17 00:00:00
# Prediction:	 [91 39]
# GoundTruth:	 [98 46]
# ----------------------------------------
# 1/1 [==============================] - 0s 52ms/step
# Drawing  Date 2023-05-15 00:00:00
# Prediction:	 [75 40]
# GoundTruth:	 [86 49]
# ----------------------------------------
# 1/1 [==============================] - 0s 60ms/step
# Drawing  Date 2023-05-12 00:00:00
# Prediction:	 [41 79]
# GoundTruth:	 [40 77]
# ----------------------------------------
# 1/1 [==============================] - 0s 54ms/step
# Drawing  Date 2023-05-10 00:00:00
# Prediction:	 [86 23]
# GoundTruth:	 [85 21]
# ----------------------------------------

# %% [markdown]
# ### Prediction with rounding up the results

# %%
print('-' * 40)
print('Prediction vs. GoundTruth with rounding up')
for i in range(1,10):
  test = df1.copy()
  test = test.tail((window_length+10-i))
  test = test.head((window_length+1))
  test_Date = df1.iloc[ (test.tail().index[-1]) ]['Date']
  test1 = test.head((window_length))
  test1.drop(['Date'], axis=1, inplace=True)
  test1 = np.array(test1)
  x_test = scaler.transform(test1)
  y_test_pred = model.predict(np.array([x_test]))
  y_test_true = test.drop(['Date'], axis=1, inplace=True)
  y_test_true = test.tail(1)
  print('Drawing  Date', test_Date)
  print('Prediction:\t', scaler.inverse_transform(y_test_pred).astype(int)[0]+1)
  print('GoundTruth:\t', np.array(y_test_true)[0])
  print('-' * 40)
# Out:
# ----------------------------------------
# Prediction vs. GoundTruth with rounding up
# 1/1 [==============================] - 0s 39ms/step
# Drawing  Date 2023-05-29 00:00:00
# Prediction:	 [73 41]
# GoundTruth:	 [68 35]
# ----------------------------------------
# 1/1 [==============================] - 0s 35ms/step
# Drawing  Date 2023-05-26 00:00:00
# Prediction:	 [49 55]
# GoundTruth:	 [46 67]
# ----------------------------------------
# 1/1 [==============================] - 0s 35ms/step
# Drawing  Date 2023-05-24 00:00:00
# Prediction:	 [30 68]
# GoundTruth:	 [25 72]
# ----------------------------------------
# 1/1 [==============================] - 0s 40ms/step
# Drawing  Date 2023-05-22 00:00:00
# Prediction:	 [57 86]
# GoundTruth:	 [54 87]
# ----------------------------------------
# 1/1 [==============================] - 0s 34ms/step
# Drawing  Date 2023-05-19 00:00:00
# Prediction:	 [79 64]
# GoundTruth:	 [85 73]
# ----------------------------------------
# 1/1 [==============================] - 0s 33ms/step
# Drawing  Date 2023-05-17 00:00:00
# Prediction:	 [92 40]
# GoundTruth:	 [98 46]
# ----------------------------------------
# 1/1 [==============================] - 0s 40ms/step
# Drawing  Date 2023-05-15 00:00:00
# Prediction:	 [76 41]
# GoundTruth:	 [86 49]
# ----------------------------------------
# 1/1 [==============================] - 0s 33ms/step
# Drawing  Date 2023-05-12 00:00:00
# Prediction:	 [42 80]
# GoundTruth:	 [40 77]
# ----------------------------------------
# 1/1 [==============================] - 0s 34ms/step
# Drawing  Date 2023-05-10 00:00:00
# Prediction:	 [87 24]
# GoundTruth:	 [85 21]
# ----------------------------------------

# %% [markdown]
# ### Predict the Future Drawing Results on June 1, 2o24

# %%
next_Date = '2024-05-20'
print('-' * 40)
print('Predict the Future Drawing on 4/16/2024')
next = df.copy()
next = next.tail((window_length))
next = np.array(next)
x_next = scaler.transform(next)
y_next_pred = model.predict(np.array([x_next]))
print('Drawing  Date', next_Date)
print('Prediction without rounding up or down:\t', scaler.inverse_transform(y_next_pred).astype(int)[0])
print('Prediction with rounding up           :\t', scaler.inverse_transform(y_next_pred).astype(int)[0]+1)
print('Prediction with rounding down         :\t', scaler.inverse_transform(y_next_pred).astype(int)[0]-1)
print('-' * 40)
# Out:
# ----------------------------------------
# Predict the Future Drawing on 4/16/2024
# 1/1 [==============================] - 0s 120ms/step
# Drawing  Date 2024-05-20
# Prediction without rounding up or down:	 [59 24]
# Prediction with rounding up           :	 [60 25]
# Prediction with rounding down         :	 [58 23]
# ----------------------------------------

# %%
filtered_df = lt_2[lt_2['date'] == next_Date]
filtered_df[['date', 'เลขล่าง','เลขบน']]
# Out:
#         date  เลขล่าง  เลขบน
# 1 2024-05-20        1     47
