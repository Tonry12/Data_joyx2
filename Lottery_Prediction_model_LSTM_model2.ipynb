# %% [markdown]
# <a href="https://colab.research.google.com/github/Tonry12/Data_joyx2/blob/main/Lottery_Prediction_model_LSTM_model2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PrepareDATA

# %% [markdown]
# Link: https://medium.com/@polanitzer/forecasting-the-next-winning-numbers-in-the-texas-lottery-mega-millions-drawing-using-a-deep-4c37ee6d30f0

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy
import os
import pickle

# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
lotto = pd.read_csv('/content/drive/MyDrive/SPN/Predictive lottery.xlsx - since 30 years ago.csv')

# %%
lotto = lotto.drop(columns=['Date','Unnamed: 1','Unnamed: 2','Unnamed: 3'])

# %%
lotto
# Out:
#           DATE  รางวัลที่ 1  2 ตัวบน  3 ตัวบน  2 ตัวล่าง  3 ตัวหน้า  \
# 0    5/16/2024       205690       90      690         60        747
# 1     5/2/2024       980116       16      116         17        104
# 2    4/16/2024       943598       98      598         79        727
# 3     4/1/2024       803481       81      481         90        122
# 4    3/16/2024       997626       26      626         78        509
# ..         ...          ...      ...      ...        ...        ...
# 717  5/16/1994      2071764       64      764         29         93
# 718   5/2/1994      3072877       77      877         69        535
# 719  4/16/1994      7893913       13      913         21        785
# 720   4/1/1994      4269815       15      815         29        675
# 721  3/16/1994      1723336       36      336         19        382
#
#      3 ตัวหน้า.1  3 ตัวล่าง  3 ตัวล่าง.1  weekday_dum    weekday
# 0            885         70          137            7   Saturday
# 1            763        634          833            4  Wednesday
# 2            729        154          200            3    Tuesday
# 3            809        559          947            2     Monday
# 4            571        329          794            7   Saturday
# ..           ...        ...          ...          ...        ...
# 717          544        535          746            2     Monday
# 718          317        170          521            2     Monday
# 719          982        151          594            7   Saturday
# 720           35        704          868            6     Friday
# 721          166        515          185            4  Wednesday
#
# [722 rows x 11 columns]

# %%
lotto.isnull().any()
# Out:
# DATE           False
# รางวัลที่ 1    False
# 2 ตัวบน        False
# 3 ตัวบน        False
# 2 ตัวล่าง      False
# 3 ตัวหน้า      False
# 3 ตัวหน้า.1    False
# 3 ตัวล่าง      False
# 3 ตัวล่าง.1    False
# weekday_dum    False
# weekday        False
# dtype: bool

# %%
lotto.rename(columns={'DATE': 'Date','รางวัลที่ 1': '1st','3 ตัวบน':'top3','2 ตัวล่าง':'up2'},inplace=True)

# %%
lotto
# Out:
#           Date      1st  2 ตัวบน  top3  up2  3 ตัวหน้า  3 ตัวหน้า.1  \
# 0    5/16/2024   205690       90   690   60        747          885
# 1     5/2/2024   980116       16   116   17        104          763
# 2    4/16/2024   943598       98   598   79        727          729
# 3     4/1/2024   803481       81   481   90        122          809
# 4    3/16/2024   997626       26   626   78        509          571
# ..         ...      ...      ...   ...  ...        ...          ...
# 717  5/16/1994  2071764       64   764   29         93          544
# 718   5/2/1994  3072877       77   877   69        535          317
# 719  4/16/1994  7893913       13   913   21        785          982
# 720   4/1/1994  4269815       15   815   29        675           35
# 721  3/16/1994  1723336       36   336   19        382          166
#
#      3 ตัวล่าง  3 ตัวล่าง.1  weekday_dum    weekday
# 0           70          137            7   Saturday
# 1          634          833            4  Wednesday
# 2          154          200            3    Tuesday
# 3          559          947            2     Monday
# 4          329          794            7   Saturday
# ..         ...          ...          ...        ...
# 717        535          746            2     Monday
# 718        170          521            2     Monday
# 719        151          594            7   Saturday
# 720        704          868            6     Friday
# 721        515          185            4  Wednesday
#
# [722 rows x 11 columns]

# %%
ls= lotto.iloc[:,9:11]

# %%
lu= lotto.iloc[:,0:5]

# %%
lt = pd.concat([lu, ls], axis=1)

# %%
lt
# Out:
#           Date      1st  2 ตัวบน  top3  up2  weekday_dum    weekday
# 0    5/16/2024   205690       90   690   60            7   Saturday
# 1     5/2/2024   980116       16   116   17            4  Wednesday
# 2    4/16/2024   943598       98   598   79            3    Tuesday
# 3     4/1/2024   803481       81   481   90            2     Monday
# 4    3/16/2024   997626       26   626   78            7   Saturday
# ..         ...      ...      ...   ...  ...          ...        ...
# 717  5/16/1994  2071764       64   764   29            2     Monday
# 718   5/2/1994  3072877       77   877   69            2     Monday
# 719  4/16/1994  7893913       13   913   21            7   Saturday
# 720   4/1/1994  4269815       15   815   29            6     Friday
# 721  3/16/1994  1723336       36   336   19            4  Wednesday
#
# [722 rows x 7 columns]

# %%
lt = lt.drop(columns=['2 ตัวบน'])

# %%
lt
# Out:
#           Date      1st  top3  up2  weekday_dum    weekday
# 0    5/16/2024   205690   690   60            7   Saturday
# 1     5/2/2024   980116   116   17            4  Wednesday
# 2    4/16/2024   943598   598   79            3    Tuesday
# 3     4/1/2024   803481   481   90            2     Monday
# 4    3/16/2024   997626   626   78            7   Saturday
# ..         ...      ...   ...  ...          ...        ...
# 717  5/16/1994  2071764   764   29            2     Monday
# 718   5/2/1994  3072877   877   69            2     Monday
# 719  4/16/1994  7893913   913   21            7   Saturday
# 720   4/1/1994  4269815   815   29            6     Friday
# 721  3/16/1994  1723336   336   19            4  Wednesday
#
# [722 rows x 6 columns]

# %%
lt.dtypes
# Out:
# Date           object
# 1st             int64
# top3            int64
# up2             int64
# weekday_dum     int64
# weekday        object
# dtype: object

# %%
more = lt[lt['1st'] >= 999999]
more.count()
# Out:
# Date           20
# 1st            20
# top3           20
# up2            20
# weekday_dum    20
# weekday        20
# dtype: int64

# %%
lt = lt[lt['1st'] <= 999999]

# %%
lt['up2'] = lt['up2'].apply(lambda x: '{:02}'.format(x))

# %%
lt['top3'] = lt['top3'].apply(lambda x: '{:03}'.format(x))

# %%
lt['Date'] = pd.to_datetime(lt['Date'])
plt.figure(figsize=(10,6))
plt.plot(lt['Date'], lt['1st'])
plt.title('Winner Over Time')
plt.xlabel('Date')
plt.ylabel('Winner')

plt.show()

# %%
sns.boxplot(data=lt['1st'])
# Out:
# <Axes: ylabel='1st'>

# %%
sns.boxplot(data=lt['top3'])
# Out:
# <Axes: ylabel='top3'>

# %%
# Plot the time-series data
plt.plot(lt['Date'], lt['1st'])
plt.xlabel('Date')
plt.ylabel('1st')
plt.xticks(rotation = 45)
plt.title('Time Series Data')
plt.show()

# %%
import pandas as pd
from statsmodels.tsa.ar_model import AutoReg

# Create and fit the AR model
model = AutoReg(lt['1st'], lags=1)
ar_model = model.fit()

# Make predictions
predictions = ar_model.predict(start=len(lt), end=len(lt)+3)  # Replace 3 with the number of future values to predict

print(predictions)
# Out:
# 702    480626.942592
# 703    497946.032907
# 704    497267.043928
# 705    497293.663458
# dtype: float64

# %%
lt['Year'] = pd.to_datetime(lt['Date']).dt.year
lt['Month'] = pd.to_datetime(lt['Date']).dt.month
lt['Day'] = pd.to_datetime(lt['Date']).dt.day

# %%
lt_1 = lt.copy()

# %%
lt_1['up2'] = lt_1['up2'].astype(str)

# Split each value in the 'digi' column into its individual digits
lt_1['Tens digit'] = lt_1['up2'].apply(lambda x: int(x[0]))
lt_1['Units digit'] = lt_1['up2'].apply(lambda x: int(x[1]) if len(x) > 1 else 0)

# %%
lt_1['top3'] = lt_1['top3'].astype(str)

# Split each value in the 'digi' column into its individual digits
lt_1['c3_r1'] = lt_1['top3'].apply(lambda x: int(x[0]))
lt_1['c3_r2'] = lt_1['top3'].apply(lambda x: int(x[1]))
lt_1['c3_r3'] = lt_1['top3'].apply(lambda x: int(x[2]))

# %%
lt_1
# Out:
#           Date     1st top3 up2  weekday_dum    weekday  Year  Month  Day  \
# 0   2024-05-16  205690  690  60            7   Saturday  2024      5   16
# 1   2024-05-02  980116  116  17            4  Wednesday  2024      5    2
# 2   2024-04-16  943598  598  79            3    Tuesday  2024      4   16
# 3   2024-04-01  803481  481  90            2     Monday  2024      4    1
# 4   2024-03-16  997626  626  78            7   Saturday  2024      3   16
# ..         ...     ...  ...  ..          ...        ...   ...    ...  ...
# 697 1995-03-16  646847  847  67            5   Thursday  1995      3   16
# 698 1995-03-01  411454  454  71            4  Wednesday  1995      3    1
# 699 1995-02-16  869070  070  95            5   Thursday  1995      2   16
# 700 1995-02-01  198162  162  48            4  Wednesday  1995      2    1
# 701 1995-01-16  922388  388  40            2     Monday  1995      1   16
#
#      Tens digit  Units digit  c3_r1  c3_r2  c3_r3
# 0             6            0      6      9      0
# 1             1            7      1      1      6
# 2             7            9      5      9      8
# 3             9            0      4      8      1
# 4             7            8      6      2      6
# ..          ...          ...    ...    ...    ...
# 697           6            7      8      4      7
# 698           7            1      4      5      4
# 699           9            5      0      7      0
# 700           4            8      1      6      2
# 701           4            0      3      8      8
#
# [702 rows x 14 columns]

# %% [markdown]
# # LSTM Model

# %% [markdown]
# ## ไม่ล่วงหน้า

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
df = lt_1.copy()

# %%
df
# Out:
#           Date     1st top3 up2  weekday_dum    weekday  Year  Month  Day  \
# 0   2024-05-16  205690  690  60            7   Saturday  2024      5   16
# 1   2024-05-02  980116  116  17            4  Wednesday  2024      5    2
# 2   2024-04-16  943598  598  79            3    Tuesday  2024      4   16
# 3   2024-04-01  803481  481  90            2     Monday  2024      4    1
# 4   2024-03-16  997626  626  78            7   Saturday  2024      3   16
# ..         ...     ...  ...  ..          ...        ...   ...    ...  ...
# 697 1995-03-16  646847  847  67            5   Thursday  1995      3   16
# 698 1995-03-01  411454  454  71            4  Wednesday  1995      3    1
# 699 1995-02-16  869070  070  95            5   Thursday  1995      2   16
# 700 1995-02-01  198162  162  48            4  Wednesday  1995      2    1
# 701 1995-01-16  922388  388  40            2     Monday  1995      1   16
#
#      Tens digit  Units digit  c3_r1  c3_r2  c3_r3
# 0             6            0      6      9      0
# 1             1            7      1      1      6
# 2             7            9      5      9      8
# 3             9            0      4      8      1
# 4             7            8      6      2      6
# ..          ...          ...    ...    ...    ...
# 697           6            7      8      4      7
# 698           7            1      4      5      4
# 699           9            5      0      7      0
# 700           4            8      1      6      2
# 701           4            0      3      8      8
#
# [702 rows x 14 columns]

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
df1 = df.copy()
df.drop(['Date','1st','weekday_dum','weekday','Year','Month','Day','Tens digit','Units digit','c3_r1','c3_r2','c3_r3'], axis=1, inplace=True)

number_of_features = df.shape[1]

# %%
df1.drop(['1st','weekday_dum','weekday','Year','Month','Day','Tens digit','Units digit','c3_r1','c3_r2','c3_r3'], axis=1, inplace=True)

# %%
window_length = 7
window_length
# Out:
# 7

# %%
train = df.copy()
train.head((window_length+1))
# Out:
#   top3 up2
# 0  690  60
# 1  116  17
# 2  598  79
# 3  481  90
# 4  626  78
# 5  603  79
# 6  395  43
# 7  063  09

# %%
train_rows = train.values.shape[0]
train_samples = np.empty([ train_rows - window_length, window_length, number_of_features], dtype=float)
train_labels = np.empty([ train_rows - window_length, number_of_features], dtype=float)
for i in range(0, train_rows-window_length):
    train_samples[i] = train.iloc[i : i+window_length, 0 : number_of_features]
    train_labels[i] = train.iloc[i+window_length : i+window_length+1, 0 : number_of_features]

# %%
train_samples[0]
# Out:
# array([[690.,  60.],
#        [116.,  17.],
#        [598.,  79.],
#        [481.,  90.],
#        [626.,  78.],
#        [603.,  79.],
#        [395.,  43.]])

# %%
train_labels[0]
# Out:
# array([63.,  9.])

# %%
scaler = StandardScaler()
transformed_dataset = scaler.fit_transform(train.values)
scaled_train_samples = pd.DataFrame(data=transformed_dataset, index=train.index)

# %%
scaled_train_samples.head(window_length+1)
# Out:
#           0         1
# 0  0.646511  0.279825
# 1 -1.380838 -1.210434
# 2  0.321570  0.938311
# 3 -0.091670  1.319540
# 4  0.420465  0.903654
# 5  0.339230  0.938311
# 6 -0.395419 -0.309348
# 7 -1.568032 -1.487692

# %%
x_train = np.empty([ train_rows - window_length, window_length, number_of_features], dtype=float)
y_train = np.empty([ train_rows - window_length, number_of_features], dtype=float)

for i in range(0, train_rows-window_length):
    x_train[i] = scaled_train_samples.iloc[i : i+window_length, 0 : number_of_features]
    y_train[i] = scaled_train_samples.iloc[i+window_length : i+window_length+1, 0 : number_of_features]

# %%
y_train
# Out:
# array([[-1.56803198, -1.48769192],
#        [ 1.66724904,  0.3144819 ],
#        [ 0.13084375,  1.28488319],
#        ...,
#        [-1.54330822,  1.49282632],
#        [-1.21836733, -0.13606156],
#        [-0.42014297, -0.41331907]])

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Bidirectional, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import mse

# %%
# Initialising the RNN
model = Sequential()
# Adding the input layer and the LSTM layer
model.add(Bidirectional(LSTM(240,
                        input_shape = (window_length, number_of_features),
                        return_sequences = True)))
# Adding a first Dropout layer
model.add(Dropout(0.2))
# Adding a second LSTM layer
model.add(Bidirectional(LSTM(240,
                        input_shape = (window_length, number_of_features),
                        return_sequences = True)))
# Adding a second Dropout layer
model.add(Dropout(0.2))
# Adding a third LSTM layer
model.add(Bidirectional(LSTM(240,
                        input_shape = (window_length, number_of_features),
                        return_sequences = True)))
# Adding a fourth LSTM layer
model.add(Bidirectional(LSTM(240,
                        input_shape = (window_length, number_of_features),
                        return_sequences = False)))
# Adding a third Dropout layer
model.add(Dropout(0.2))
# Adding the first output layer
model.add(Dense(70))
# Adding the last output layer
model.add(Dense(number_of_features))

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Bidirectional, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import mse

# %%
# Initialising the RNN
model = Sequential()
# Adding the input layer and the LSTM layer
model.add(Bidirectional(LSTM(240,
                        input_shape = (window_length, number_of_features),
                        return_sequences = True)))
# Adding a first Dropout layer
model.add(Dropout(0.2))
# Adding a second LSTM layer
model.add(Bidirectional(LSTM(240,
                        input_shape = (window_length, number_of_features),
                        return_sequences = True)))
# Adding a second Dropout layer
model.add(Dropout(0.2))
# Adding a third LSTM layer
model.add(Bidirectional(LSTM(240,
                        input_shape = (window_length, number_of_features),
                        return_sequences = True)))
# Adding a fourth LSTM layer
model.add(Bidirectional(LSTM(240,
                        input_shape = (window_length, number_of_features),
                        return_sequences = False)))
# Adding a third Dropout layer
model.add(Dropout(0.2))
# Adding the first output layer
model.add(Dense(37))
# Adding the last output layer
model.add(Dense(number_of_features))

# %%
model.compile(optimizer=Adam(learning_rate=0.001), loss ='mse', metrics=['accuracy'])

# %%
model.fit(x=x_train, y=y_train, batch_size=128, epochs=200, verbose=2)
# Out:
# Epoch 1/200
# 6/6 - 26s - loss: 1.0100 - accuracy: 0.4791 - 26s/epoch - 4s/step
# Epoch 2/200
# 6/6 - 4s - loss: 1.0091 - accuracy: 0.4820 - 4s/epoch - 699ms/step
# Epoch 3/200
# 6/6 - 3s - loss: 1.0043 - accuracy: 0.5252 - 3s/epoch - 549ms/step
# Epoch 4/200
# 6/6 - 3s - loss: 1.0064 - accuracy: 0.4964 - 3s/epoch - 510ms/step
# Epoch 5/200
# 6/6 - 5s - loss: 1.0052 - accuracy: 0.5036 - 5s/epoch - 758ms/step
# Epoch 6/200
# 6/6 - 4s - loss: 1.0019 - accuracy: 0.4964 - 4s/epoch - 741ms/step
# Epoch 7/200
# 6/6 - 3s - loss: 1.0024 - accuracy: 0.5122 - 3s/epoch - 526ms/step
# Epoch 8/200
# 6/6 - 3s - loss: 1.0031 - accuracy: 0.5209 - 3s/epoch - 517ms/step
# Epoch 9/200
# 6/6 - 5s - loss: 1.0005 - accuracy: 0.5165 - 5s/epoch - 774ms/step
# Epoch 10/200
# 6/6 - 4s - loss: 1.0018 - accuracy: 0.5079 - 4s/epoch - 693ms/step
# Epoch 11/200
# 6/6 - 3s - loss: 0.9985 - accuracy: 0.5094 - 3s/epoch - 550ms/step
# Epoch 12/200
# 6/6 - 3s - loss: 1.0041 - accuracy: 0.5007 - 3s/epoch - 535ms/step
# Epoch 13/200
# 6/6 - 4s - loss: 0.9992 - accuracy: 0.5108 - 4s/epoch - 733ms/step
# Epoch 14/200
# 6/6 - 4s - loss: 0.9986 - accuracy: 0.5165 - 4s/epoch - 709ms/step
# Epoch 15/200
# 6/6 - 3s - loss: 1.0009 - accuracy: 0.5079 - 3s/epoch - 575ms/step
# Epoch 16/200
# 6/6 - 3s - loss: 1.0043 - accuracy: 0.4820 - 3s/epoch - 567ms/step
# Epoch 17/200
# 6/6 - 5s - loss: 1.0019 - accuracy: 0.4921 - 5s/epoch - 827ms/step
# Epoch 18/200
# 6/6 - 4s - loss: 0.9990 - accuracy: 0.5094 - 4s/epoch - 654ms/step
# Epoch 19/200
# 6/6 - 3s - loss: 1.0027 - accuracy: 0.4748 - 3s/epoch - 519ms/step
# Epoch 20/200
# 6/6 - 3s - loss: 0.9986 - accuracy: 0.5065 - 3s/epoch - 547ms/step
# Epoch 21/200
# 6/6 - 5s - loss: 0.9940 - accuracy: 0.5309 - 5s/epoch - 823ms/step
# Epoch 22/200
# 6/6 - 4s - loss: 0.9968 - accuracy: 0.5022 - 4s/epoch - 683ms/step
# Epoch 23/200
# 6/6 - 3s - loss: 0.9927 - accuracy: 0.5223 - 3s/epoch - 517ms/step
# Epoch 24/200
# 6/6 - 3s - loss: 0.9938 - accuracy: 0.5036 - 3s/epoch - 535ms/step
# Epoch 25/200
# 6/6 - 5s - loss: 0.9933 - accuracy: 0.5180 - 5s/epoch - 827ms/step
# Epoch 26/200
# 6/6 - 4s - loss: 0.9970 - accuracy: 0.5151 - 4s/epoch - 648ms/step
# Epoch 27/200
# 6/6 - 3s - loss: 0.9970 - accuracy: 0.5007 - 3s/epoch - 569ms/step
# Epoch 28/200
# 6/6 - 4s - loss: 0.9914 - accuracy: 0.5036 - 4s/epoch - 599ms/step
# Epoch 29/200
# 6/6 - 5s - loss: 0.9901 - accuracy: 0.5137 - 5s/epoch - 885ms/step
# Epoch 30/200
# 6/6 - 3s - loss: 0.9893 - accuracy: 0.4878 - 3s/epoch - 546ms/step
# Epoch 31/200
# 6/6 - 3s - loss: 0.9926 - accuracy: 0.5050 - 3s/epoch - 518ms/step
# Epoch 32/200
# 6/6 - 3s - loss: 0.9886 - accuracy: 0.5079 - 3s/epoch - 517ms/step
# Epoch 33/200
# 6/6 - 5s - loss: 0.9883 - accuracy: 0.5036 - 5s/epoch - 870ms/step
# Epoch 34/200
# 6/6 - 4s - loss: 0.9932 - accuracy: 0.5223 - 4s/epoch - 639ms/step
# Epoch 35/200
# 6/6 - 4s - loss: 0.9824 - accuracy: 0.5223 - 4s/epoch - 600ms/step
# Epoch 36/200
# 6/6 - 4s - loss: 0.9804 - accuracy: 0.5137 - 4s/epoch - 590ms/step
# Epoch 37/200
# 6/6 - 5s - loss: 0.9762 - accuracy: 0.4950 - 5s/epoch - 880ms/step
# Epoch 38/200
# 6/6 - 3s - loss: 0.9763 - accuracy: 0.5022 - 3s/epoch - 536ms/step
# Epoch 39/200
# 6/6 - 4s - loss: 0.9736 - accuracy: 0.5324 - 4s/epoch - 592ms/step
# Epoch 40/200
# 6/6 - 3s - loss: 0.9803 - accuracy: 0.5094 - 3s/epoch - 580ms/step
# Epoch 41/200
# 6/6 - 5s - loss: 0.9822 - accuracy: 0.5122 - 5s/epoch - 899ms/step
# Epoch 42/200
# 6/6 - 3s - loss: 0.9890 - accuracy: 0.5324 - 3s/epoch - 526ms/step
# Epoch 43/200
# 6/6 - 4s - loss: 0.9943 - accuracy: 0.5295 - 4s/epoch - 590ms/step
# Epoch 44/200
# 6/6 - 4s - loss: 0.9840 - accuracy: 0.5151 - 4s/epoch - 623ms/step
# Epoch 45/200
# 6/6 - 5s - loss: 0.9878 - accuracy: 0.5223 - 5s/epoch - 825ms/step
# Epoch 46/200
# 6/6 - 3s - loss: 0.9797 - accuracy: 0.5410 - 3s/epoch - 565ms/step
# Epoch 47/200
# 6/6 - 3s - loss: 0.9827 - accuracy: 0.5194 - 3s/epoch - 554ms/step
# Epoch 48/200
# 6/6 - 3s - loss: 0.9755 - accuracy: 0.5281 - 3s/epoch - 578ms/step
# Epoch 49/200
# 6/6 - 5s - loss: 0.9764 - accuracy: 0.5036 - 5s/epoch - 863ms/step
# Epoch 50/200
# 6/6 - 3s - loss: 0.9777 - accuracy: 0.5137 - 3s/epoch - 579ms/step
# Epoch 51/200
# 6/6 - 3s - loss: 0.9751 - accuracy: 0.5122 - 3s/epoch - 540ms/step
# Epoch 52/200
# 6/6 - 4s - loss: 0.9716 - accuracy: 0.5050 - 4s/epoch - 593ms/step
# Epoch 53/200
# 6/6 - 5s - loss: 0.9695 - accuracy: 0.5194 - 5s/epoch - 886ms/step
# Epoch 54/200
# 6/6 - 4s - loss: 0.9613 - accuracy: 0.5468 - 4s/epoch - 593ms/step
# Epoch 55/200
# 6/6 - 3s - loss: 0.9605 - accuracy: 0.5252 - 3s/epoch - 545ms/step
# Epoch 56/200
# 6/6 - 4s - loss: 0.9562 - accuracy: 0.5324 - 4s/epoch - 682ms/step
# Epoch 57/200
# 6/6 - 5s - loss: 0.9508 - accuracy: 0.5453 - 5s/epoch - 753ms/step
# Epoch 58/200
# 6/6 - 4s - loss: 0.9547 - accuracy: 0.5540 - 4s/epoch - 598ms/step
# Epoch 59/200
# 6/6 - 3s - loss: 0.9476 - accuracy: 0.5583 - 3s/epoch - 550ms/step
# Epoch 60/200
# 6/6 - 4s - loss: 0.9505 - accuracy: 0.5540 - 4s/epoch - 704ms/step
# Epoch 61/200
# 6/6 - 5s - loss: 0.9347 - accuracy: 0.5367 - 5s/epoch - 769ms/step
# Epoch 62/200
# 6/6 - 4s - loss: 0.9532 - accuracy: 0.5511 - 4s/epoch - 588ms/step
# Epoch 63/200
# 6/6 - 3s - loss: 0.9432 - accuracy: 0.5727 - 3s/epoch - 527ms/step
# Epoch 64/200
# 6/6 - 4s - loss: 0.9459 - accuracy: 0.5367 - 4s/epoch - 736ms/step
# Epoch 65/200
# 6/6 - 5s - loss: 0.9347 - accuracy: 0.5396 - 5s/epoch - 799ms/step
# Epoch 66/200
# 6/6 - 3s - loss: 0.9296 - accuracy: 0.5496 - 3s/epoch - 544ms/step
# Epoch 67/200
# 6/6 - 3s - loss: 0.9293 - accuracy: 0.5712 - 3s/epoch - 524ms/step
# Epoch 68/200
# 6/6 - 4s - loss: 0.9191 - accuracy: 0.5468 - 4s/epoch - 735ms/step
# Epoch 69/200
# 6/6 - 4s - loss: 0.9330 - accuracy: 0.5410 - 4s/epoch - 708ms/step
# Epoch 70/200
# 6/6 - 3s - loss: 0.9095 - accuracy: 0.5626 - 3s/epoch - 536ms/step
# Epoch 71/200
# 6/6 - 3s - loss: 0.9042 - accuracy: 0.5856 - 3s/epoch - 544ms/step
# Epoch 72/200
# 6/6 - 4s - loss: 0.9231 - accuracy: 0.5482 - 4s/epoch - 737ms/step
# Epoch 73/200
# 6/6 - 4s - loss: 0.9031 - accuracy: 0.5683 - 4s/epoch - 702ms/step
# Epoch 74/200
# 6/6 - 3s - loss: 0.9146 - accuracy: 0.5612 - 3s/epoch - 523ms/step
# Epoch 75/200
# 6/6 - 3s - loss: 0.8825 - accuracy: 0.5914 - 3s/epoch - 571ms/step
# Epoch 76/200
# 6/6 - 5s - loss: 0.8857 - accuracy: 0.5683 - 5s/epoch - 811ms/step
# Epoch 77/200
# 6/6 - 4s - loss: 0.8572 - accuracy: 0.6014 - 4s/epoch - 673ms/step
# Epoch 78/200
# 6/6 - 3s - loss: 0.8548 - accuracy: 0.5914 - 3s/epoch - 582ms/step
# Epoch 79/200
# 6/6 - 3s - loss: 0.8472 - accuracy: 0.5928 - 3s/epoch - 517ms/step
# Epoch 80/200
# 6/6 - 5s - loss: 0.9036 - accuracy: 0.6043 - 5s/epoch - 774ms/step
# Epoch 81/200
# 6/6 - 4s - loss: 0.8787 - accuracy: 0.5612 - 4s/epoch - 725ms/step
# Epoch 82/200
# 6/6 - 3s - loss: 0.8689 - accuracy: 0.5885 - 3s/epoch - 539ms/step
# Epoch 83/200
# 6/6 - 3s - loss: 0.8383 - accuracy: 0.6144 - 3s/epoch - 515ms/step
# Epoch 84/200
# 6/6 - 5s - loss: 0.8366 - accuracy: 0.6058 - 5s/epoch - 755ms/step
# Epoch 85/200
# 6/6 - 4s - loss: 0.8367 - accuracy: 0.6331 - 4s/epoch - 713ms/step
# Epoch 86/200
# 6/6 - 3s - loss: 0.7884 - accuracy: 0.6245 - 3s/epoch - 581ms/step
# Epoch 87/200
# 6/6 - 3s - loss: 0.7851 - accuracy: 0.6619 - 3s/epoch - 535ms/step
# Epoch 88/200
# 6/6 - 5s - loss: 0.7714 - accuracy: 0.6273 - 5s/epoch - 760ms/step
# Epoch 89/200
# 6/6 - 4s - loss: 0.7669 - accuracy: 0.6417 - 4s/epoch - 652ms/step
# Epoch 90/200
# 6/6 - 3s - loss: 0.7214 - accuracy: 0.6532 - 3s/epoch - 529ms/step
# Epoch 91/200
# 6/6 - 3s - loss: 0.6943 - accuracy: 0.6748 - 3s/epoch - 539ms/step
# Epoch 92/200
# 6/6 - 5s - loss: 0.6874 - accuracy: 0.6849 - 5s/epoch - 813ms/step
# Epoch 93/200
# 6/6 - 4s - loss: 0.7219 - accuracy: 0.6216 - 4s/epoch - 689ms/step
# Epoch 94/200
# 6/6 - 3s - loss: 0.6760 - accuracy: 0.6633 - 3s/epoch - 518ms/step
# Epoch 95/200
# 6/6 - 3s - loss: 0.6831 - accuracy: 0.6576 - 3s/epoch - 519ms/step
# Epoch 96/200
# 6/6 - 4s - loss: 0.6169 - accuracy: 0.6921 - 4s/epoch - 720ms/step
# Epoch 97/200
# 6/6 - 4s - loss: 0.5791 - accuracy: 0.6906 - 4s/epoch - 726ms/step
# Epoch 98/200
# 6/6 - 3s - loss: 0.5794 - accuracy: 0.6892 - 3s/epoch - 543ms/step
# Epoch 99/200
# 6/6 - 3s - loss: 0.5152 - accuracy: 0.7309 - 3s/epoch - 516ms/step
# Epoch 100/200
# 6/6 - 4s - loss: 0.4863 - accuracy: 0.7353 - 4s/epoch - 738ms/step
# Epoch 101/200
# 6/6 - 4s - loss: 0.4468 - accuracy: 0.7626 - 4s/epoch - 726ms/step
# Epoch 102/200
# 6/6 - 3s - loss: 0.4000 - accuracy: 0.7842 - 3s/epoch - 516ms/step
# Epoch 103/200
# 6/6 - 3s - loss: 0.3500 - accuracy: 0.7827 - 3s/epoch - 548ms/step
# Epoch 104/200
# 6/6 - 5s - loss: 0.3216 - accuracy: 0.8173 - 5s/epoch - 752ms/step
# Epoch 105/200
# 6/6 - 5s - loss: 0.2809 - accuracy: 0.7899 - 5s/epoch - 752ms/step
# Epoch 106/200
# 6/6 - 3s - loss: 0.2576 - accuracy: 0.8460 - 3s/epoch - 537ms/step
# Epoch 107/200
# 6/6 - 3s - loss: 0.2330 - accuracy: 0.8446 - 3s/epoch - 512ms/step
# Epoch 108/200
# 6/6 - 5s - loss: 0.1975 - accuracy: 0.8576 - 5s/epoch - 767ms/step
# Epoch 109/200
# 6/6 - 5s - loss: 0.1947 - accuracy: 0.8345 - 5s/epoch - 765ms/step
# Epoch 110/200
# 6/6 - 3s - loss: 0.1799 - accuracy: 0.8561 - 3s/epoch - 549ms/step
# Epoch 111/200
# 6/6 - 4s - loss: 0.1764 - accuracy: 0.8604 - 4s/epoch - 591ms/step
# Epoch 112/200
# 6/6 - 5s - loss: 0.1707 - accuracy: 0.8532 - 5s/epoch - 813ms/step
# Epoch 113/200
# 6/6 - 4s - loss: 0.1443 - accuracy: 0.8547 - 4s/epoch - 632ms/step
# Epoch 114/200
# 6/6 - 3s - loss: 0.1233 - accuracy: 0.8719 - 3s/epoch - 545ms/step
# Epoch 115/200
# 6/6 - 3s - loss: 0.1124 - accuracy: 0.8777 - 3s/epoch - 572ms/step
# Epoch 116/200
# 6/6 - 5s - loss: 0.1005 - accuracy: 0.8849 - 5s/epoch - 836ms/step
# Epoch 117/200
# 6/6 - 4s - loss: 0.0981 - accuracy: 0.8921 - 4s/epoch - 647ms/step
# Epoch 118/200
# 6/6 - 4s - loss: 0.0872 - accuracy: 0.8906 - 4s/epoch - 588ms/step
# Epoch 119/200
# 6/6 - 3s - loss: 0.0791 - accuracy: 0.9108 - 3s/epoch - 538ms/step
# Epoch 120/200
# 6/6 - 5s - loss: 0.0695 - accuracy: 0.9022 - 5s/epoch - 822ms/step
# Epoch 121/200
# 6/6 - 4s - loss: 0.0666 - accuracy: 0.9137 - 4s/epoch - 600ms/step
# Epoch 122/200
# 6/6 - 3s - loss: 0.0606 - accuracy: 0.9151 - 3s/epoch - 550ms/step
# Epoch 123/200
# 6/6 - 3s - loss: 0.0567 - accuracy: 0.8978 - 3s/epoch - 563ms/step
# Epoch 124/200
# 6/6 - 5s - loss: 0.0510 - accuracy: 0.9237 - 5s/epoch - 776ms/step
# Epoch 125/200
# 6/6 - 4s - loss: 0.0449 - accuracy: 0.9281 - 4s/epoch - 632ms/step
# Epoch 126/200
# 6/6 - 3s - loss: 0.0462 - accuracy: 0.9209 - 3s/epoch - 532ms/step
# Epoch 127/200
# 6/6 - 3s - loss: 0.0420 - accuracy: 0.9209 - 3s/epoch - 533ms/step
# Epoch 128/200
# 6/6 - 5s - loss: 0.0442 - accuracy: 0.9252 - 5s/epoch - 845ms/step
# Epoch 129/200
# 6/6 - 4s - loss: 0.0415 - accuracy: 0.9367 - 4s/epoch - 666ms/step
# Epoch 130/200
# 6/6 - 3s - loss: 0.0409 - accuracy: 0.9295 - 3s/epoch - 580ms/step
# Epoch 131/200
# 6/6 - 3s - loss: 0.0363 - accuracy: 0.9424 - 3s/epoch - 562ms/step
# Epoch 132/200
# 6/6 - 5s - loss: 0.0361 - accuracy: 0.9381 - 5s/epoch - 806ms/step
# Epoch 133/200
# 6/6 - 4s - loss: 0.0347 - accuracy: 0.9252 - 4s/epoch - 589ms/step
# Epoch 134/200
# 6/6 - 3s - loss: 0.0317 - accuracy: 0.9295 - 3s/epoch - 523ms/step
# Epoch 135/200
# 6/6 - 3s - loss: 0.0316 - accuracy: 0.9266 - 3s/epoch - 532ms/step
# Epoch 136/200
# 6/6 - 5s - loss: 0.0307 - accuracy: 0.9511 - 5s/epoch - 805ms/step
# Epoch 137/200
# 6/6 - 4s - loss: 0.0309 - accuracy: 0.9424 - 4s/epoch - 623ms/step
# Epoch 138/200
# 6/6 - 3s - loss: 0.0281 - accuracy: 0.9324 - 3s/epoch - 514ms/step
# Epoch 139/200
# 6/6 - 3s - loss: 0.0272 - accuracy: 0.9468 - 3s/epoch - 512ms/step
# Epoch 140/200
# 6/6 - 4s - loss: 0.0248 - accuracy: 0.9324 - 4s/epoch - 703ms/step
# Epoch 141/200
# 6/6 - 4s - loss: 0.0277 - accuracy: 0.9453 - 4s/epoch - 703ms/step
# Epoch 142/200
# 6/6 - 3s - loss: 0.0248 - accuracy: 0.9396 - 3s/epoch - 583ms/step
# Epoch 143/200
# 6/6 - 7s - loss: 0.0261 - accuracy: 0.9439 - 7s/epoch - 1s/step
# Epoch 144/200
# 6/6 - 7s - loss: 0.0231 - accuracy: 0.9396 - 7s/epoch - 1s/step
# Epoch 145/200
# 6/6 - 4s - loss: 0.0258 - accuracy: 0.9367 - 4s/epoch - 627ms/step
# Epoch 146/200
# 6/6 - 4s - loss: 0.0231 - accuracy: 0.9482 - 4s/epoch - 624ms/step
# Epoch 147/200
# 6/6 - 5s - loss: 0.0226 - accuracy: 0.9482 - 5s/epoch - 798ms/step
# Epoch 148/200
# 6/6 - 3s - loss: 0.0231 - accuracy: 0.9525 - 3s/epoch - 511ms/step
# Epoch 149/200
# 6/6 - 3s - loss: 0.0251 - accuracy: 0.9424 - 3s/epoch - 532ms/step
# Epoch 150/200
# 6/6 - 4s - loss: 0.0231 - accuracy: 0.9496 - 4s/epoch - 600ms/step
# Epoch 151/200
# 6/6 - 5s - loss: 0.0242 - accuracy: 0.9338 - 5s/epoch - 871ms/step
# Epoch 152/200
# 6/6 - 3s - loss: 0.0227 - accuracy: 0.9410 - 3s/epoch - 530ms/step
# Epoch 153/200
# 6/6 - 3s - loss: 0.0217 - accuracy: 0.9367 - 3s/epoch - 575ms/step
# Epoch 154/200
# 6/6 - 4s - loss: 0.0228 - accuracy: 0.9396 - 4s/epoch - 648ms/step
# Epoch 155/200
# 6/6 - 5s - loss: 0.0208 - accuracy: 0.9453 - 5s/epoch - 793ms/step
# Epoch 156/200
# 6/6 - 3s - loss: 0.0214 - accuracy: 0.9338 - 3s/epoch - 549ms/step
# Epoch 157/200
# 6/6 - 3s - loss: 0.0202 - accuracy: 0.9540 - 3s/epoch - 522ms/step
# Epoch 158/200
# 6/6 - 3s - loss: 0.0194 - accuracy: 0.9540 - 3s/epoch - 543ms/step
# Epoch 159/200
# 6/6 - 5s - loss: 0.0207 - accuracy: 0.9554 - 5s/epoch - 894ms/step
# Epoch 160/200
# 6/6 - 4s - loss: 0.0201 - accuracy: 0.9511 - 4s/epoch - 595ms/step
# Epoch 161/200
# 6/6 - 3s - loss: 0.0190 - accuracy: 0.9597 - 3s/epoch - 572ms/step
# Epoch 162/200
# 6/6 - 4s - loss: 0.0193 - accuracy: 0.9424 - 4s/epoch - 674ms/step
# Epoch 163/200
# 6/6 - 5s - loss: 0.0187 - accuracy: 0.9496 - 5s/epoch - 794ms/step
# Epoch 164/200
# 6/6 - 3s - loss: 0.0197 - accuracy: 0.9424 - 3s/epoch - 515ms/step
# Epoch 165/200
# 6/6 - 3s - loss: 0.0184 - accuracy: 0.9554 - 3s/epoch - 560ms/step
# Epoch 166/200
# 6/6 - 3s - loss: 0.0185 - accuracy: 0.9396 - 3s/epoch - 577ms/step
# Epoch 167/200
# 6/6 - 5s - loss: 0.0197 - accuracy: 0.9597 - 5s/epoch - 856ms/step
# Epoch 168/200
# 6/6 - 3s - loss: 0.0191 - accuracy: 0.9482 - 3s/epoch - 539ms/step
# Epoch 169/200
# 6/6 - 3s - loss: 0.0172 - accuracy: 0.9496 - 3s/epoch - 569ms/step
# Epoch 170/200
# 6/6 - 4s - loss: 0.0189 - accuracy: 0.9568 - 4s/epoch - 714ms/step
# Epoch 171/200
# 6/6 - 5s - loss: 0.0179 - accuracy: 0.9597 - 5s/epoch - 793ms/step
# Epoch 172/200
# 6/6 - 3s - loss: 0.0174 - accuracy: 0.9511 - 3s/epoch - 549ms/step
# Epoch 173/200
# 6/6 - 3s - loss: 0.0179 - accuracy: 0.9482 - 3s/epoch - 557ms/step
# Epoch 174/200
# 6/6 - 4s - loss: 0.0187 - accuracy: 0.9554 - 4s/epoch - 725ms/step
# Epoch 175/200
# 6/6 - 5s - loss: 0.0162 - accuracy: 0.9525 - 5s/epoch - 760ms/step
# Epoch 176/200
# 6/6 - 3s - loss: 0.0168 - accuracy: 0.9554 - 3s/epoch - 565ms/step
# Epoch 177/200
# 6/6 - 4s - loss: 0.0179 - accuracy: 0.9496 - 4s/epoch - 598ms/step
# Epoch 178/200
# 6/6 - 5s - loss: 0.0159 - accuracy: 0.9482 - 5s/epoch - 789ms/step
# Epoch 179/200
# 6/6 - 4s - loss: 0.0175 - accuracy: 0.9511 - 4s/epoch - 658ms/step
# Epoch 180/200
# 6/6 - 3s - loss: 0.0165 - accuracy: 0.9669 - 3s/epoch - 575ms/step
# Epoch 181/200
# 6/6 - 3s - loss: 0.0154 - accuracy: 0.9525 - 3s/epoch - 553ms/step
# Epoch 182/200
# 6/6 - 5s - loss: 0.0157 - accuracy: 0.9540 - 5s/epoch - 835ms/step
# Epoch 183/200
# 6/6 - 4s - loss: 0.0146 - accuracy: 0.9540 - 4s/epoch - 666ms/step
# Epoch 184/200
# 6/6 - 3s - loss: 0.0157 - accuracy: 0.9597 - 3s/epoch - 514ms/step
# Epoch 185/200
# 6/6 - 3s - loss: 0.0146 - accuracy: 0.9568 - 3s/epoch - 515ms/step
# Epoch 186/200
# 6/6 - 5s - loss: 0.0150 - accuracy: 0.9568 - 5s/epoch - 781ms/step
# Epoch 187/200
# 6/6 - 4s - loss: 0.0161 - accuracy: 0.9482 - 4s/epoch - 653ms/step
# Epoch 188/200
# 6/6 - 4s - loss: 0.0145 - accuracy: 0.9583 - 4s/epoch - 585ms/step
# Epoch 189/200
# 6/6 - 3s - loss: 0.0148 - accuracy: 0.9626 - 3s/epoch - 576ms/step
# Epoch 190/200
# 6/6 - 5s - loss: 0.0136 - accuracy: 0.9626 - 5s/epoch - 865ms/step
# Epoch 191/200
# 6/6 - 4s - loss: 0.0141 - accuracy: 0.9554 - 4s/epoch - 593ms/step
# Epoch 192/200
# 6/6 - 3s - loss: 0.0150 - accuracy: 0.9511 - 3s/epoch - 523ms/step
# Epoch 193/200
# 6/6 - 3s - loss: 0.0143 - accuracy: 0.9511 - 3s/epoch - 537ms/step
# Epoch 194/200
# 6/6 - 5s - loss: 0.0141 - accuracy: 0.9568 - 5s/epoch - 831ms/step
# Epoch 195/200
# 6/6 - 4s - loss: 0.0139 - accuracy: 0.9612 - 4s/epoch - 712ms/step
# Epoch 196/200
# 6/6 - 3s - loss: 0.0139 - accuracy: 0.9612 - 3s/epoch - 575ms/step
# Epoch 197/200
# 6/6 - 4s - loss: 0.0141 - accuracy: 0.9525 - 4s/epoch - 589ms/step
# Epoch 198/200
# 6/6 - 5s - loss: 0.0155 - accuracy: 0.9655 - 5s/epoch - 861ms/step
# Epoch 199/200
# 6/6 - 3s - loss: 0.0149 - accuracy: 0.9554 - 3s/epoch - 562ms/step
# Epoch 200/200
# 6/6 - 3s - loss: 0.0146 - accuracy: 0.9511 - 3s/epoch - 564ms/step

# %% [markdown]
# ### Prediction without rounding up or down the results

# %%
print('-' * 40)
print('Prediction vs. GoundTruth without rounding up or down')
for i in range(1,10):
  test = df1.copy()
  test = test.tail((window_length+10-i))
  test = test.head((window_length+1))
  test_Date = df1.iloc[ (test.tail().index[-1]) ]['Date']
  test1 = test.head((window_length))
  test1.drop(['Date'], axis=1, inplace=True)
  test1 = np.array(test1)
  x_test = scaler.transform(test1)
  y_test_pred = model.predict(np.array([x_test]))
  y_test_true = test.drop(['Date'], axis=1, inplace=True)
  y_test_true = test.tail(1)
  print('Drawing  Date', test_Date)
  print('Prediction:\t', scaler.inverse_transform(y_test_pred).astype(int)[0])
  print('GoundTruth:\t', np.array(y_test_true)[0])
  print('-' * 40)
# Out:
# ----------------------------------------
# Prediction vs. GoundTruth without rounding up or down
# 1/1 [==============================] - 3s 3s/step
# Drawing  Date 1995-05-17 00:00:00
# Prediction:	 [346  56]
# GoundTruth:	 ['381' '55']
# ----------------------------------------
# 1/1 [==============================] - 0s 39ms/step
# Drawing  Date 1995-05-02 00:00:00
# Prediction:	 [692  89]
# GoundTruth:	 ['692' '88']
# ----------------------------------------
# 1/1 [==============================] - 0s 38ms/step
# Drawing  Date 1995-04-16 00:00:00
# Prediction:	 [586 100]
# GoundTruth:	 ['581' '99']
# ----------------------------------------
# 1/1 [==============================] - 0s 35ms/step
# Drawing  Date 1995-04-01 00:00:00
# Prediction:	 [46  4]
# GoundTruth:	 ['039' '06']
# ----------------------------------------
# 1/1 [==============================] - 0s 38ms/step
# Drawing  Date 1995-03-16 00:00:00
# Prediction:	 [859  66]
# GoundTruth:	 ['847' '67']
# ----------------------------------------
# 1/1 [==============================] - 0s 38ms/step
# Drawing  Date 1995-03-01 00:00:00
# Prediction:	 [458  71]
# GoundTruth:	 ['454' '71']
# ----------------------------------------
# 1/1 [==============================] - 0s 36ms/step
# Drawing  Date 1995-02-16 00:00:00
# Prediction:	 [77 95]
# GoundTruth:	 ['070' '95']
# ----------------------------------------
# 1/1 [==============================] - 0s 39ms/step
# Drawing  Date 1995-02-01 00:00:00
# Prediction:	 [138  49]
# GoundTruth:	 ['162' '48']
# ----------------------------------------
# 1/1 [==============================] - 0s 37ms/step
# Drawing  Date 1995-01-16 00:00:00
# Prediction:	 [365  40]
# GoundTruth:	 ['388' '40']
# ----------------------------------------

# %% [markdown]
# ### Prediction with rounding up the results

# %%
print('-' * 40)
print('Prediction vs. GoundTruth with rounding up')
for i in range(1,10):
  test = df1.copy()
  test = test.tail((window_length+10-i))
  test = test.head((window_length+1))
  test_Date = df1.iloc[ (test.tail().index[-1]) ]['Date']
  test1 = test.head((window_length))
  test1.drop(['Date'], axis=1, inplace=True)
  test1 = np.array(test1)
  x_test = scaler.transform(test1)
  y_test_pred = model.predict(np.array([x_test]))
  y_test_true = test.drop(['Date'], axis=1, inplace=True)
  y_test_true = test.tail(1)
  print('Drawing  Date', test_Date)
  print('Prediction:\t', scaler.inverse_transform(y_test_pred).astype(int)[0]+1)
  print('GoundTruth:\t', np.array(y_test_true)[0])
  print('-' * 40)
# Out:
# ----------------------------------------
# Prediction vs. GoundTruth with rounding up
# 1/1 [==============================] - 0s 40ms/step
# Drawing  Date 1995-05-17 00:00:00
# Prediction:	 [347  57]
# GoundTruth:	 ['381' '55']
# ----------------------------------------
# 1/1 [==============================] - 0s 43ms/step
# Drawing  Date 1995-05-02 00:00:00
# Prediction:	 [693  90]
# GoundTruth:	 ['692' '88']
# ----------------------------------------
# 1/1 [==============================] - 0s 45ms/step
# Drawing  Date 1995-04-16 00:00:00
# Prediction:	 [587 101]
# GoundTruth:	 ['581' '99']
# ----------------------------------------
# 1/1 [==============================] - 0s 48ms/step
# Drawing  Date 1995-04-01 00:00:00
# Prediction:	 [47  5]
# GoundTruth:	 ['039' '06']
# ----------------------------------------
# 1/1 [==============================] - 0s 42ms/step
# Drawing  Date 1995-03-16 00:00:00
# Prediction:	 [860  67]
# GoundTruth:	 ['847' '67']
# ----------------------------------------
# 1/1 [==============================] - 0s 42ms/step
# Drawing  Date 1995-03-01 00:00:00
# Prediction:	 [459  72]
# GoundTruth:	 ['454' '71']
# ----------------------------------------
# 1/1 [==============================] - 0s 48ms/step
# Drawing  Date 1995-02-16 00:00:00
# Prediction:	 [78 96]
# GoundTruth:	 ['070' '95']
# ----------------------------------------
# 1/1 [==============================] - 0s 43ms/step
# Drawing  Date 1995-02-01 00:00:00
# Prediction:	 [139  50]
# GoundTruth:	 ['162' '48']
# ----------------------------------------
# 1/1 [==============================] - 0s 43ms/step
# Drawing  Date 1995-01-16 00:00:00
# Prediction:	 [366  41]
# GoundTruth:	 ['388' '40']
# ----------------------------------------

# %% [markdown]
# ### Predict the Future Drawing Results on June 1, 2o24

# %%
next_Date = '2024-06-01'
print('-' * 40)
print('Predict the Future Drawing on 01/06/2024')
next = df.copy()
next = next.tail((window_length))
next = np.array(next)
x_next = scaler.transform(next)
y_next_pred = model.predict(np.array([x_next]))
print('Drawing  Date', next_Date)
print('Prediction without rounding up or down:\t', scaler.inverse_transform(y_next_pred).astype(int)[0])
print('Prediction with rounding up           :\t', scaler.inverse_transform(y_next_pred).astype(int)[0]+1)
print('Prediction with rounding down         :\t', scaler.inverse_transform(y_next_pred).astype(int)[0]-1)
print('-' * 40)
# Out:
# ----------------------------------------
# Predict the Future Drawing on 01/06/2024
# 1/1 [==============================] - 0s 150ms/step
# Drawing  Date 2024-06-01
# Prediction without rounding up or down:	 [448  71]
# Prediction with rounding up           :	 [449  72]
# Prediction with rounding down         :	 [447  70]
# ----------------------------------------
